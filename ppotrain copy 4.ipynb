# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 35 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 35, iteration: 0, seed: 961742
# env: metapop1
# device: cpu
# state size: (np.int64(10), np.int64(4)), action size: 20
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [256, 256]
# encoder: hidden num: 2, hidden size: [128, 128], encoder output size: 128
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 2048, minibatch size: 64, n_epochs: 10
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 100000
# -------------------------------------------------------
# --------------------------------------------------------
# Episode 500
# Episode 1000
# Episode 1500
# Episode 2000
# Episode 2500
# Episode 3000
# Episode 3500
# Episode 4000
# Episode 4500
# Episode 5000
# Episode 5500
# Episode 6000
# Episode 6500
# Episode 7000
# Episode 7500
# Episode 8000
# Episode 8500
# Episode 9000
# Episode 9500
# Episode 10000
# serial calc_performance called
# Episode 10000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0085, Critic Loss: 0.6752, Entropy: 1.8009
# best score so far: 5.59553
# -----------------------------------
# serial calc_performance called
# Episode 10200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.52
# Actor Loss: -0.0100, Critic Loss: 0.7593, Entropy: 1.8148
# best score so far: 5.59553
# -----------------------------------
# serial calc_performance called
# Episode 10400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0077, Critic Loss: 0.8008, Entropy: 1.7281
# best score so far: 5.59553
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.66
# Actor Loss: -0.0101, Critic Loss: 0.6962, Entropy: 1.6453
# best score so far: 5.66247
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0108, Critic Loss: 0.6704, Entropy: 1.5491
# best score so far: 5.66247
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0081, Critic Loss: 0.7185, Entropy: 1.5287
# best score so far: 5.66247
# -----------------------------------
# serial calc_performance called
# Episode 11200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.73
# Actor Loss: -0.0081, Critic Loss: 0.7284, Entropy: 1.5545
# best score so far: 5.73117
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0089, Critic Loss: 0.8734, Entropy: 1.5912
# best score so far: 5.75641
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.71
# Actor Loss: -0.0089, Critic Loss: 0.6750, Entropy: 1.5540
# best score so far: 5.75641
# -----------------------------------
# serial calc_performance called
# Episode 11800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.67
# Actor Loss: -0.0076, Critic Loss: 0.6340, Entropy: 1.5285
# best score so far: 5.75641
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.73
# Actor Loss: -0.0077, Critic Loss: 0.6895, Entropy: 1.5593
# best score so far: 5.75641
# -----------------------------------
# serial calc_performance called
# Episode 12200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0103, Critic Loss: 0.8655, Entropy: 1.4665
# best score so far: 5.75641
# -----------------------------------
# serial calc_performance called
# Episode 12400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0107, Critic Loss: 0.7399, Entropy: 1.5242
# best score so far: 5.76682
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0075, Critic Loss: 0.6779, Entropy: 1.4725
# best score so far: 5.76682
# -----------------------------------
# serial calc_performance called
# Episode 12800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0100, Critic Loss: 0.7505, Entropy: 1.4178
# best score so far: 5.78356
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0094, Critic Loss: 0.7533, Entropy: 1.5084
# best score so far: 5.78356
# -----------------------------------
# serial calc_performance called
# Episode 13200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0082, Critic Loss: 0.7009, Entropy: 1.4669
# best score so far: 5.78356
# -----------------------------------
# serial calc_performance called
# Episode 13400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.61
# Actor Loss: -0.0090, Critic Loss: 0.6741, Entropy: 1.4210
# best score so far: 5.78356
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0108, Critic Loss: 0.8083, Entropy: 1.3449
# best score so far: 5.78356
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.87
# Actor Loss: -0.0093, Critic Loss: 0.7217, Entropy: 1.3493
# best score so far: 5.87090
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.79
# Actor Loss: -0.0070, Critic Loss: 0.8192, Entropy: 1.3346
# best score so far: 5.87090
# -----------------------------------
# serial calc_performance called
# Episode 14200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.79
# Actor Loss: -0.0088, Critic Loss: 0.6817, Entropy: 1.3417
# best score so far: 5.87090
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.80
# Actor Loss: -0.0090, Critic Loss: 0.6845, Entropy: 1.3173
# best score so far: 5.87090
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0149, Critic Loss: 0.7376, Entropy: 1.2939
# best score so far: 5.87090
# -----------------------------------
# serial calc_performance called
# Episode 14800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0090, Critic Loss: 0.7062, Entropy: 1.2828
# best score so far: 5.87090
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0063, Critic Loss: 0.6612, Entropy: 1.2702
# best score so far: 5.87090
# -----------------------------------
# serial calc_performance called
# Episode 15200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0103, Critic Loss: 0.7818, Entropy: 1.2564
# best score so far: 5.87090
# -----------------------------------
# serial calc_performance called
# Episode 15400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.81
# Actor Loss: -0.0091, Critic Loss: 0.7436, Entropy: 1.2253
# best score so far: 5.87090
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.91
# Actor Loss: -0.0082, Critic Loss: 0.7851, Entropy: 1.2196
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 15800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.84
# Actor Loss: -0.0097, Critic Loss: 0.7427, Entropy: 1.2447
# best score so far: 5.90503
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.67
# Actor Loss: -0.0086, Critic Loss: 0.7660, Entropy: 1.2355
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 16200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0095, Critic Loss: 0.8164, Entropy: 1.2002
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 16400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0076, Critic Loss: 0.7588, Entropy: 1.1497
# best score so far: 5.90503
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0088, Critic Loss: 0.7225, Entropy: 1.1573
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.85
# Actor Loss: -0.0081, Critic Loss: 0.9869, Entropy: 1.1299
# best score so far: 5.90503
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.79
# Actor Loss: -0.0119, Critic Loss: 0.7757, Entropy: 1.1776
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 17200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.84
# Actor Loss: -0.0095, Critic Loss: 0.6776, Entropy: 1.1854
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.84
# Actor Loss: -0.0104, Critic Loss: 0.7538, Entropy: 1.1510
# best score so far: 5.90503
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.89
# Actor Loss: -0.0097, Critic Loss: 0.7321, Entropy: 1.1097
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 17800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.85
# Actor Loss: -0.0060, Critic Loss: 0.7524, Entropy: 1.1410
# best score so far: 5.90503
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0079, Critic Loss: 1.0296, Entropy: 1.1498
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 18200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.87
# Actor Loss: -0.0095, Critic Loss: 0.8759, Entropy: 1.0819
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 18400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0102, Critic Loss: 0.7427, Entropy: 1.1266
# best score so far: 5.90503
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.79
# Actor Loss: -0.0099, Critic Loss: 1.0288, Entropy: 1.0770
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 18800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0094, Critic Loss: 0.6726, Entropy: 1.0217
# best score so far: 5.90503
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.90
# Actor Loss: -0.0097, Critic Loss: 0.7205, Entropy: 1.0485
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 19200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.69
# Actor Loss: -0.0076, Critic Loss: 0.8077, Entropy: 1.0907
# best score so far: 5.90503
# -----------------------------------
# serial calc_performance called
# Episode 19400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.92
# Actor Loss: -0.0095, Critic Loss: 0.7666, Entropy: 1.1093
# best score so far: 5.91902
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0061, Critic Loss: 0.8138, Entropy: 1.0224
# best score so far: 5.91902
# -----------------------------------
# serial calc_performance called
# Episode 19800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.95
# Actor Loss: -0.0072, Critic Loss: 0.8310, Entropy: 1.0096
# best score so far: 5.94644
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.90
# Actor Loss: -0.0074, Critic Loss: 0.8431, Entropy: 1.0384
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 20200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0102, Critic Loss: 0.6416, Entropy: 1.0694
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 20400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0070, Critic Loss: 0.8228, Entropy: 1.0238
# best score so far: 5.94644
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0077, Critic Loss: 0.7062, Entropy: 0.9581
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 20800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.74
# Actor Loss: -0.0088, Critic Loss: 0.8716, Entropy: 1.0523
# best score so far: 5.94644
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0086, Critic Loss: 0.7618, Entropy: 1.0414
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 21200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0089, Critic Loss: 0.7987, Entropy: 1.0132
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 21400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0055, Critic Loss: 0.7684, Entropy: 1.0406
# best score so far: 5.94644
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.70
# Actor Loss: -0.0064, Critic Loss: 0.7181, Entropy: 0.9854
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 21800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0103, Critic Loss: 0.8296, Entropy: 1.0076
# best score so far: 5.94644
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0069, Critic Loss: 0.6567, Entropy: 0.9772
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 22200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0098, Critic Loss: 0.6977, Entropy: 1.0444
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 22400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0080, Critic Loss: 0.8517, Entropy: 1.0219
# best score so far: 5.94644
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0083, Critic Loss: 0.6884, Entropy: 1.0157
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 22800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0077, Critic Loss: 0.7452, Entropy: 1.0404
# best score so far: 5.94644
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.94
# Actor Loss: -0.0082, Critic Loss: 0.8348, Entropy: 1.0116
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 23200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.74
# Actor Loss: -0.0052, Critic Loss: 0.7232, Entropy: 1.0252
# best score so far: 5.94644
# -----------------------------------
# serial calc_performance called
# Episode 23400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0096, Critic Loss: 0.8571, Entropy: 0.9622
# best score so far: 5.94644
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.95
# Actor Loss: -0.0078, Critic Loss: 0.8010, Entropy: 0.9920
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 23800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0056, Critic Loss: 0.6634, Entropy: 0.9552
# best score so far: 5.94773
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.67
# Actor Loss: -0.0115, Critic Loss: 0.7351, Entropy: 1.0267
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 24200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0067, Critic Loss: 0.8481, Entropy: 0.9826
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 24400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0098, Critic Loss: 0.8073, Entropy: 0.9821
# best score so far: 5.94773
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0077, Critic Loss: 0.7625, Entropy: 0.9757
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 24800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0088, Critic Loss: 0.6736, Entropy: 0.9403
# best score so far: 5.94773
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0084, Critic Loss: 0.7838, Entropy: 0.9416
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 25200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0120, Critic Loss: 0.7276, Entropy: 0.9862
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 25400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0079, Critic Loss: 0.6192, Entropy: 0.9130
# best score so far: 5.94773
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0075, Critic Loss: 0.7012, Entropy: 0.9614
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 25800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.78
# Actor Loss: -0.0069, Critic Loss: 0.6848, Entropy: 0.8629
# best score so far: 5.94773
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0080, Critic Loss: 0.6143, Entropy: 0.9313
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 26200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0078, Critic Loss: 0.8172, Entropy: 0.9087
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 26400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0083, Critic Loss: 0.7672, Entropy: 0.8706
# best score so far: 5.94773
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0092, Critic Loss: 0.7914, Entropy: 0.8677
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 26800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.93
# Actor Loss: -0.0093, Critic Loss: 0.6467, Entropy: 0.8580
# best score so far: 5.94773
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0089, Critic Loss: 0.7529, Entropy: 0.8111
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 27200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0087, Critic Loss: 0.7018, Entropy: 0.8373
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 27400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0087, Critic Loss: 0.8803, Entropy: 0.8418
# best score so far: 5.94773
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0074, Critic Loss: 0.7643, Entropy: 0.8589
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 27800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0092, Critic Loss: 0.8870, Entropy: 0.8288
# best score so far: 5.94773
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.94
# Actor Loss: -0.0072, Critic Loss: 0.8618, Entropy: 0.7882
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 28200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.94
# Actor Loss: -0.0089, Critic Loss: 0.8489, Entropy: 0.8019
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 28400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0053, Critic Loss: 0.6644, Entropy: 0.7581
# best score so far: 5.94773
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0066, Critic Loss: 0.7927, Entropy: 0.7737
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 28800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.72
# Actor Loss: -0.0093, Critic Loss: 0.7729, Entropy: 0.7560
# best score so far: 5.94773
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0075, Critic Loss: 0.7323, Entropy: 0.7670
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 29200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0100, Critic Loss: 0.7581, Entropy: 0.7515
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 29400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0084, Critic Loss: 0.6246, Entropy: 0.7470
# best score so far: 5.94773
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0071, Critic Loss: 0.7771, Entropy: 0.7120
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 29800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0095, Critic Loss: 0.7251, Entropy: 0.7507
# best score so far: 5.94773
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0065, Critic Loss: 1.0201, Entropy: 0.7036
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 30200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.90
# Actor Loss: -0.0068, Critic Loss: 0.7415, Entropy: 0.7240
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 30400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0069, Critic Loss: 0.6749, Entropy: 0.7326
# best score so far: 5.94773
# -----------------------------------
# Episode 30500
# serial calc_performance called
# Episode 30600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0083, Critic Loss: 0.6419, Entropy: 0.6858
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 30800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0084, Critic Loss: 0.8428, Entropy: 0.7273
# best score so far: 5.94773
# -----------------------------------
# Episode 31000
# serial calc_performance called
# Episode 31000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0103, Critic Loss: 0.9470, Entropy: 0.7322
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 31200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0081, Critic Loss: 0.7268, Entropy: 0.7363
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 31400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.93
# Actor Loss: -0.0079, Critic Loss: 0.8576, Entropy: 0.7265
# best score so far: 5.94773
# -----------------------------------
# Episode 31500
# serial calc_performance called
# Episode 31600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0075, Critic Loss: 0.7445, Entropy: 0.7007
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 31800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0077, Critic Loss: 0.6583, Entropy: 0.6778
# best score so far: 5.94773
# -----------------------------------
# Episode 32000
# serial calc_performance called
# Episode 32000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.90
# Actor Loss: -0.0096, Critic Loss: 0.7934, Entropy: 0.6729
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 32200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0050, Critic Loss: 0.8125, Entropy: 0.6809
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 32400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0088, Critic Loss: 0.8985, Entropy: 0.6986
# best score so far: 5.94773
# -----------------------------------
# Episode 32500
# serial calc_performance called
# Episode 32600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.88
# Actor Loss: -0.0069, Critic Loss: 0.7956, Entropy: 0.6853
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 32800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0077, Critic Loss: 0.8250, Entropy: 0.6672
# best score so far: 5.94773
# -----------------------------------
# Episode 33000
# serial calc_performance called
# Episode 33000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0089, Critic Loss: 0.6947, Entropy: 0.6618
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 33200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0096, Critic Loss: 0.6875, Entropy: 0.7163
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 33400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0077, Critic Loss: 0.7004, Entropy: 0.6785
# best score so far: 5.94773
# -----------------------------------
# Episode 33500
# serial calc_performance called
# Episode 33600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0055, Critic Loss: 0.8005, Entropy: 0.6791
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 33800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.94
# Actor Loss: -0.0085, Critic Loss: 0.8171, Entropy: 0.6573
# best score so far: 5.94773
# -----------------------------------
# Episode 34000
# serial calc_performance called
# Episode 34000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0075, Critic Loss: 0.8167, Entropy: 0.6743
# best score so far: 5.94773
# -----------------------------------
# serial calc_performance called
# Episode 34200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.95
# Actor Loss: -0.0082, Critic Loss: 0.8046, Entropy: 0.6961
# best score so far: 5.95224
# -----------------------------------
# serial calc_performance called
# Episode 34400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0099, Critic Loss: 0.9578, Entropy: 0.6999
# best score so far: 5.95224
# -----------------------------------
# Episode 34500
# serial calc_performance called
# Episode 34600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.90
# Actor Loss: -0.0094, Critic Loss: 0.7954, Entropy: 0.6737
# best score so far: 5.95224
# -----------------------------------
# serial calc_performance called
# Episode 34800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0074, Critic Loss: 0.7683, Entropy: 0.6601
# best score so far: 5.95224
# -----------------------------------
# Episode 35000
# serial calc_performance called
# Episode 35000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0068, Critic Loss: 0.7118, Entropy: 0.6913
# best score so far: 5.95224
# -----------------------------------
# serial calc_performance called
# Episode 35200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0079, Critic Loss: 0.8338, Entropy: 0.7063
# best score so far: 5.95224
# -----------------------------------
# serial calc_performance called
# Episode 35400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0073, Critic Loss: 0.5867, Entropy: 0.6947
# best score so far: 5.95224
# -----------------------------------
# Episode 35500
# serial calc_performance called
# Episode 35600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0078, Critic Loss: 0.7919, Entropy: 0.6722
# best score so far: 5.95224
# -----------------------------------
# serial calc_performance called
# Episode 35800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.95
# Actor Loss: -0.0084, Critic Loss: 0.7931, Entropy: 0.7364
# best score so far: 5.95404
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0078, Critic Loss: 0.6883, Entropy: 0.6959
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 36200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0091, Critic Loss: 0.7415, Entropy: 0.6593
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 36400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.88
# Actor Loss: -0.0073, Critic Loss: 0.9362, Entropy: 0.6811
# best score so far: 5.95404
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0071, Critic Loss: 0.9261, Entropy: 0.6582
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 36800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0074, Critic Loss: 0.7446, Entropy: 0.7338
# best score so far: 5.95404
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0083, Critic Loss: 0.7137, Entropy: 0.6444
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 37200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0084, Critic Loss: 0.7354, Entropy: 0.6920
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 37400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0071, Critic Loss: 0.7100, Entropy: 0.6629
# best score so far: 5.95404
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0090, Critic Loss: 0.8064, Entropy: 0.6883
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.95
# Actor Loss: -0.0105, Critic Loss: 0.8456, Entropy: 0.6216
# best score so far: 5.95404
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0087, Critic Loss: 0.6191, Entropy: 0.6297
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 38200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0063, Critic Loss: 0.7341, Entropy: 0.6151
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0072, Critic Loss: 0.7487, Entropy: 0.6002
# best score so far: 5.95404
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.76
# Actor Loss: -0.0097, Critic Loss: 0.6677, Entropy: 0.6128
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 38800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0070, Critic Loss: 0.7511, Entropy: 0.5972
# best score so far: 5.95404
# -----------------------------------
# Episode 39000
# serial calc_performance called
# Episode 39000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0085, Critic Loss: 0.9539, Entropy: 0.6004
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 39200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.91
# Actor Loss: -0.0077, Critic Loss: 0.7509, Entropy: 0.6368
# best score so far: 5.95404
# -----------------------------------
# serial calc_performance called
# Episode 39400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0085, Critic Loss: 0.6725, Entropy: 0.6363
# best score so far: 5.95404
# -----------------------------------
# Episode 39500
# serial calc_performance called
# Episode 39600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.96
# Actor Loss: -0.0078, Critic Loss: 0.6998, Entropy: 0.6582
# best score so far: 5.95801
# -----------------------------------
# serial calc_performance called
# Episode 39800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0091, Critic Loss: 0.7740, Entropy: 0.6156
# best score so far: 5.95801
# -----------------------------------
# Episode 40000
# serial calc_performance called
# Episode 40000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0086, Critic Loss: 0.8129, Entropy: 0.5955
# best score so far: 5.95801
# -----------------------------------
# serial calc_performance called
# Episode 40200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0073, Critic Loss: 0.6671, Entropy: 0.6229
# best score so far: 5.95801
# -----------------------------------
# serial calc_performance called
# Episode 40400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0070, Critic Loss: 0.8171, Entropy: 0.6348
# best score so far: 5.95801
# -----------------------------------
# Episode 40500
# serial calc_performance called
# Episode 40600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0078, Critic Loss: 0.6864, Entropy: 0.6318
# best score so far: 5.95801
# -----------------------------------
# serial calc_performance called
# Episode 40800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.99
# Actor Loss: -0.0069, Critic Loss: 0.8469, Entropy: 0.6143
# best score so far: 5.99232
# -----------------------------------
# Episode 41000
# serial calc_performance called
# Episode 41000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0074, Critic Loss: 0.6632, Entropy: 0.6441
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 41200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0070, Critic Loss: 0.6885, Entropy: 0.6071
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 41400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0062, Critic Loss: 0.7096, Entropy: 0.6174
# best score so far: 5.99232
# -----------------------------------
# Episode 41500
# serial calc_performance called
# Episode 41600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0067, Critic Loss: 0.7045, Entropy: 0.5798
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 41800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0074, Critic Loss: 0.6794, Entropy: 0.6004
# best score so far: 5.99232
# -----------------------------------
# Episode 42000
# serial calc_performance called
# Episode 42000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0055, Critic Loss: 0.7402, Entropy: 0.5512
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 42200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0083, Critic Loss: 0.6701, Entropy: 0.6070
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 42400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0061, Critic Loss: 0.7041, Entropy: 0.5616
# best score so far: 5.99232
# -----------------------------------
# Episode 42500
# serial calc_performance called
# Episode 42600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0063, Critic Loss: 0.7901, Entropy: 0.5563
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 42800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0072, Critic Loss: 0.7733, Entropy: 0.5398
# best score so far: 5.99232
# -----------------------------------
# Episode 43000
# serial calc_performance called
# Episode 43000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0064, Critic Loss: 0.7461, Entropy: 0.5816
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 43200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.87
# Actor Loss: -0.0082, Critic Loss: 0.7881, Entropy: 0.5738
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 43400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.90
# Actor Loss: -0.0078, Critic Loss: 0.6743, Entropy: 0.5578
# best score so far: 5.99232
# -----------------------------------
# Episode 43500
# serial calc_performance called
# Episode 43600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.94
# Actor Loss: -0.0065, Critic Loss: 0.6470, Entropy: 0.6106
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 43800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0081, Critic Loss: 0.8075, Entropy: 0.5769
# best score so far: 5.99232
# -----------------------------------
# Episode 44000
# serial calc_performance called
# Episode 44000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0093, Critic Loss: 0.7843, Entropy: 0.5662
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 44200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0070, Critic Loss: 0.6061, Entropy: 0.5806
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 44400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0086, Critic Loss: 0.7509, Entropy: 0.5427
# best score so far: 5.99232
# -----------------------------------
# Episode 44500
# serial calc_performance called
# Episode 44600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.96
# Actor Loss: -0.0056, Critic Loss: 0.7725, Entropy: 0.5938
# best score so far: 5.99232
# -----------------------------------
# serial calc_performance called
# Episode 44800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.91
# Actor Loss: -0.0105, Critic Loss: 0.8922, Entropy: 0.6313
# best score so far: 5.99232
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 6.03
# Actor Loss: -0.0060, Critic Loss: 0.7135, Entropy: 0.6015
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 45200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.93
# Actor Loss: -0.0077, Critic Loss: 0.6470, Entropy: 0.5809
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 45400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0074, Critic Loss: 0.8568, Entropy: 0.5741
# best score so far: 6.02705
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0091, Critic Loss: 0.5401, Entropy: 0.5889
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 45800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0070, Critic Loss: 0.8420, Entropy: 0.5781
# best score so far: 6.02705
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0073, Critic Loss: 0.8035, Entropy: 0.5990
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 46200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0062, Critic Loss: 0.8278, Entropy: 0.5697
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 46400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0071, Critic Loss: 0.7213, Entropy: 0.5828
# best score so far: 6.02705
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0058, Critic Loss: 0.9307, Entropy: 0.5668
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0073, Critic Loss: 0.7742, Entropy: 0.5450
# best score so far: 6.02705
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.82
# Actor Loss: -0.0055, Critic Loss: 0.7876, Entropy: 0.5825
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 47200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.96
# Actor Loss: -0.0068, Critic Loss: 0.7020, Entropy: 0.5551
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.88
# Actor Loss: -0.0070, Critic Loss: 0.7118, Entropy: 0.5591
# best score so far: 6.02705
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0077, Critic Loss: 0.6628, Entropy: 0.5482
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 47800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.90
# Actor Loss: -0.0081, Critic Loss: 0.7103, Entropy: 0.5532
# best score so far: 6.02705
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.91
# Actor Loss: -0.0082, Critic Loss: 0.7657, Entropy: 0.5183
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 48200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0071, Critic Loss: 0.7290, Entropy: 0.5517
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 48400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0062, Critic Loss: 0.6769, Entropy: 0.5244
# best score so far: 6.02705
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.88
# Actor Loss: -0.0081, Critic Loss: 0.8454, Entropy: 0.5187
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 48800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.93
# Actor Loss: -0.0049, Critic Loss: 0.7793, Entropy: 0.5528
# best score so far: 6.02705
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0056, Critic Loss: 0.6878, Entropy: 0.5616
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 49200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0065, Critic Loss: 0.8038, Entropy: 0.5880
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 49400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.89
# Actor Loss: -0.0062, Critic Loss: 0.6760, Entropy: 0.5970
# best score so far: 6.02705
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.94
# Actor Loss: -0.0069, Critic Loss: 0.8185, Entropy: 0.5339
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0082, Critic Loss: 0.6545, Entropy: 0.5642
# best score so far: 6.02705
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.93
# Actor Loss: -0.0080, Critic Loss: 0.6627, Entropy: 0.5363
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 50200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.90
# Actor Loss: -0.0073, Critic Loss: 0.6765, Entropy: 0.5670
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.92
# Actor Loss: -0.0044, Critic Loss: 0.8314, Entropy: 0.5541
# best score so far: 6.02705
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.83
# Actor Loss: -0.0049, Critic Loss: 0.6822, Entropy: 0.5331
# best score so far: 6.02705
# -----------------------------------
# serial calc_performance called
# Episode 50800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.94
# Actor Loss: -0.0065, Critic Loss: 0.7497, Entropy: 0.5440
# best score so far: 6.02705
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 6.04
# Actor Loss: -0.0042, Critic Loss: 0.7848, Entropy: 0.5417
# best score so far: 6.04468
# -----------------------------------
# serial calc_performance called
# Episode 51200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.87
# Actor Loss: -0.0037, Critic Loss: 0.7031, Entropy: 0.5448
# best score so far: 6.04468
# -----------------------------------
# serial calc_performance called
# Episode 51400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.86
# Actor Loss: -0.0051, Critic Loss: 0.7335, Entropy: 0.5439
# best score so far: 6.04468
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.94
# Actor Loss: -0.0053, Critic Loss: 0.9635, Entropy: 0.5603
# ...
# -----------------------------------
# serial calc_performance called
# Episode 44800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0094, Critic Loss: 0.7316, Entropy: 0.6213
# best score so far: 5.86732
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0076, Critic Loss: 0.7211, Entropy: 0.5907
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 45200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0067, Critic Loss: 0.6472, Entropy: 0.5828
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 45400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0056, Critic Loss: 0.7661, Entropy: 0.5729
# best score so far: 5.86732
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.74
# Actor Loss: -0.0081, Critic Loss: 0.7268, Entropy: 0.5597
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 45800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0063, Critic Loss: 0.7561, Entropy: 0.5756
# best score so far: 5.86732
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0095, Critic Loss: 0.6027, Entropy: 0.5769
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 46200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.78
# Actor Loss: -0.0079, Critic Loss: 0.7746, Entropy: 0.5900
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 46400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.76
# Actor Loss: -0.0072, Critic Loss: 0.7031, Entropy: 0.5711
# best score so far: 5.86732
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.70
# Actor Loss: -0.0085, Critic Loss: 0.6824, Entropy: 0.5679
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.63
# Actor Loss: -0.0069, Critic Loss: 0.7726, Entropy: 0.5554
# best score so far: 5.86732
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0075, Critic Loss: 0.8495, Entropy: 0.5781
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 47200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0083, Critic Loss: 0.8436, Entropy: 0.6047
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.72
# Actor Loss: -0.0074, Critic Loss: 0.7724, Entropy: 0.5831
# best score so far: 5.86732
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0069, Critic Loss: 0.8056, Entropy: 0.6244
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 47800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.66
# Actor Loss: -0.0062, Critic Loss: 0.9115, Entropy: 0.6100
# best score so far: 5.86732
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.66
# Actor Loss: -0.0083, Critic Loss: 0.6002, Entropy: 0.6021
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 48200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.76
# Actor Loss: -0.0082, Critic Loss: 0.6604, Entropy: 0.6070
# best score so far: 5.86732
# -----------------------------------
# serial calc_performance called
# Episode 48400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.92
# Actor Loss: -0.0091, Critic Loss: 0.7528, Entropy: 0.6179
# best score so far: 5.91771
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0077, Critic Loss: 0.6267, Entropy: 0.6304
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 48800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0093, Critic Loss: 0.7045, Entropy: 0.6165
# best score so far: 5.91771
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0068, Critic Loss: 0.8069, Entropy: 0.5636
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 49200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0080, Critic Loss: 0.7082, Entropy: 0.6152
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 49400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0060, Critic Loss: 0.7810, Entropy: 0.5929
# best score so far: 5.91771
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.67
# Actor Loss: -0.0086, Critic Loss: 0.7487, Entropy: 0.6347
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0056, Critic Loss: 0.7078, Entropy: 0.6498
# best score so far: 5.91771
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.68
# Actor Loss: -0.0080, Critic Loss: 0.8839, Entropy: 0.6530
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 50200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.77
# Actor Loss: -0.0061, Critic Loss: 0.7345, Entropy: 0.6673
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0045, Critic Loss: 0.8078, Entropy: 0.6643
# best score so far: 5.91771
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0061, Critic Loss: 0.7087, Entropy: 0.6326
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 50800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.80
# Actor Loss: -0.0054, Critic Loss: 0.7398, Entropy: 0.6576
# best score so far: 5.91771
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.82
# Actor Loss: -0.0057, Critic Loss: 0.6055, Entropy: 0.6533
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 51200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.71
# Actor Loss: -0.0052, Critic Loss: 0.8570, Entropy: 0.6420
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 51400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.78
# Actor Loss: -0.0047, Critic Loss: 0.6053, Entropy: 0.6061
# best score so far: 5.91771
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0062, Critic Loss: 0.7668, Entropy: 0.6495
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 51800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0054, Critic Loss: 1.1025, Entropy: 0.6031
# best score so far: 5.91771
# -----------------------------------
# Episode 52000
# serial calc_performance called
# Episode 52000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.80
# Actor Loss: -0.0072, Critic Loss: 0.7255, Entropy: 0.6087
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 52200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.74
# Actor Loss: -0.0056, Critic Loss: 0.6187, Entropy: 0.6225
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 52400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.74
# Actor Loss: -0.0050, Critic Loss: 0.7731, Entropy: 0.6374
# best score so far: 5.91771
# -----------------------------------
# Episode 52500
# serial calc_performance called
# Episode 52600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.71
# Actor Loss: -0.0055, Critic Loss: 0.8079, Entropy: 0.6493
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 52800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.82
# Actor Loss: -0.0067, Critic Loss: 0.7958, Entropy: 0.6222
# best score so far: 5.91771
# -----------------------------------
# Episode 53000
# serial calc_performance called
# Episode 53000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.84
# Actor Loss: -0.0051, Critic Loss: 0.7604, Entropy: 0.6415
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 53200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.74
# Actor Loss: -0.0069, Critic Loss: 0.9286, Entropy: 0.6336
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 53400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.78
# Actor Loss: -0.0086, Critic Loss: 0.7427, Entropy: 0.6590
# best score so far: 5.91771
# -----------------------------------
# Episode 53500
# serial calc_performance called
# Episode 53600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.71
# Actor Loss: -0.0063, Critic Loss: 0.6941, Entropy: 0.6238
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 53800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.70
# Actor Loss: -0.0059, Critic Loss: 0.6849, Entropy: 0.6013
# best score so far: 5.91771
# -----------------------------------
# Episode 54000
# serial calc_performance called
# Episode 54000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.69
# Actor Loss: -0.0055, Critic Loss: 0.6300, Entropy: 0.6190
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 54200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0051, Critic Loss: 0.9054, Entropy: 0.6121
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 54400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.84
# Actor Loss: -0.0066, Critic Loss: 0.7004, Entropy: 0.6092
# best score so far: 5.91771
# -----------------------------------
# Episode 54500
# serial calc_performance called
# Episode 54600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.76
# Actor Loss: -0.0042, Critic Loss: 0.8324, Entropy: 0.6142
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 54800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.77
# Actor Loss: -0.0070, Critic Loss: 0.6195, Entropy: 0.6378
# best score so far: 5.91771
# -----------------------------------
# Episode 55000
# serial calc_performance called
# Episode 55000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.78
# Actor Loss: -0.0058, Critic Loss: 0.8260, Entropy: 0.6384
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 55200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.78
# Actor Loss: -0.0059, Critic Loss: 0.6942, Entropy: 0.5898
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 55400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.81
# Actor Loss: -0.0052, Critic Loss: 0.7513, Entropy: 0.5980
# best score so far: 5.91771
# -----------------------------------
# Episode 55500
# serial calc_performance called
# Episode 55600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.69
# Actor Loss: -0.0059, Critic Loss: 0.7372, Entropy: 0.5990
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 55800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.78
# Actor Loss: -0.0052, Critic Loss: 0.8274, Entropy: 0.6023
# best score so far: 5.91771
# -----------------------------------
# Episode 56000
# serial calc_performance called
# Episode 56000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.66
# Actor Loss: -0.0050, Critic Loss: 0.6406, Entropy: 0.6290
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 56200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0078, Critic Loss: 0.7435, Entropy: 0.6106
# best score so far: 5.91771
# -----------------------------------
# serial calc_performance called
# Episode 56400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.93
# Actor Loss: -0.0055, Critic Loss: 0.6392, Entropy: 0.5979
# best score so far: 5.93035
# -----------------------------------
# Episode 56500
# serial calc_performance called
# Episode 56600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.82
# Actor Loss: -0.0065, Critic Loss: 0.6580, Entropy: 0.6282
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 56800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.88
# Actor Loss: -0.0060, Critic Loss: 0.6953, Entropy: 0.6166
# best score so far: 5.93035
# -----------------------------------
# Episode 57000
# serial calc_performance called
# Episode 57000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.79
# Actor Loss: -0.0052, Critic Loss: 0.6709, Entropy: 0.5993
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 57200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.69
# Actor Loss: -0.0064, Critic Loss: 0.7683, Entropy: 0.6285
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 57400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.75
# Actor Loss: -0.0072, Critic Loss: 0.6500, Entropy: 0.6246
# best score so far: 5.93035
# -----------------------------------
# Episode 57500
# serial calc_performance called
# Episode 57600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.79
# Actor Loss: -0.0056, Critic Loss: 0.7468, Entropy: 0.6244
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 57800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.84
# Actor Loss: -0.0060, Critic Loss: 0.8690, Entropy: 0.6271
# best score so far: 5.93035
# -----------------------------------
# Episode 58000
# serial calc_performance called
# Episode 58000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.84
# Actor Loss: -0.0064, Critic Loss: 0.7869, Entropy: 0.6094
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 58200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.75
# Actor Loss: -0.0057, Critic Loss: 0.8135, Entropy: 0.6215
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 58400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.76
# Actor Loss: -0.0072, Critic Loss: 0.7175, Entropy: 0.5715
# best score so far: 5.93035
# -----------------------------------
# Episode 58500
# serial calc_performance called
# Episode 58600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.81
# Actor Loss: -0.0061, Critic Loss: 0.7016, Entropy: 0.5756
# best score so far: 5.93035
# -----------------------------------
# serial calc_performance called
# Episode 58800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.71
# Actor Loss: -0.0065, Critic Loss: 0.8666, Entropy: 0.5828
# best score so far: 5.93035
# -----------------------------------
