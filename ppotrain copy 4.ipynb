# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 34 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 34, iteration: 0, seed: 460875
# env: metapop1
# device: cpu
# state size: (np.int64(20), np.int64(4)), action size: 40
# actor: hidden num: 2, hidden size: [128, 128]
# critic: hidden num: 2, hidden size: [512, 512]
# encoder: hidden num: 2, hidden size: [256, 256], encoder output size: 256
# actor lr: 0.0001, critic lr: 0.0001, encoder lr: 0.0001
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 4096, minibatch size: 128, n_epochs: 10
# evaluation interval: 300, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 100000
# -------------------------------------------------------
# --------------------------------------------------------
# Episode 500
# Episode 1000
# Episode 1500
# Episode 2000
# Episode 2500
# Episode 3000
# Episode 3500
# Episode 4000
# Episode 4500
# Episode 5000
# Episode 5500
# Episode 6000
# Episode 6500
# Episode 7000
# Episode 7500
# Episode 8000
# Episode 8500
# Episode 9000
# Episode 9500
# Episode 10000
# serial calc_performance called
# Episode 10200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.32
# Actor Loss: -0.0038, Critic Loss: 0.3334, Entropy: 7.3643
# best score so far: 4.31783
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.40
# Actor Loss: -0.0053, Critic Loss: 0.2990, Entropy: 7.3682
# best score so far: 4.40484
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.34
# Actor Loss: -0.0063, Critic Loss: 0.3205, Entropy: 7.2680
# best score so far: 4.40484
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.54
# Actor Loss: -0.0085, Critic Loss: 0.3126, Entropy: 7.1181
# best score so far: 4.54223
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.63
# Actor Loss: -0.0037, Critic Loss: 0.3337, Entropy: 7.0239
# best score so far: 4.62707
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.65
# Actor Loss: -0.0041, Critic Loss: 0.2985, Entropy: 6.9976
# best score so far: 4.64976
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.65
# Actor Loss: -0.0038, Critic Loss: 0.3407, Entropy: 6.8259
# best score so far: 4.64976
# -----------------------------------
# serial calc_performance called
# Episode 12300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.72
# Actor Loss: -0.0058, Critic Loss: 0.3789, Entropy: 6.7148
# best score so far: 4.71813
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.69
# Actor Loss: -0.0043, Critic Loss: 0.3515, Entropy: 6.7036
# best score so far: 4.71813
# -----------------------------------
# serial calc_performance called
# Episode 12900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.76
# Actor Loss: -0.0052, Critic Loss: 0.3528, Entropy: 6.4922
# best score so far: 4.75634
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.81
# Actor Loss: -0.0030, Critic Loss: 0.3981, Entropy: 6.3655
# best score so far: 4.81471
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.83
# Actor Loss: -0.0045, Critic Loss: 0.3945, Entropy: 6.2496
# best score so far: 4.83444
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.89
# Actor Loss: -0.0027, Critic Loss: 0.3687, Entropy: 6.1891
# best score so far: 4.88600
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.85
# Actor Loss: -0.0034, Critic Loss: 0.2770, Entropy: 6.2019
# best score so far: 4.88600
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.84
# Actor Loss: -0.0037, Critic Loss: 0.3362, Entropy: 6.0224
# best score so far: 4.88600
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.89
# Actor Loss: -0.0035, Critic Loss: 0.3525, Entropy: 5.9704
# best score so far: 4.89042
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.87
# Actor Loss: -0.0060, Critic Loss: 0.3421, Entropy: 5.9632
# best score so far: 4.89042
# -----------------------------------
# serial calc_performance called
# Episode 15300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.94
# Actor Loss: -0.0035, Critic Loss: 0.3536, Entropy: 5.9563
# best score so far: 4.93626
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.98
# Actor Loss: -0.0039, Critic Loss: 0.3095, Entropy: 5.9145
# best score so far: 4.97850
# -----------------------------------
# serial calc_performance called
# Episode 15900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.97
# Actor Loss: -0.0050, Critic Loss: 0.3281, Entropy: 5.8718
# best score so far: 4.97850
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.99
# Actor Loss: -0.0060, Critic Loss: 0.3870, Entropy: 5.7643
# best score so far: 4.98893
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.93
# Actor Loss: -0.0044, Critic Loss: 0.3773, Entropy: 5.8021
# best score so far: 4.98893
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.11
# Actor Loss: -0.0044, Critic Loss: 0.4357, Entropy: 5.5325
# best score so far: 5.11181
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.06
# Actor Loss: -0.0059, Critic Loss: 0.3499, Entropy: 5.4252
# best score so far: 5.11181
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.12
# Actor Loss: -0.0060, Critic Loss: 0.3491, Entropy: 5.3865
# best score so far: 5.12224
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.09
# Actor Loss: -0.0047, Critic Loss: 0.3892, Entropy: 5.3980
# best score so far: 5.12224
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.19
# Actor Loss: -0.0052, Critic Loss: 0.3724, Entropy: 5.4747
# best score so far: 5.19403
# -----------------------------------
# serial calc_performance called
# Episode 18300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.10
# Actor Loss: -0.0043, Critic Loss: 0.3253, Entropy: 5.5388
# best score so far: 5.19403
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.14
# Actor Loss: -0.0027, Critic Loss: 0.3328, Entropy: 5.3010
# best score so far: 5.19403
# -----------------------------------
# serial calc_performance called
# Episode 18900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.15
# Actor Loss: -0.0053, Critic Loss: 0.3079, Entropy: 5.0006
# best score so far: 5.19403
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.19
# Actor Loss: -0.0040, Critic Loss: 0.3733, Entropy: 5.0125
# best score so far: 5.19403
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.21
# Actor Loss: -0.0043, Critic Loss: 0.3750, Entropy: 4.8829
# best score so far: 5.21123
# -----------------------------------
# serial calc_performance called
# Episode 19800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.15
# Actor Loss: -0.0042, Critic Loss: 0.3747, Entropy: 5.0162
# best score so far: 5.21123
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.13
# Actor Loss: -0.0033, Critic Loss: 0.3488, Entropy: 4.9354
# best score so far: 5.21123
# -----------------------------------
# serial calc_performance called
# Episode 20400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.21
# Actor Loss: -0.0035, Critic Loss: 0.3761, Entropy: 4.7922
# best score so far: 5.21256
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.16
# Actor Loss: -0.0031, Critic Loss: 0.4067, Entropy: 4.7443
# best score so far: 5.21256
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.21
# Actor Loss: -0.0041, Critic Loss: 0.3055, Entropy: 4.5116
# best score so far: 5.21433
# -----------------------------------
# serial calc_performance called
# Episode 21300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.21
# Actor Loss: -0.0021, Critic Loss: 0.3544, Entropy: 4.5538
# best score so far: 5.21433
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0018, Critic Loss: 0.3611, Entropy: 4.5174
# best score so far: 5.28849
# -----------------------------------
# serial calc_performance called
# Episode 21900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.21
# Actor Loss: -0.0036, Critic Loss: 0.3765, Entropy: 4.3872
# best score so far: 5.28849
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.25
# Actor Loss: -0.0034, Critic Loss: 0.3398, Entropy: 4.3573
# best score so far: 5.28849
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.26
# Actor Loss: -0.0033, Critic Loss: 0.3668, Entropy: 4.3106
# best score so far: 5.28849
# -----------------------------------
# serial calc_performance called
# Episode 22800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0045, Critic Loss: 0.4020, Entropy: 4.0832
# best score so far: 5.32989
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0038, Critic Loss: 0.4032, Entropy: 4.1349
# best score so far: 5.32989
# -----------------------------------
# serial calc_performance called
# Episode 23400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0025, Critic Loss: 0.3535, Entropy: 4.2079
# best score so far: 5.32989
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.24
# Actor Loss: -0.0018, Critic Loss: 0.4047, Entropy: 4.1644
# best score so far: 5.32989
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.19
# Actor Loss: -0.0027, Critic Loss: 0.3737, Entropy: 4.1174
# best score so far: 5.32989
# -----------------------------------
# serial calc_performance called
# Episode 24300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.24
# Actor Loss: -0.0035, Critic Loss: 0.3645, Entropy: 4.0991
# best score so far: 5.32989
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0020, Critic Loss: 0.3096, Entropy: 3.9701
# best score so far: 5.32989
# -----------------------------------
# serial calc_performance called
# Episode 24900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0027, Critic Loss: 0.3914, Entropy: 3.8787
# best score so far: 5.32989
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0040, Critic Loss: 0.3651, Entropy: 3.8959
# best score so far: 5.32989
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.27
# Actor Loss: -0.0036, Critic Loss: 0.3975, Entropy: 3.8846
# best score so far: 5.32989
# -----------------------------------
# serial calc_performance called
# Episode 25800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0052, Critic Loss: 0.3509, Entropy: 3.9094
# best score so far: 5.33501
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0040, Critic Loss: 0.3505, Entropy: 3.8234
# best score so far: 5.33501
# -----------------------------------
# serial calc_performance called
# Episode 26400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0024, Critic Loss: 0.3810, Entropy: 3.7121
# best score so far: 5.33501
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0045, Critic Loss: 0.3232, Entropy: 3.7140
# best score so far: 5.33501
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.32
# Actor Loss: -0.0040, Critic Loss: 0.3804, Entropy: 3.7471
# best score so far: 5.33501
# -----------------------------------
# serial calc_performance called
# Episode 27300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0037, Critic Loss: 0.3573, Entropy: 3.5979
# best score so far: 5.37384
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0048, Critic Loss: 0.3623, Entropy: 3.5043
# best score so far: 5.37384
# -----------------------------------
# serial calc_performance called
# Episode 27900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0020, Critic Loss: 0.3757, Entropy: 3.4911
# best score so far: 5.37384
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0024, Critic Loss: 0.3592, Entropy: 3.6026
# best score so far: 5.37384
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.27
# Actor Loss: -0.0028, Critic Loss: 0.3663, Entropy: 3.5716
# best score so far: 5.37384
# -----------------------------------
# serial calc_performance called
# Episode 28800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0034, Critic Loss: 0.3753, Entropy: 3.5767
# best score so far: 5.37384
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.25
# Actor Loss: -0.0044, Critic Loss: 0.3843, Entropy: 3.6189
# best score so far: 5.37384
# -----------------------------------
# serial calc_performance called
# Episode 29400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.28
# Actor Loss: -0.0031, Critic Loss: 0.3531, Entropy: 3.5106
# best score so far: 5.37384
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0049, Critic Loss: 0.3142, Entropy: 3.5572
# best score so far: 5.37384
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.24
# Actor Loss: -0.0042, Critic Loss: 0.3504, Entropy: 3.5620
# best score so far: 5.37384
# -----------------------------------
# serial calc_performance called
# Episode 30300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.23
# Actor Loss: -0.0026, Critic Loss: 0.3662, Entropy: 3.6171
# best score so far: 5.37384
# -----------------------------------
# Episode 30500
# serial calc_performance called
# Episode 30600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0029, Critic Loss: 0.3798, Entropy: 3.5897
# best score so far: 5.37384
# -----------------------------------
# serial calc_performance called
# Episode 30900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0035, Critic Loss: 0.4025, Entropy: 3.5437
# best score so far: 5.37384
# -----------------------------------
# Episode 31000
# serial calc_performance called
# Episode 31200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0043, Critic Loss: 0.3351, Entropy: 3.4743
# best score so far: 5.37980
# -----------------------------------
# Episode 31500
# serial calc_performance called
# Episode 31500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0010, Critic Loss: 0.3225, Entropy: 3.3225
# best score so far: 5.37980
# -----------------------------------
# serial calc_performance called
# Episode 31800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0011, Critic Loss: 0.4004, Entropy: 3.3473
# best score so far: 5.37980
# -----------------------------------
# Episode 32000
# serial calc_performance called
# Episode 32100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0024, Critic Loss: 0.3923, Entropy: 3.2425
# best score so far: 5.37980
# -----------------------------------
# serial calc_performance called
# Episode 32400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0022, Critic Loss: 0.3429, Entropy: 3.2528
# best score so far: 5.37980
# -----------------------------------
# Episode 32500
# serial calc_performance called
# Episode 32700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0025, Critic Loss: 0.3562, Entropy: 3.1787
# best score so far: 5.37980
# -----------------------------------
# Episode 33000
# serial calc_performance called
# Episode 33000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0038, Critic Loss: 0.3759, Entropy: 3.2323
# best score so far: 5.37980
# -----------------------------------
# serial calc_performance called
# Episode 33300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.25
# Actor Loss: -0.0031, Critic Loss: 0.3859, Entropy: 3.3423
# best score so far: 5.37980
# -----------------------------------
# Episode 33500
# serial calc_performance called
# Episode 33600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0030, Critic Loss: 0.3837, Entropy: 3.2637
# best score so far: 5.37980
# -----------------------------------
# serial calc_performance called
# Episode 33900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0042, Critic Loss: 0.3390, Entropy: 3.2417
# best score so far: 5.37980
# -----------------------------------
# Episode 34000
# serial calc_performance called
# Episode 34200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0040, Critic Loss: 0.3751, Entropy: 3.3891
# best score so far: 5.37980
# -----------------------------------
# Episode 34500
# serial calc_performance called
# Episode 34500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0044, Critic Loss: 0.3467, Entropy: 3.2893
# best score so far: 5.37980
# -----------------------------------
# serial calc_performance called
# Episode 34800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0029, Critic Loss: 0.3696, Entropy: 3.2112
# best score so far: 5.37980
# -----------------------------------
# Episode 35000
# serial calc_performance called
# Episode 35100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0018, Critic Loss: 0.3430, Entropy: 3.2443
# best score so far: 5.37980
# -----------------------------------
# serial calc_performance called
# Episode 35400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0026, Critic Loss: 0.3959, Entropy: 3.2291
# best score so far: 5.41276
# -----------------------------------
# Episode 35500
# serial calc_performance called
# Episode 35700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0026, Critic Loss: 0.3812, Entropy: 3.1339
# best score so far: 5.41276
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0038, Critic Loss: 0.3991, Entropy: 3.1135
# best score so far: 5.41276
# -----------------------------------
# serial calc_performance called
# Episode 36300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0041, Critic Loss: 0.3684, Entropy: 2.9479
# best score so far: 5.44546
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0025, Critic Loss: 0.3691, Entropy: 2.8808
# best score so far: 5.44546
# -----------------------------------
# serial calc_performance called
# Episode 36900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0015, Critic Loss: 0.3639, Entropy: 2.9385
# best score so far: 5.50717
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0028, Critic Loss: 0.3846, Entropy: 2.8910
# best score so far: 5.50717
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0033, Critic Loss: 0.4013, Entropy: 2.8914
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0040, Critic Loss: 0.3377, Entropy: 2.9364
# best score so far: 5.50717
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0030, Critic Loss: 0.3740, Entropy: 2.8305
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0043, Critic Loss: 0.3465, Entropy: 2.7556
# best score so far: 5.50717
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0021, Critic Loss: 0.3481, Entropy: 2.6304
# best score so far: 5.50717
# -----------------------------------
# Episode 39000
# serial calc_performance called
# Episode 39000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0030, Critic Loss: 0.4221, Entropy: 2.6286
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 39300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0032, Critic Loss: 0.3894, Entropy: 2.5801
# best score so far: 5.50717
# -----------------------------------
# Episode 39500
# serial calc_performance called
# Episode 39600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0019, Critic Loss: 0.3948, Entropy: 2.5895
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 39900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0020, Critic Loss: 0.3572, Entropy: 2.5172
# best score so far: 5.50717
# -----------------------------------
# Episode 40000
# serial calc_performance called
# Episode 40200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0018, Critic Loss: 0.3544, Entropy: 2.5458
# best score so far: 5.50717
# -----------------------------------
# Episode 40500
# serial calc_performance called
# Episode 40500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0013, Critic Loss: 0.4214, Entropy: 2.5151
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 40800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0025, Critic Loss: 0.3311, Entropy: 2.4526
# best score so far: 5.50717
# -----------------------------------
# Episode 41000
# serial calc_performance called
# Episode 41100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0009, Critic Loss: 0.3631, Entropy: 2.4943
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 41400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0030, Critic Loss: 0.3480, Entropy: 2.4559
# best score so far: 5.50717
# -----------------------------------
# Episode 41500
# serial calc_performance called
# Episode 41700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0030, Critic Loss: 0.3809, Entropy: 2.4164
# best score so far: 5.50717
# -----------------------------------
# Episode 42000
# serial calc_performance called
# Episode 42000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0042, Critic Loss: 0.3807, Entropy: 2.4132
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 42300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0019, Critic Loss: 0.3956, Entropy: 2.4634
# best score so far: 5.50717
# -----------------------------------
# Episode 42500
# serial calc_performance called
# Episode 42600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0037, Critic Loss: 0.4217, Entropy: 2.3789
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 42900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0021, Critic Loss: 0.3786, Entropy: 2.3152
# best score so far: 5.50717
# -----------------------------------
# Episode 43000
# serial calc_performance called
# Episode 43200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0029, Critic Loss: 0.4126, Entropy: 2.2877
# best score so far: 5.50717
# -----------------------------------
# Episode 43500
# serial calc_performance called
# Episode 43500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0021, Critic Loss: 0.3851, Entropy: 2.2567
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 43800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0024, Critic Loss: 0.3580, Entropy: 2.2885
# best score so far: 5.50717
# -----------------------------------
# Episode 44000
# serial calc_performance called
# Episode 44100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0006, Critic Loss: 0.3607, Entropy: 2.2701
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 44400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0020, Critic Loss: 0.3903, Entropy: 2.2476
# best score so far: 5.50717
# -----------------------------------
# Episode 44500
# serial calc_performance called
# Episode 44700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0022, Critic Loss: 0.3971, Entropy: 2.2646
# best score so far: 5.50717
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0022, Critic Loss: 0.3898, Entropy: 2.4086
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 45300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0037, Critic Loss: 0.3426, Entropy: 2.3024
# best score so far: 5.50717
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0019, Critic Loss: 0.3936, Entropy: 2.2911
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 45900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0029, Critic Loss: 0.3813, Entropy: 2.3516
# best score so far: 5.50717
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0017, Critic Loss: 0.3892, Entropy: 2.2959
# best score so far: 5.50717
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0021, Critic Loss: 0.3954, Entropy: 2.2489
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0045, Critic Loss: 0.3358, Entropy: 2.1832
# best score so far: 5.50717
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0017, Critic Loss: 0.3875, Entropy: 2.2070
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0024, Critic Loss: 0.4148, Entropy: 2.1915
# best score so far: 5.50717
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0016, Critic Loss: 0.3765, Entropy: 2.1213
# best score so far: 5.50717
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0017, Critic Loss: 0.4083, Entropy: 2.0955
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 48300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0028, Critic Loss: 0.3528, Entropy: 2.1034
# best score so far: 5.50717
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0023, Critic Loss: 0.3886, Entropy: 2.0942
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 48900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0017, Critic Loss: 0.3392, Entropy: 2.0547
# best score so far: 5.50717
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0026, Critic Loss: 0.3680, Entropy: 2.0644
# best score so far: 5.50717
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0032, Critic Loss: 0.3576, Entropy: 2.0384
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0042, Critic Loss: 0.4146, Entropy: 1.9647
# best score so far: 5.50717
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0015, Critic Loss: 0.3397, Entropy: 1.9267
# best score so far: 5.50717
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0036, Critic Loss: 0.3752, Entropy: 1.9910
# best score so far: 5.50717
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0015, Critic Loss: 0.3727, Entropy: 2.0032
# best score so far: 5.51075
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0037, Critic Loss: 0.3529, Entropy: 1.9936
# best score so far: 5.51075
# -----------------------------------
# serial calc_performance called
# Episode 51300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0024, Critic Loss: 0.4006, Entropy: 1.9893
# best score so far: 5.51075
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0011, Critic Loss: 0.3890, Entropy: 1.9642
# best score so far: 5.51075
# -----------------------------------
# serial calc_performance called
# Episode 51900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0019, Critic Loss: 0.3949, Entropy: 2.0507
# best score so far: 5.51075
# -----------------------------------
# Episode 52000
# serial calc_performance called
# Episode 52200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0017, Critic Loss: 0.4054, Entropy: 2.0744
# best score so far: 5.51075
# -----------------------------------
# Episode 52500
# serial calc_performance called
# Episode 52500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0021, Critic Loss: 0.3775, Entropy: 2.0367
# best score so far: 5.51075
# -----------------------------------
# serial calc_performance called
# Episode 52800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0025, Critic Loss: 0.4023, Entropy: 2.0521
# best score so far: 5.51075
# -----------------------------------
# Episode 53000
# serial calc_performance called
# Episode 53100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0026, Critic Loss: 0.4366, Entropy: 2.0380
# best score so far: 5.51075
# -----------------------------------
# serial calc_performance called
# Episode 53400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0021, Critic Loss: 0.3898, Entropy: 2.0450
# best score so far: 5.51075
# -----------------------------------
# Episode 53500
# serial calc_performance called
# Episode 53700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0023, Critic Loss: 0.3482, Entropy: 1.9802
# best score so far: 5.51075
# -----------------------------------
# Episode 54000
# serial calc_performance called
# Episode 54000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0025, Critic Loss: 0.3795, Entropy: 1.9436
# best score so far: 5.51075
# -----------------------------------
# serial calc_performance called
# Episode 54300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0031, Critic Loss: 0.3949, Entropy: 1.9085
# best score so far: 5.51075
# -----------------------------------
# Episode 54500
# serial calc_performance called
# Episode 54600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0013, Critic Loss: 0.4046, Entropy: 1.9175
# best score so far: 5.51075
# -----------------------------------
# serial calc_performance called
# Episode 54900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0026, Critic Loss: 0.3642, Entropy: 1.8822
# best score so far: 5.51376
# -----------------------------------
# Episode 55000
# serial calc_performance called
# Episode 55200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0018, Critic Loss: 0.3974, Entropy: 1.8657
# best score so far: 5.51376
# -----------------------------------
# Episode 55500
# serial calc_performance called
# Episode 55500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0022, Critic Loss: 0.3845, Entropy: 1.9011
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 55800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0026, Critic Loss: 0.3903, Entropy: 1.9007
# best score so far: 5.53217
# -----------------------------------
# Episode 56000
# serial calc_performance called
# Episode 56100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0020, Critic Loss: 0.3708, Entropy: 1.8503
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 56400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0042, Critic Loss: 0.3697, Entropy: 1.8479
# best score so far: 5.53217
# -----------------------------------
# Episode 56500
# serial calc_performance called
# Episode 56700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0028, Critic Loss: 0.3836, Entropy: 1.8570
# best score so far: 5.53217
# -----------------------------------
# Episode 57000
# serial calc_performance called
# Episode 57000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0036, Critic Loss: 0.3617, Entropy: 1.8734
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 57300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0021, Critic Loss: 0.3785, Entropy: 1.8128
# best score so far: 5.53217
# -----------------------------------
# Episode 57500
# serial calc_performance called
# Episode 57600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0018, Critic Loss: 0.3393, Entropy: 1.8505
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 57900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0031, Critic Loss: 0.3637, Entropy: 1.7851
# best score so far: 5.53217
# -----------------------------------
# Episode 58000
# serial calc_performance called
# Episode 58200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0022, Critic Loss: 0.3717, Entropy: 1.8133
# best score so far: 5.53217
# -----------------------------------
# Episode 58500
# serial calc_performance called
# Episode 58500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0018, Critic Loss: 0.3197, Entropy: 1.7255
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 58800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0051, Critic Loss: 0.3871, Entropy: 1.7098
# best score so far: 5.53217
# -----------------------------------
# Episode 59000
# serial calc_performance called
# Episode 59100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0012, Critic Loss: 0.4345, Entropy: 1.7268
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 59400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0025, Critic Loss: 0.3689, Entropy: 1.7299
# best score so far: 5.53217
# -----------------------------------
# Episode 59500
# serial calc_performance called
# Episode 59700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0018, Critic Loss: 0.3683, Entropy: 1.7310
# best score so far: 5.53217
# -----------------------------------
# Episode 60000
# serial calc_performance called
# Episode 60000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0015, Critic Loss: 0.4174, Entropy: 1.7184
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 60300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.37
# Actor Loss: -0.0013, Critic Loss: 0.3505, Entropy: 1.7636
# best score so far: 5.53217
# -----------------------------------
# Episode 60500
# serial calc_performance called
# Episode 60600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.34
# Actor Loss: -0.0027, Critic Loss: 0.3912, Entropy: 1.7068
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 60900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.39
# Actor Loss: -0.0012, Critic Loss: 0.3052, Entropy: 1.6857
# best score so far: 5.53217
# -----------------------------------
# Episode 61000
# serial calc_performance called
# Episode 61200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.34
# Actor Loss: -0.0019, Critic Loss: 0.3839, Entropy: 1.7195
# best score so far: 5.53217
# -----------------------------------
# Episode 61500
# serial calc_performance called
# Episode 61500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0013, Critic Loss: 0.4076, Entropy: 1.6778
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 61800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0011, Critic Loss: 0.3989, Entropy: 1.6914
# best score so far: 5.53217
# -----------------------------------
# Episode 62000
# serial calc_performance called
# Episode 62100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0015, Critic Loss: 0.4300, Entropy: 1.6620
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 62400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0018, Critic Loss: 0.3561, Entropy: 1.6332
# best score so far: 5.53217
# -----------------------------------
# Episode 62500
# serial calc_performance called
# Episode 62700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0022, Critic Loss: 0.3585, Entropy: 1.6736
# best score so far: 5.53217
# -----------------------------------
# Episode 63000
# serial calc_performance called
# Episode 63000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0012, Critic Loss: 0.3745, Entropy: 1.6480
# best score so far: 5.53217
# -----------------------------------
# serial calc_performance called
# Episode 63300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.53
# Actor Loss: -0.0012, Critic Loss: 0.3809, Entropy: 1.6655
# best score so far: 5.53482
# -----------------------------------
# Episode 63500
# serial calc_performance called
# Episode 63600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0007, Critic Loss: 0.3723, Entropy: 1.6640
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 63900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0018, Critic Loss: 0.3464, Entropy: 1.6629
# best score so far: 5.53482
# -----------------------------------
# Episode 64000
# serial calc_performance called
# Episode 64200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.36
# Actor Loss: -0.0021, Critic Loss: 0.2942, Entropy: 1.6747
# best score so far: 5.53482
# -----------------------------------
# Episode 64500
# serial calc_performance called
# Episode 64500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0018, Critic Loss: 0.3257, Entropy: 1.6667
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 64800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.38
# Actor Loss: -0.0032, Critic Loss: 0.3236, Entropy: 1.6899
# best score so far: 5.53482
# -----------------------------------
# Episode 65000
# serial calc_performance called
# Episode 65100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.38
# Actor Loss: -0.0025, Critic Loss: 0.3731, Entropy: 1.6583
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 65400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0013, Critic Loss: 0.3304, Entropy: 1.6409
# best score so far: 5.53482
# -----------------------------------
# Episode 65500
# serial calc_performance called
# Episode 65700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0018, Critic Loss: 0.3867, Entropy: 1.6708
# best score so far: 5.53482
# -----------------------------------
# Episode 66000
# serial calc_performance called
# Episode 66000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0017, Critic Loss: 0.3263, Entropy: 1.6514
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 66300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0011, Critic Loss: 0.3676, Entropy: 1.6212
# best score so far: 5.53482
# -----------------------------------
# Episode 66500
# serial calc_performance called
# Episode 66600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0024, Critic Loss: 0.3552, Entropy: 1.5962
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 66900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0020, Critic Loss: 0.4294, Entropy: 1.5824
# best score so far: 5.53482
# -----------------------------------
# Episode 67000
# serial calc_performance called
# Episode 67200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0014, Critic Loss: 0.3369, Entropy: 1.5544
# best score so far: 5.53482
# -----------------------------------
# Episode 67500
# serial calc_performance called
# Episode 67500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0009, Critic Loss: 0.4112, Entropy: 1.5990
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 67800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0011, Critic Loss: 0.3817, Entropy: 1.5594
# best score so far: 5.53482
# -----------------------------------
# Episode 68000
# serial calc_performance called
# Episode 68100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.37
# Actor Loss: -0.0018, Critic Loss: 0.3633, Entropy: 1.5896
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 68400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0029, Critic Loss: 0.3619, Entropy: 1.5549
# best score so far: 5.53482
# -----------------------------------
# Episode 68500
# serial calc_performance called
# Episode 68700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0015, Critic Loss: 0.3282, Entropy: 1.5231
# best score so far: 5.53482
# -----------------------------------
# Episode 69000
# serial calc_performance called
# Episode 69000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.33
# Actor Loss: -0.0013, Critic Loss: 0.3827, Entropy: 1.5429
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 69300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0014, Critic Loss: 0.3536, Entropy: 1.5880
# best score so far: 5.53482
# -----------------------------------
# Episode 69500
# serial calc_performance called
# Episode 69600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0010, Critic Loss: 0.3841, Entropy: 1.5677
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 69900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0016, Critic Loss: 0.3273, Entropy: 1.5463
# best score so far: 5.53482
# -----------------------------------
# Episode 70000
# serial calc_performance called
# Episode 70200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.51
# Actor Loss: -0.0020, Critic Loss: 0.3205, Entropy: 1.5858
# best score so far: 5.53482
# -----------------------------------
# Episode 70500
# serial calc_performance called
# Episode 70500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.36
# Actor Loss: -0.0034, Critic Loss: 0.3921, Entropy: 1.5889
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 70800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.30
# Actor Loss: -0.0018, Critic Loss: 0.3346, Entropy: 1.6190
# best score so far: 5.53482
# -----------------------------------
# Episode 71000
# serial calc_performance called
# Episode 71100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0006, Critic Loss: 0.3661, Entropy: 1.6115
# best score so far: 5.53482
# -----------------------------------
# serial calc_performance called
# Episode 71400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0020, Critic Loss: 0.3717, Entropy: 1.5721
# best score so far: 5.53482
# -----------------------------------
# Episode 71500
# serial calc_performance called
# Episode 71700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0023, Critic Loss: 0.3536, Entropy: 1.5673
# best score so far: 5.53482
# -----------------------------------
# Episode 72000
# serial calc_performance called
# Episode 72000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0022, Critic Loss: 0.3741, Entropy: 1.5106
# best score so far: 5.53482
# -----------------------------------
# ...
# -----------------------------------
# Episode 62500
# serial calc_performance called
# Episode 62700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0027, Critic Loss: 0.4168, Entropy: 2.0114
# best score so far: 5.61286
# -----------------------------------
# Episode 63000
# serial calc_performance called
# Episode 63000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0022, Critic Loss: 0.4139, Entropy: 1.9942
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 63300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0022, Critic Loss: 0.3857, Entropy: 2.0219
# best score so far: 5.61286
# -----------------------------------
# Episode 63500
# serial calc_performance called
# Episode 63600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0012, Critic Loss: 0.3694, Entropy: 1.9415
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 63900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0023, Critic Loss: 0.4054, Entropy: 1.9606
# best score so far: 5.61286
# -----------------------------------
# Episode 64000
# serial calc_performance called
# Episode 64200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0020, Critic Loss: 0.3432, Entropy: 1.9798
# best score so far: 5.61286
# -----------------------------------
# Episode 64500
# serial calc_performance called
# Episode 64500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.53
# Actor Loss: -0.0015, Critic Loss: 0.3395, Entropy: 2.0106
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 64800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0022, Critic Loss: 0.3920, Entropy: 1.9608
# best score so far: 5.61286
# -----------------------------------
# Episode 65000
# serial calc_performance called
# Episode 65100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0010, Critic Loss: 0.4240, Entropy: 1.9891
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 65400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0020, Critic Loss: 0.4932, Entropy: 2.0042
# best score so far: 5.61286
# -----------------------------------
# Episode 65500
# serial calc_performance called
# Episode 65700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.52
# Actor Loss: -0.0029, Critic Loss: 0.4075, Entropy: 2.0166
# best score so far: 5.61286
# -----------------------------------
# Episode 66000
# serial calc_performance called
# Episode 66000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0027, Critic Loss: 0.4027, Entropy: 1.9458
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 66300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0030, Critic Loss: 0.4138, Entropy: 1.9053
# best score so far: 5.61286
# -----------------------------------
# Episode 66500
# serial calc_performance called
# Episode 66600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0029, Critic Loss: 0.3752, Entropy: 1.9656
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 66900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.52
# Actor Loss: -0.0024, Critic Loss: 0.3211, Entropy: 1.9156
# best score so far: 5.61286
# -----------------------------------
# Episode 67000
# serial calc_performance called
# Episode 67200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0019, Critic Loss: 0.3795, Entropy: 1.9054
# best score so far: 5.61286
# -----------------------------------
# Episode 67500
# serial calc_performance called
# Episode 67500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0033, Critic Loss: 0.3781, Entropy: 1.9189
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 67800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0015, Critic Loss: 0.3680, Entropy: 1.9004
# best score so far: 5.61286
# -----------------------------------
# Episode 68000
# serial calc_performance called
# Episode 68100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0036, Critic Loss: 0.3626, Entropy: 1.9496
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 68400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0030, Critic Loss: 0.3621, Entropy: 1.9485
# best score so far: 5.61286
# -----------------------------------
# Episode 68500
# serial calc_performance called
# Episode 68700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0031, Critic Loss: 0.3650, Entropy: 1.8926
# best score so far: 5.61286
# -----------------------------------
# Episode 69000
# serial calc_performance called
# Episode 69000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0020, Critic Loss: 0.3532, Entropy: 1.9204
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 69300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.39
# Actor Loss: -0.0027, Critic Loss: 0.3580, Entropy: 1.9125
# best score so far: 5.61286
# -----------------------------------
# Episode 69500
# serial calc_performance called
# Episode 69600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.51
# Actor Loss: -0.0017, Critic Loss: 0.3650, Entropy: 1.8681
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 69900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0024, Critic Loss: 0.3738, Entropy: 1.8779
# best score so far: 5.61286
# -----------------------------------
# Episode 70000
# serial calc_performance called
# Episode 70200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0011, Critic Loss: 0.3767, Entropy: 1.8853
# best score so far: 5.61286
# -----------------------------------
# Episode 70500
# serial calc_performance called
# Episode 70500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0022, Critic Loss: 0.3909, Entropy: 1.8684
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 70800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0017, Critic Loss: 0.3251, Entropy: 1.8620
# best score so far: 5.61286
# -----------------------------------
# Episode 71000
# serial calc_performance called
# Episode 71100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0019, Critic Loss: 0.3846, Entropy: 1.8943
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 71400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0019, Critic Loss: 0.4380, Entropy: 1.8551
# best score so far: 5.61286
# -----------------------------------
# Episode 71500
# serial calc_performance called
# Episode 71700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.51
# Actor Loss: -0.0014, Critic Loss: 0.4215, Entropy: 1.8621
# best score so far: 5.61286
# -----------------------------------
# Episode 72000
# serial calc_performance called
# Episode 72000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0023, Critic Loss: 0.3916, Entropy: 1.9197
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 72300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0024, Critic Loss: 0.4017, Entropy: 1.8418
# best score so far: 5.61286
# -----------------------------------
# Episode 72500
# serial calc_performance called
# Episode 72600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0023, Critic Loss: 0.4501, Entropy: 1.8562
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 72900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0025, Critic Loss: 0.3951, Entropy: 1.8169
# best score so far: 5.61286
# -----------------------------------
# Episode 73000
# serial calc_performance called
# Episode 73200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0033, Critic Loss: 0.3972, Entropy: 1.8211
# best score so far: 5.61286
# -----------------------------------
# Episode 73500
# serial calc_performance called
# Episode 73500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.52
# Actor Loss: -0.0030, Critic Loss: 0.3530, Entropy: 1.8114
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 73800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0035, Critic Loss: 0.3374, Entropy: 1.8672
# best score so far: 5.61286
# -----------------------------------
# Episode 74000
# serial calc_performance called
# Episode 74100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0021, Critic Loss: 0.3909, Entropy: 1.8693
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 74400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0024, Critic Loss: 0.4009, Entropy: 1.8868
# best score so far: 5.61286
# -----------------------------------
# Episode 74500
# serial calc_performance called
# Episode 74700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0019, Critic Loss: 0.3352, Entropy: 1.8223
# best score so far: 5.61286
# -----------------------------------
# Episode 75000
# serial calc_performance called
# Episode 75000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0026, Critic Loss: 0.4337, Entropy: 1.7939
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 75300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0031, Critic Loss: 0.3708, Entropy: 1.7834
# best score so far: 5.61286
# -----------------------------------
# Episode 75500
# serial calc_performance called
# Episode 75600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0028, Critic Loss: 0.3569, Entropy: 1.8091
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 75900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0021, Critic Loss: 0.3921, Entropy: 1.8301
# best score so far: 5.61286
# -----------------------------------
# Episode 76000
# serial calc_performance called
# Episode 76200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0020, Critic Loss: 0.3813, Entropy: 1.8309
# best score so far: 5.61286
# -----------------------------------
# Episode 76500
# serial calc_performance called
# Episode 76500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0029, Critic Loss: 0.4041, Entropy: 1.8759
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 76800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0018, Critic Loss: 0.4405, Entropy: 1.7952
# best score so far: 5.61286
# -----------------------------------
# Episode 77000
# serial calc_performance called
# Episode 77100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0034, Critic Loss: 0.3577, Entropy: 1.8155
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 77400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0028, Critic Loss: 0.3683, Entropy: 1.7842
# best score so far: 5.61286
# -----------------------------------
# Episode 77500
# serial calc_performance called
# Episode 77700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.39
# Actor Loss: -0.0034, Critic Loss: 0.3863, Entropy: 1.8219
# best score so far: 5.61286
# -----------------------------------
# Episode 78000
# serial calc_performance called
# Episode 78000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0029, Critic Loss: 0.3720, Entropy: 1.8232
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 78300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.39
# Actor Loss: -0.0019, Critic Loss: 0.3346, Entropy: 1.8137
# best score so far: 5.61286
# -----------------------------------
# Episode 78500
# serial calc_performance called
# Episode 78600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.54
# Actor Loss: -0.0022, Critic Loss: 0.3920, Entropy: 1.8951
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 78900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.36
# Actor Loss: -0.0015, Critic Loss: 0.3712, Entropy: 1.8633
# best score so far: 5.61286
# -----------------------------------
# Episode 79000
# serial calc_performance called
# Episode 79200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0024, Critic Loss: 0.3878, Entropy: 1.8599
# best score so far: 5.61286
# -----------------------------------
# Episode 79500
# serial calc_performance called
# Episode 79500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0025, Critic Loss: 0.3726, Entropy: 1.8469
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 79800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0023, Critic Loss: 0.3941, Entropy: 1.7994
# best score so far: 5.61286
# -----------------------------------
# Episode 80000
# serial calc_performance called
# Episode 80100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.56
# Actor Loss: -0.0020, Critic Loss: 0.3923, Entropy: 1.7747
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 80400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0023, Critic Loss: 0.3908, Entropy: 1.7742
# best score so far: 5.61286
# -----------------------------------
# Episode 80500
# serial calc_performance called
# Episode 80700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.54
# Actor Loss: -0.0015, Critic Loss: 0.3821, Entropy: 1.7939
# best score so far: 5.61286
# -----------------------------------
# Episode 81000
# serial calc_performance called
# Episode 81000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.52
# Actor Loss: -0.0016, Critic Loss: 0.4000, Entropy: 1.8262
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 81300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0017, Critic Loss: 0.3980, Entropy: 1.8060
# best score so far: 5.61286
# -----------------------------------
# Episode 81500
# serial calc_performance called
# Episode 81600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.52
# Actor Loss: -0.0028, Critic Loss: 0.3505, Entropy: 1.8196
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 81900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0020, Critic Loss: 0.3513, Entropy: 1.8292
# best score so far: 5.61286
# -----------------------------------
# Episode 82000
# serial calc_performance called
# Episode 82200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0017, Critic Loss: 0.3344, Entropy: 1.8671
# best score so far: 5.61286
# -----------------------------------
# Episode 82500
# serial calc_performance called
# Episode 82500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0025, Critic Loss: 0.3614, Entropy: 1.8642
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 82800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.53
# Actor Loss: -0.0022, Critic Loss: 0.3761, Entropy: 1.8572
# best score so far: 5.61286
# -----------------------------------
# Episode 83000
# serial calc_performance called
# Episode 83100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0022, Critic Loss: 0.4260, Entropy: 1.9003
# best score so far: 5.61286
# -----------------------------------
# serial calc_performance called
# Episode 83400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0022, Critic Loss: 0.4026, Entropy: 1.8788
# best score so far: 5.61286
# -----------------------------------
# Episode 83500
# serial calc_performance called
# Episode 83700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.43
# Actor Loss: -0.0021, Critic Loss: 0.4132, Entropy: 1.8563
# best score so far: 5.61286
# -----------------------------------
# Episode 84000
# serial calc_performance called
# Episode 84000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0024, Critic Loss: 0.3718, Entropy: 1.8784
# best score so far: 5.61286
# -----------------------------------
