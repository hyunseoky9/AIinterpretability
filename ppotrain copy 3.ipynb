# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 34 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1 
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 34, iteration: 0, seed: 252358
# env: metapop1
# device: cpu
# state size: (np.int64(20), np.int64(4)), action size: 40
# actor: hidden num: 2, hidden size: [128, 128]
# critic: hidden num: 2, hidden size: [512, 512]
# encoder: hidden num: 2, hidden size: [256, 256], encoder output size: 256
# actor lr: 0.0001, critic lr: 0.0001, encoder lr: 0.0001
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 4096, minibatch size: 128, n_epochs: 10
# evaluation interval: 300, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 100000
# -------------------------------------------------------
# --------------------------------------------------------
# Episode 500
# Episode 1000
# Episode 1500
# Episode 2000
# Episode 2500
# Episode 3000
# Episode 3500
# Episode 4000
# Episode 4500
# Episode 5000
# Episode 5500
# Episode 6000
# Episode 6500
# Episode 7000
# Episode 7500
# Episode 8000
# Episode 8500
# Episode 9000
# Episode 9500
# Episode 10000
# serial calc_performance called
# Episode 10200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.45
# Actor Loss: -0.0046, Critic Loss: 0.3163, Entropy: 9.0246
# best score so far: 4.44546
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.43
# Actor Loss: -0.0050, Critic Loss: 0.3786, Entropy: 8.8950
# best score so far: 4.44546
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.53
# Actor Loss: -0.0083, Critic Loss: 0.3766, Entropy: 8.8435
# best score so far: 4.53162
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.58
# Actor Loss: -0.0054, Critic Loss: 0.4247, Entropy: 8.5850
# best score so far: 4.58305
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.62
# Actor Loss: -0.0043, Critic Loss: 0.4328, Entropy: 8.5600
# best score so far: 4.61798
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.67
# Actor Loss: -0.0054, Critic Loss: 0.3153, Entropy: 8.3064
# best score so far: 4.67032
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.71
# Actor Loss: -0.0040, Critic Loss: 0.3968, Entropy: 8.1018
# best score so far: 4.70664
# -----------------------------------
# serial calc_performance called
# Episode 12300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.75
# Actor Loss: -0.0041, Critic Loss: 0.3464, Entropy: 7.8679
# best score so far: 4.75254
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.82
# Actor Loss: -0.0046, Critic Loss: 0.3713, Entropy: 7.8890
# best score so far: 4.81523
# -----------------------------------
# serial calc_performance called
# Episode 12900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.83
# Actor Loss: -0.0059, Critic Loss: 0.3497, Entropy: 7.7482
# best score so far: 4.82526
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.72
# Actor Loss: -0.0021, Critic Loss: 0.3263, Entropy: 7.5842
# best score so far: 4.82526
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.87
# Actor Loss: -0.0060, Critic Loss: 0.3506, Entropy: 7.5557
# best score so far: 4.86995
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.76
# Actor Loss: -0.0018, Critic Loss: 0.3449, Entropy: 7.5494
# best score so far: 4.86995
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.92
# Actor Loss: -0.0027, Critic Loss: 0.3841, Entropy: 7.4268
# best score so far: 4.91697
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.89
# Actor Loss: -0.0058, Critic Loss: 0.4182, Entropy: 7.1217
# best score so far: 4.91697
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.91
# Actor Loss: -0.0046, Critic Loss: 0.3650, Entropy: 7.1352
# best score so far: 4.91697
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.97
# Actor Loss: -0.0082, Critic Loss: 0.3433, Entropy: 7.1285
# best score so far: 4.96974
# -----------------------------------
# serial calc_performance called
# Episode 15300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.98
# Actor Loss: -0.0046, Critic Loss: 0.4563, Entropy: 6.9334
# best score so far: 4.97556
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.05
# Actor Loss: -0.0077, Critic Loss: 0.4421, Entropy: 6.7973
# best score so far: 5.04875
# -----------------------------------
# serial calc_performance called
# Episode 15900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.02
# Actor Loss: -0.0042, Critic Loss: 0.3925, Entropy: 6.6327
# best score so far: 5.04875
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.11
# Actor Loss: -0.0046, Critic Loss: 0.3644, Entropy: 6.3237
# best score so far: 5.11136
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.10
# Actor Loss: -0.0050, Critic Loss: 0.3486, Entropy: 6.2900
# best score so far: 5.11136
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.10
# Actor Loss: -0.0051, Critic Loss: 0.3703, Entropy: 6.3217
# best score so far: 5.11136
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.14
# Actor Loss: -0.0047, Critic Loss: 0.3807, Entropy: 6.3875
# best score so far: 5.13504
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.13
# Actor Loss: -0.0063, Critic Loss: 0.4472, Entropy: 6.2693
# best score so far: 5.13504
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.11
# Actor Loss: -0.0048, Critic Loss: 0.3657, Entropy: 6.1946
# best score so far: 5.13504
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.12
# Actor Loss: -0.0074, Critic Loss: 0.4580, Entropy: 6.1852
# best score so far: 5.13504
# -----------------------------------
# serial calc_performance called
# Episode 18300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.22
# Actor Loss: -0.0034, Critic Loss: 0.3735, Entropy: 6.0634
# best score so far: 5.22218
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.18
# Actor Loss: -0.0044, Critic Loss: 0.4036, Entropy: 6.1713
# best score so far: 5.22218
# -----------------------------------
# serial calc_performance called
# Episode 18900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.23
# Actor Loss: -0.0053, Critic Loss: 0.4103, Entropy: 6.0064
# best score so far: 5.23338
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.20
# Actor Loss: -0.0031, Critic Loss: 0.3970, Entropy: 6.0079
# best score so far: 5.23338
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.19
# Actor Loss: -0.0065, Critic Loss: 0.3468, Entropy: 5.8071
# best score so far: 5.23338
# -----------------------------------
# serial calc_performance called
# Episode 19800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.22
# Actor Loss: -0.0051, Critic Loss: 0.4152, Entropy: 5.8596
# best score so far: 5.23338
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.25
# Actor Loss: -0.0046, Critic Loss: 0.3705, Entropy: 5.8499
# best score so far: 5.25136
# -----------------------------------
# serial calc_performance called
# Episode 20400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.26
# Actor Loss: -0.0057, Critic Loss: 0.3612, Entropy: 5.7079
# best score so far: 5.25852
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.18
# Actor Loss: -0.0057, Critic Loss: 0.4064, Entropy: 5.8179
# best score so far: 5.25852
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0032, Critic Loss: 0.4387, Entropy: 5.6368
# best score so far: 5.36724
# -----------------------------------
# serial calc_performance called
# Episode 21300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.22
# Actor Loss: -0.0030, Critic Loss: 0.4034, Entropy: 5.5670
# best score so far: 5.36724
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0042, Critic Loss: 0.3849, Entropy: 5.4919
# best score so far: 5.36724
# -----------------------------------
# serial calc_performance called
# Episode 21900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0050, Critic Loss: 0.4270, Entropy: 5.3789
# best score so far: 5.36724
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0038, Critic Loss: 0.3670, Entropy: 5.3546
# best score so far: 5.36724
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.32
# Actor Loss: -0.0048, Critic Loss: 0.4690, Entropy: 5.3139
# best score so far: 5.36724
# -----------------------------------
# serial calc_performance called
# Episode 22800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0045, Critic Loss: 0.4638, Entropy: 5.2259
# best score so far: 5.36724
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0037, Critic Loss: 0.4353, Entropy: 5.1370
# best score so far: 5.36724
# -----------------------------------
# serial calc_performance called
# Episode 23400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0027, Critic Loss: 0.4333, Entropy: 5.0595
# best score so far: 5.36724
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.32
# Actor Loss: -0.0040, Critic Loss: 0.3496, Entropy: 5.0648
# best score so far: 5.36724
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0051, Critic Loss: 0.4241, Entropy: 5.0575
# best score so far: 5.43645
# -----------------------------------
# serial calc_performance called
# Episode 24300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0029, Critic Loss: 0.3975, Entropy: 4.8763
# best score so far: 5.43645
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0038, Critic Loss: 0.4414, Entropy: 5.0483
# best score so far: 5.43645
# -----------------------------------
# serial calc_performance called
# Episode 24900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0060, Critic Loss: 0.4523, Entropy: 4.9399
# best score so far: 5.43645
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0038, Critic Loss: 0.4313, Entropy: 4.8847
# best score so far: 5.45094
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0033, Critic Loss: 0.4146, Entropy: 4.7903
# best score so far: 5.45962
# -----------------------------------
# serial calc_performance called
# Episode 25800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0028, Critic Loss: 0.4511, Entropy: 4.6169
# best score so far: 5.47020
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0025, Critic Loss: 0.3784, Entropy: 4.4509
# best score so far: 5.47020
# -----------------------------------
# serial calc_performance called
# Episode 26400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0046, Critic Loss: 0.3673, Entropy: 4.4126
# best score so far: 5.47020
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0028, Critic Loss: 0.4508, Entropy: 4.4587
# best score so far: 5.47020
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0020, Critic Loss: 0.3684, Entropy: 4.3262
# best score so far: 5.47020
# -----------------------------------
# serial calc_performance called
# Episode 27300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0040, Critic Loss: 0.4132, Entropy: 4.3744
# best score so far: 5.47020
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0024, Critic Loss: 0.3604, Entropy: 4.3609
# best score so far: 5.51378
# -----------------------------------
# serial calc_performance called
# Episode 27900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0018, Critic Loss: 0.3827, Entropy: 4.2339
# best score so far: 5.51378
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0036, Critic Loss: 0.3678, Entropy: 4.3476
# best score so far: 5.51378
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0027, Critic Loss: 0.3833, Entropy: 4.2915
# best score so far: 5.51378
# -----------------------------------
# serial calc_performance called
# Episode 28800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0030, Critic Loss: 0.3809, Entropy: 4.2466
# best score so far: 5.51378
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0033, Critic Loss: 0.3983, Entropy: 4.3269
# best score so far: 5.51378
# -----------------------------------
# serial calc_performance called
# Episode 29400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0034, Critic Loss: 0.4583, Entropy: 4.1754
# best score so far: 5.51378
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0038, Critic Loss: 0.4490, Entropy: 4.2168
# best score so far: 5.51858
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0035, Critic Loss: 0.3915, Entropy: 4.1339
# best score so far: 5.51858
# -----------------------------------
# serial calc_performance called
# Episode 30300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0034, Critic Loss: 0.4433, Entropy: 4.1687
# best score so far: 5.51858
# -----------------------------------
# Episode 30500
# serial calc_performance called
# Episode 30600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0032, Critic Loss: 0.3872, Entropy: 4.0693
# best score so far: 5.55864
# -----------------------------------
# serial calc_performance called
# Episode 30900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0037, Critic Loss: 0.3425, Entropy: 4.2285
# best score so far: 5.55864
# -----------------------------------
# Episode 31000
# serial calc_performance called
# Episode 31200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0036, Critic Loss: 0.3446, Entropy: 4.1964
# best score so far: 5.55864
# -----------------------------------
# Episode 31500
# serial calc_performance called
# Episode 31500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0053, Critic Loss: 0.4050, Entropy: 4.1514
# best score so far: 5.55864
# -----------------------------------
# serial calc_performance called
# Episode 31800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0041, Critic Loss: 0.4091, Entropy: 4.1736
# best score so far: 5.55864
# -----------------------------------
# Episode 32000
# serial calc_performance called
# Episode 32100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0036, Critic Loss: 0.4287, Entropy: 4.0747
# best score so far: 5.55864
# -----------------------------------
# serial calc_performance called
# Episode 32400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0033, Critic Loss: 0.3892, Entropy: 4.1444
# best score so far: 5.55864
# -----------------------------------
# Episode 32500
# serial calc_performance called
# Episode 32700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0029, Critic Loss: 0.3739, Entropy: 4.0239
# best score so far: 5.55888
# -----------------------------------
# Episode 33000
# serial calc_performance called
# Episode 33000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0024, Critic Loss: 0.3699, Entropy: 3.9308
# best score so far: 5.55888
# -----------------------------------
# serial calc_performance called
# Episode 33300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0030, Critic Loss: 0.3630, Entropy: 3.8951
# best score so far: 5.55888
# -----------------------------------
# Episode 33500
# serial calc_performance called
# Episode 33600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0031, Critic Loss: 0.3803, Entropy: 3.8579
# best score so far: 5.58787
# -----------------------------------
# serial calc_performance called
# Episode 33900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0022, Critic Loss: 0.3586, Entropy: 3.7104
# best score so far: 5.58787
# -----------------------------------
# Episode 34000
# serial calc_performance called
# Episode 34200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0051, Critic Loss: 0.3848, Entropy: 3.7005
# best score so far: 5.60193
# -----------------------------------
# Episode 34500
# serial calc_performance called
# Episode 34500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0024, Critic Loss: 0.3779, Entropy: 3.6202
# best score so far: 5.60193
# -----------------------------------
# serial calc_performance called
# Episode 34800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0027, Critic Loss: 0.4054, Entropy: 3.4958
# best score so far: 5.60193
# -----------------------------------
# Episode 35000
# serial calc_performance called
# Episode 35100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0032, Critic Loss: 0.3836, Entropy: 3.6386
# best score so far: 5.60193
# -----------------------------------
# serial calc_performance called
# Episode 35400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.57
# Actor Loss: -0.0053, Critic Loss: 0.4019, Entropy: 3.5332
# best score so far: 5.60193
# -----------------------------------
# Episode 35500
# serial calc_performance called
# Episode 35700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0032, Critic Loss: 0.3812, Entropy: 3.5199
# best score so far: 5.60193
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0042, Critic Loss: 0.3574, Entropy: 3.5363
# best score so far: 5.60193
# -----------------------------------
# serial calc_performance called
# Episode 36300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0034, Critic Loss: 0.4194, Entropy: 3.4449
# best score so far: 5.60193
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0026, Critic Loss: 0.4045, Entropy: 3.4698
# best score so far: 5.60193
# -----------------------------------
# serial calc_performance called
# Episode 36900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0047, Critic Loss: 0.3696, Entropy: 3.4002
# best score so far: 5.64746
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0026, Critic Loss: 0.3810, Entropy: 3.4095
# best score so far: 5.64746
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0032, Critic Loss: 0.3702, Entropy: 3.3694
# best score so far: 5.64746
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0027, Critic Loss: 0.3991, Entropy: 3.3515
# best score so far: 5.64746
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0042, Critic Loss: 0.3381, Entropy: 3.2701
# best score so far: 5.64746
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.64
# Actor Loss: -0.0026, Critic Loss: 0.4269, Entropy: 3.2518
# best score so far: 5.64746
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0016, Critic Loss: 0.3596, Entropy: 3.1886
# best score so far: 5.64746
# -----------------------------------
# Episode 39000
# serial calc_performance called
# Episode 39000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0042, Critic Loss: 0.3528, Entropy: 3.1853
# best score so far: 5.64746
# -----------------------------------
# serial calc_performance called
# Episode 39300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0030, Critic Loss: 0.3837, Entropy: 3.2131
# best score so far: 5.65139
# -----------------------------------
# Episode 39500
# serial calc_performance called
# Episode 39600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0030, Critic Loss: 0.3224, Entropy: 3.1255
# best score so far: 5.65139
# -----------------------------------
# serial calc_performance called
# Episode 39900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0029, Critic Loss: 0.3852, Entropy: 3.1240
# best score so far: 5.65139
# -----------------------------------
# Episode 40000
# serial calc_performance called
# Episode 40200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0035, Critic Loss: 0.4066, Entropy: 3.0383
# best score so far: 5.65139
# -----------------------------------
# Episode 40500
# serial calc_performance called
# Episode 40500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0034, Critic Loss: 0.3626, Entropy: 3.0428
# best score so far: 5.65139
# -----------------------------------
# serial calc_performance called
# Episode 40800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0017, Critic Loss: 0.3408, Entropy: 3.0168
# best score so far: 5.66711
# -----------------------------------
# Episode 41000
# serial calc_performance called
# Episode 41100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0025, Critic Loss: 0.3514, Entropy: 3.0969
# best score so far: 5.67140
# -----------------------------------
# serial calc_performance called
# Episode 41400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0024, Critic Loss: 0.4024, Entropy: 3.0986
# best score so far: 5.67140
# -----------------------------------
# Episode 41500
# serial calc_performance called
# Episode 41700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0034, Critic Loss: 0.3658, Entropy: 3.0245
# best score so far: 5.67140
# -----------------------------------
# Episode 42000
# serial calc_performance called
# Episode 42000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0029, Critic Loss: 0.3772, Entropy: 2.9799
# best score so far: 5.67140
# -----------------------------------
# serial calc_performance called
# Episode 42300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0038, Critic Loss: 0.3591, Entropy: 2.9573
# best score so far: 5.67140
# -----------------------------------
# Episode 42500
# serial calc_performance called
# Episode 42600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0037, Critic Loss: 0.3914, Entropy: 2.9998
# best score so far: 5.67140
# -----------------------------------
# serial calc_performance called
# Episode 42900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.63
# Actor Loss: -0.0045, Critic Loss: 0.4802, Entropy: 3.0095
# best score so far: 5.67140
# -----------------------------------
# Episode 43000
# serial calc_performance called
# Episode 43200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0029, Critic Loss: 0.4295, Entropy: 3.0458
# best score so far: 5.67140
# -----------------------------------
# Episode 43500
# serial calc_performance called
# Episode 43500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0042, Critic Loss: 0.3967, Entropy: 3.0087
# best score so far: 5.67140
# -----------------------------------
# serial calc_performance called
# Episode 43800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0032, Critic Loss: 0.3551, Entropy: 2.9687
# best score so far: 5.67140
# -----------------------------------
# Episode 44000
# serial calc_performance called
# Episode 44100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.63
# Actor Loss: -0.0040, Critic Loss: 0.3808, Entropy: 3.0399
# best score so far: 5.67140
# -----------------------------------
# serial calc_performance called
# Episode 44400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0036, Critic Loss: 0.3612, Entropy: 2.9268
# best score so far: 5.67140
# -----------------------------------
# Episode 44500
# serial calc_performance called
# Episode 44700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0034, Critic Loss: 0.4389, Entropy: 2.9408
# best score so far: 5.67140
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0034, Critic Loss: 0.3601, Entropy: 2.8191
# best score so far: 5.67140
# -----------------------------------
# serial calc_performance called
# Episode 45300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0032, Critic Loss: 0.3759, Entropy: 2.8855
# best score so far: 5.67140
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.68
# Actor Loss: -0.0015, Critic Loss: 0.3825, Entropy: 2.8393
# best score so far: 5.67958
# -----------------------------------
# serial calc_performance called
# Episode 45900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.68
# Actor Loss: -0.0018, Critic Loss: 0.4107, Entropy: 2.8406
# best score so far: 5.67958
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.64
# Actor Loss: -0.0032, Critic Loss: 0.3445, Entropy: 2.7474
# best score so far: 5.67958
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0030, Critic Loss: 0.4172, Entropy: 2.7508
# best score so far: 5.67958
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0041, Critic Loss: 0.3422, Entropy: 2.7157
# best score so far: 5.67958
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.63
# Actor Loss: -0.0061, Critic Loss: 0.3593, Entropy: 2.7807
# best score so far: 5.67958
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.71
# Actor Loss: -0.0026, Critic Loss: 0.3748, Entropy: 2.7082
# best score so far: 5.71044
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.66
# Actor Loss: -0.0041, Critic Loss: 0.4137, Entropy: 2.8144
# best score so far: 5.71044
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.63
# Actor Loss: -0.0019, Critic Loss: 0.3927, Entropy: 2.7468
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 48300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0031, Critic Loss: 0.3637, Entropy: 2.8525
# best score so far: 5.71044
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.68
# Actor Loss: -0.0026, Critic Loss: 0.3872, Entropy: 2.8339
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 48900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.68
# Actor Loss: -0.0020, Critic Loss: 0.3817, Entropy: 2.7386
# best score so far: 5.71044
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.63
# Actor Loss: -0.0017, Critic Loss: 0.4120, Entropy: 2.7552
# best score so far: 5.71044
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.68
# Actor Loss: -0.0030, Critic Loss: 0.4422, Entropy: 2.7536
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0022, Critic Loss: 0.4589, Entropy: 2.8052
# best score so far: 5.71044
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.69
# Actor Loss: -0.0028, Critic Loss: 0.3975, Entropy: 2.7904
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.70
# Actor Loss: -0.0021, Critic Loss: 0.3928, Entropy: 2.6563
# best score so far: 5.71044
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0028, Critic Loss: 0.3372, Entropy: 2.7720
# best score so far: 5.71044
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.70
# Actor Loss: -0.0038, Critic Loss: 0.3734, Entropy: 2.7418
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 51300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0028, Critic Loss: 0.3909, Entropy: 2.7438
# best score so far: 5.71044
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0015, Critic Loss: 0.3550, Entropy: 2.6986
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 51900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0030, Critic Loss: 0.3838, Entropy: 2.7444
# best score so far: 5.71044
# -----------------------------------
# Episode 52000
# serial calc_performance called
# Episode 52200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0029, Critic Loss: 0.3838, Entropy: 2.6861
# best score so far: 5.71044
# -----------------------------------
# Episode 52500
# serial calc_performance called
# Episode 52500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.64
# Actor Loss: -0.0035, Critic Loss: 0.3327, Entropy: 2.6411
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 52800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.68
# Actor Loss: -0.0026, Critic Loss: 0.4146, Entropy: 2.6382
# best score so far: 5.71044
# -----------------------------------
# Episode 53000
# serial calc_performance called
# Episode 53100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.66
# Actor Loss: -0.0036, Critic Loss: 0.3929, Entropy: 2.6351
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 53400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.64
# Actor Loss: -0.0017, Critic Loss: 0.4286, Entropy: 2.6556
# best score so far: 5.71044
# -----------------------------------
# Episode 53500
# serial calc_performance called
# Episode 53700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.66
# Actor Loss: -0.0030, Critic Loss: 0.4291, Entropy: 2.5961
# best score so far: 5.71044
# -----------------------------------
# Episode 54000
# serial calc_performance called
# Episode 54000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.70
# Actor Loss: -0.0031, Critic Loss: 0.4411, Entropy: 2.6523
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 54300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.64
# Actor Loss: -0.0052, Critic Loss: 0.3403, Entropy: 2.6035
# best score so far: 5.71044
# -----------------------------------
# Episode 54500
# serial calc_performance called
# Episode 54600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.63
# Actor Loss: -0.0032, Critic Loss: 0.3608, Entropy: 2.6152
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 54900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0032, Critic Loss: 0.3742, Entropy: 2.5420
# best score so far: 5.71044
# -----------------------------------
# Episode 55000
# serial calc_performance called
# Episode 55200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0026, Critic Loss: 0.3467, Entropy: 2.5294
# best score so far: 5.71044
# -----------------------------------
# Episode 55500
# serial calc_performance called
# Episode 55500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0038, Critic Loss: 0.3847, Entropy: 2.6501
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 55800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0025, Critic Loss: 0.4236, Entropy: 2.5562
# best score so far: 5.71044
# -----------------------------------
# Episode 56000
# serial calc_performance called
# Episode 56100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0031, Critic Loss: 0.3989, Entropy: 2.6093
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 56400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0019, Critic Loss: 0.3568, Entropy: 2.5507
# best score so far: 5.71044
# -----------------------------------
# Episode 56500
# serial calc_performance called
# Episode 56700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.70
# Actor Loss: -0.0030, Critic Loss: 0.4067, Entropy: 2.4688
# best score so far: 5.71044
# -----------------------------------
# Episode 57000
# serial calc_performance called
# Episode 57000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0028, Critic Loss: 0.3940, Entropy: 2.4189
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 57300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.64
# Actor Loss: -0.0036, Critic Loss: 0.3775, Entropy: 2.4938
# best score so far: 5.71044
# -----------------------------------
# Episode 57500
# serial calc_performance called
# Episode 57600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0016, Critic Loss: 0.3770, Entropy: 2.4771
# best score so far: 5.71044
# -----------------------------------
# serial calc_performance called
# Episode 57900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.67
# Actor Loss: -0.0041, Critic Loss: 0.3575, Entropy: 2.5312
# best score so far: 5.71044
# -----------------------------------
# Episode 58000
# serial calc_performance called
# Episode 58200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0032, Critic Loss: 0.4658, Entropy: 2.5053
# best score so far: 5.71044
# -----------------------------------
# Episode 58500
# serial calc_performance called
# Episode 58500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0024, Critic Loss: 0.3954, Entropy: 2.4893
# best score so far: 5.71044
# -----------------------------------
