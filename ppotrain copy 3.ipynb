# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 35 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1 
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 35, iteration: 0, seed: 945378
# env: metapop1
# device: cpu
# state size: (np.int64(10), np.int64(4)), action size: 20
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [256, 256]
# encoder: hidden num: 2, hidden size: [128, 128], encoder output size: 128
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 2048, minibatch size: 64, n_epochs: 10
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 100000
# -------------------------------------------------------
# --------------------------------------------------------
# Episode 500
# Episode 1000
# Episode 1500
# Episode 2000
# Episode 2500
# Episode 3000
# Episode 3500
# Episode 4000
# Episode 4500
# Episode 5000
# Episode 5500
# Episode 6000
# Episode 6500
# Episode 7000
# Episode 7500
# Episode 8000
# Episode 8500
# Episode 9000
# Episode 9500
# Episode 10000
# serial calc_performance called
# Episode 10000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0129, Critic Loss: 0.7698, Entropy: 1.8807
# best score so far: 5.54042
# -----------------------------------
# serial calc_performance called
# Episode 10200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0147, Critic Loss: 0.6658, Entropy: 1.8453
# best score so far: 5.54565
# -----------------------------------
# serial calc_performance called
# Episode 10400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0105, Critic Loss: 0.7047, Entropy: 1.7458
# best score so far: 5.63924
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0130, Critic Loss: 0.8164, Entropy: 1.6937
# best score so far: 5.63924
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0122, Critic Loss: 0.7215, Entropy: 1.7191
# best score so far: 5.63924
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0092, Critic Loss: 0.6494, Entropy: 1.7033
# best score so far: 5.63924
# -----------------------------------
# serial calc_performance called
# Episode 11200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0117, Critic Loss: 0.7523, Entropy: 1.6436
# best score so far: 5.63924
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0127, Critic Loss: 0.6558, Entropy: 1.6609
# best score so far: 5.63924
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0129, Critic Loss: 0.6484, Entropy: 1.5806
# best score so far: 5.63924
# -----------------------------------
# serial calc_performance called
# Episode 11800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0139, Critic Loss: 0.8972, Entropy: 1.5561
# best score so far: 5.76319
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0110, Critic Loss: 0.8385, Entropy: 1.4449
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 12200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.49
# Actor Loss: -0.0137, Critic Loss: 0.7413, Entropy: 1.4498
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 12400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0131, Critic Loss: 0.6106, Entropy: 1.3846
# best score so far: 5.76319
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.73
# Actor Loss: -0.0125, Critic Loss: 0.7240, Entropy: 1.3138
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 12800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.66
# Actor Loss: -0.0117, Critic Loss: 0.6737, Entropy: 1.2464
# best score so far: 5.76319
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.71
# Actor Loss: -0.0116, Critic Loss: 0.6924, Entropy: 1.2352
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 13200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.73
# Actor Loss: -0.0139, Critic Loss: 0.7633, Entropy: 1.2039
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 13400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0097, Critic Loss: 0.7312, Entropy: 1.2154
# best score so far: 5.76319
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.71
# Actor Loss: -0.0121, Critic Loss: 0.7525, Entropy: 1.1733
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0113, Critic Loss: 0.6819, Entropy: 1.1753
# best score so far: 5.76319
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0147, Critic Loss: 0.7454, Entropy: 1.2793
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 14200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.69
# Actor Loss: -0.0099, Critic Loss: 0.6147, Entropy: 1.1463
# best score so far: 5.76319
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0103, Critic Loss: 0.7791, Entropy: 1.1462
# best score so far: 5.76721
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.74
# Actor Loss: -0.0082, Critic Loss: 0.6418, Entropy: 1.1824
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 14800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.67
# Actor Loss: -0.0142, Critic Loss: 0.7167, Entropy: 1.0710
# best score so far: 5.76721
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0093, Critic Loss: 0.7866, Entropy: 1.0114
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 15200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0087, Critic Loss: 0.6602, Entropy: 0.9543
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 15400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0110, Critic Loss: 0.7303, Entropy: 0.9584
# best score so far: 5.76721
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0134, Critic Loss: 0.6377, Entropy: 0.9572
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 15800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0116, Critic Loss: 0.6790, Entropy: 0.9406
# best score so far: 5.76721
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0102, Critic Loss: 0.6757, Entropy: 0.9907
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 16200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0133, Critic Loss: 0.7248, Entropy: 1.0274
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 16400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0106, Critic Loss: 0.8692, Entropy: 0.9790
# best score so far: 5.76721
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0116, Critic Loss: 0.7015, Entropy: 1.0009
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0113, Critic Loss: 0.7257, Entropy: 1.0365
# best score so far: 5.76721
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.51
# Actor Loss: -0.0162, Critic Loss: 0.7276, Entropy: 1.0371
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 17200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.66
# Actor Loss: -0.0126, Critic Loss: 0.6781, Entropy: 1.0312
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0144, Critic Loss: 0.7176, Entropy: 0.9934
# best score so far: 5.76721
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.48
# Actor Loss: -0.0121, Critic Loss: 0.7881, Entropy: 0.9613
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 17800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0100, Critic Loss: 0.6384, Entropy: 0.9917
# best score so far: 5.76721
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0147, Critic Loss: 0.7928, Entropy: 1.0465
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 18200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0108, Critic Loss: 0.6399, Entropy: 1.0225
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 18400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0125, Critic Loss: 0.6999, Entropy: 1.0107
# best score so far: 5.76721
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0126, Critic Loss: 0.6816, Entropy: 1.0176
# best score so far: 5.76721
# -----------------------------------
# serial calc_performance called
# Episode 18800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.
,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.63
# Actor Loss: -0.0065, Critic Loss: 0.6316, Entropy: 0.6077
# best score so far: 5.89903
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.64
# Actor Loss: -0.0083, Critic Loss: 0.6928, Entropy: 0.6151
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 36200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0125, Critic Loss: 0.6480, Entropy: 0.6318
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 36400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0074, Critic Loss: 0.7910, Entropy: 0.6400
# best score so far: 5.89903
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.69
# Actor Loss: -0.0083, Critic Loss: 0.6623, Entropy: 0.6232
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 36800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.74
# Actor Loss: -0.0119, Critic Loss: 0.6942, Entropy: 0.6235
# best score so far: 5.89903
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.74
# Actor Loss: -0.0109, Critic Loss: 0.6974, Entropy: 0.6356
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 37200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0089, Critic Loss: 0.7907, Entropy: 0.6208
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 37400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.69
# Actor Loss: -0.0084, Critic Loss: 0.7599, Entropy: 0.6291
# best score so far: 5.89903
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.67
# Actor Loss: -0.0076, Critic Loss: 0.6688, Entropy: 0.5869
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0108, Critic Loss: 0.8297, Entropy: 0.5825
# best score so far: 5.89903
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0096, Critic Loss: 0.7144, Entropy: 0.5844
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 38200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0088, Critic Loss: 0.6952, Entropy: 0.5968
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0079, Critic Loss: 0.7836, Entropy: 0.5877
# best score so far: 5.89903
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.69
# Actor Loss: -0.0091, Critic Loss: 0.8217, Entropy: 0.6009
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 38800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0100, Critic Loss: 0.8108, Entropy: 0.5938
# best score so far: 5.89903
# -----------------------------------
# Episode 39000
# serial calc_performance called
# Episode 39000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0078, Critic Loss: 0.6178, Entropy: 0.6129
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 39200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0075, Critic Loss: 0.7590, Entropy: 0.6303
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 39400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0088, Critic Loss: 0.6509, Entropy: 0.6104
# best score so far: 5.89903
# -----------------------------------
# Episode 39500
# serial calc_performance called
# Episode 39600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0109, Critic Loss: 0.7878, Entropy: 0.6022
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 39800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0099, Critic Loss: 0.7066, Entropy: 0.6041
# best score so far: 5.89903
# -----------------------------------
# Episode 40000
# serial calc_performance called
# Episode 40000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0078, Critic Loss: 0.7053, Entropy: 0.5744
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 40200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0081, Critic Loss: 0.7556, Entropy: 0.5846
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 40400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.78
# Actor Loss: -0.0100, Critic Loss: 0.8871, Entropy: 0.5487
# best score so far: 5.89903
# -----------------------------------
# Episode 40500
# serial calc_performance called
# Episode 40600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0093, Critic Loss: 0.6838, Entropy: 0.5598
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 40800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0115, Critic Loss: 0.7522, Entropy: 0.5790
# best score so far: 5.89903
# -----------------------------------
# Episode 41000
# serial calc_performance called
# Episode 41000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0081, Critic Loss: 0.7453, Entropy: 0.5877
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 41200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.76
# Actor Loss: -0.0107, Critic Loss: 0.7173, Entropy: 0.5744
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 41400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.74
# Actor Loss: -0.0084, Critic Loss: 0.6796, Entropy: 0.5603
# best score so far: 5.89903
# -----------------------------------
# Episode 41500
# serial calc_performance called
# Episode 41600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0089, Critic Loss: 0.7109, Entropy: 0.5840
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 41800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.85
# Actor Loss: -0.0085, Critic Loss: 0.7625, Entropy: 0.5717
# best score so far: 5.89903
# -----------------------------------
# Episode 42000
# serial calc_performance called
# Episode 42000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0077, Critic Loss: 0.6671, Entropy: 0.5722
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 42200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0067, Critic Loss: 0.7580, Entropy: 0.5556
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 42400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.70
# Actor Loss: -0.0080, Critic Loss: 0.9235, Entropy: 0.5517
# best score so far: 5.89903
# -----------------------------------
# Episode 42500
# serial calc_performance called
# Episode 42600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0076, Critic Loss: 0.8121, Entropy: 0.5708
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 42800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0107, Critic Loss: 0.5801, Entropy: 0.5597
# best score so far: 5.89903
# -----------------------------------
# Episode 43000
# serial calc_performance called
# Episode 43000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0080, Critic Loss: 0.7135, Entropy: 0.5461
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 43200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0089, Critic Loss: 0.7230, Entropy: 0.5993
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 43400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.67
# Actor Loss: -0.0083, Critic Loss: 0.7563, Entropy: 0.5737
# best score so far: 5.89903
# -----------------------------------
# Episode 43500
# serial calc_performance called
# Episode 43600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.84
# Actor Loss: -0.0075, Critic Loss: 0.8473, Entropy: 0.5814
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 43800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0090, Critic Loss: 0.6853, Entropy: 0.5947
# best score so far: 5.89903
# -----------------------------------
# Episode 44000
# serial calc_performance called
# Episode 44000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0094, Critic Loss: 0.6561, Entropy: 0.5599
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 44200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0090, Critic Loss: 0.8618, Entropy: 0.6071
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 44400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.67
# Actor Loss: -0.0099, Critic Loss: 0.6157, Entropy: 0.5841
# best score so far: 5.89903
# -----------------------------------
# Episode 44500
# serial calc_performance called
# Episode 44600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0078, Critic Loss: 0.6727, Entropy: 0.5477
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 44800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.72
# Actor Loss: -0.0067, Critic Loss: 0.6820, Entropy: 0.5704
# best score so far: 5.89903
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0068, Critic Loss: 0.7335, Entropy: 0.5513
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 45200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0075, Critic Loss: 0.8407, Entropy: 0.5318
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 45400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0071, Critic Loss: 0.7134, Entropy: 0.5584
# best score so far: 5.89903
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.64
# Actor Loss: -0.0100, Critic Loss: 0.6731, Entropy: 0.5767
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 45800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.75
# Actor Loss: -0.0072, Critic Loss: 0.7710, Entropy: 0.5801
# best score so far: 5.89903
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0094, Critic Loss: 0.7252, Entropy: 0.5631
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 46200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.76
# Actor Loss: -0.0088, Critic Loss: 0.6839, Entropy: 0.5601
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 46400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0074, Critic Loss: 0.9735, Entropy: 0.5347
# best score so far: 5.89903
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.73
# Actor Loss: -0.0106, Critic Loss: 0.6522, Entropy: 0.5485
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0092, Critic Loss: 0.7313, Entropy: 0.5393
# best score so far: 5.89903
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0087, Critic Loss: 0.6710, Entropy: 0.5281
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 47200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0119, Critic Loss: 0.6728, Entropy: 0.5325
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.79
# Actor Loss: -0.0094, Critic Loss: 0.7555, Entropy: 0.5352
# best score so far: 5.89903
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0102, Critic Loss: 0.7835, Entropy: 0.5149
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 47800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.86
# Actor Loss: -0.0066, Critic Loss: 0.7763, Entropy: 0.5532
# best score so far: 5.89903
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0081, Critic Loss: 0.5600, Entropy: 0.5440
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 48200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.71
# Actor Loss: -0.0098, Critic Loss: 0.7174, Entropy: 0.5464
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 48400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0101, Critic Loss: 0.7861, Entropy: 0.5364
# best score so far: 5.89903
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.81
# Actor Loss: -0.0098, Critic Loss: 0.7206, Entropy: 0.5488
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 48800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.88
# Actor Loss: -0.0094, Critic Loss: 0.6934, Entropy: 0.5517
# best score so far: 5.89903
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.77
# Actor Loss: -0.0082, Critic Loss: 0.7738, Entropy: 0.5585
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 49200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.83
# Actor Loss: -0.0083, Critic Loss: 0.6995, Entropy: 0.5365
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 49400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.78
# Actor Loss: -0.0084, Critic Loss: 0.7217, Entropy: 0.5592
# best score so far: 5.89903
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.70
# Actor Loss: -0.0079, Critic Loss: 0.7452, Entropy: 0.5222
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.80
# Actor Loss: -0.0083, Critic Loss: 0.7551, Entropy: 0.5138
# best score so far: 5.89903
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.64
# Actor Loss: -0.0112, Critic Loss: 0.7991, Entropy: 0.5440
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 50200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0060, Critic Loss: 0.7293, Entropy: 0.5183
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.69
# Actor Loss: -0.0058, Critic Loss: 0.8332, Entropy: 0.5042
# best score so far: 5.89903
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.79
# Actor Loss: -0.0075, Critic Loss: 0.7301, Entropy: 0.4880
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 50800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.79
# Actor Loss: -0.0078, Critic Loss: 0.6712, Entropy: 0.4968
# best score so far: 5.89903
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.73
# Actor Loss: -0.0074, Critic Loss: 0.7521, Entropy: 0.5155
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 51200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.84
# Actor Loss: -0.0054, Critic Loss: 0.6993, Entropy: 0.5108
# best score so far: 5.89903
# -----------------------------------
# serial calc_performance called
# Episode 51400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.82
# Actor Loss: -0.0074, Critic Loss: 0.7828, Entropy: 0.5027
# best score so far: 5.89903
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.72
# Actor Loss: -0.0078, Critic Loss: 0.7195, Entropy: 0.5250
# ...
# Episode 44500
# serial calc_performance called
# Episode 44600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.50
# Actor Loss: -0.0084, Critic Loss: 0.7905, Entropy: 0.5335
# best score so far: 5.62593
# -----------------------------------
# serial calc_performance called
# Episode 44800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.56
# Actor Loss: -0.0057, Critic Loss: 0.6083, Entropy: 0.4941
# best score so far: 5.62593
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.52
# Actor Loss: -0.0055, Critic Loss: 0.7174, Entropy: 0.5078
# best score so far: 5.62593
# -----------------------------------
# serial calc_performance called
# Episode 45200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.59
# Actor Loss: -0.0088, Critic Loss: 0.6940, Entropy: 0.5082
# best score so far: 5.62593
# -----------------------------------
# serial calc_performance called
# Episode 45400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.58
# Actor Loss: -0.0077, Critic Loss: 0.6730, Entropy: 0.5548
# best score so far: 5.62593
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.54
# Actor Loss: -0.0057, Critic Loss: 0.7253, Entropy: 0.5061
# best score so far: 5.62593
# -----------------------------------
# serial calc_performance called
# Episode 45800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.47
# Actor Loss: -0.0077, Critic Loss: 0.6326, Entropy: 0.5154
# best score so far: 5.62593
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.57
# Actor Loss: -0.0075, Critic Loss: 0.7584, Entropy: 0.4972
# best score so far: 5.62593
# -----------------------------------
# serial calc_performance called
# Episode 46200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.56
# Actor Loss: -0.0063, Critic Loss: 0.7962, Entropy: 0.5090
# best score so far: 5.62593
# -----------------------------------
# serial calc_performance called
# Episode 46400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.58
# Actor Loss: -0.0072, Critic Loss: 0.6896, Entropy: 0.4952
# best score so far: 5.62593
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.64
# Actor Loss: -0.0057, Critic Loss: 0.6711, Entropy: 0.4983
# best score so far: 5.64391
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.58
# Actor Loss: -0.0080, Critic Loss: 0.7108, Entropy: 0.4928
# best score so far: 5.64391
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.49
# Actor Loss: -0.0082, Critic Loss: 0.6501, Entropy: 0.5101
# best score so far: 5.64391
# -----------------------------------
# serial calc_performance called
# Episode 47200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.59
# Actor Loss: -0.0067, Critic Loss: 0.7096, Entropy: 0.5284
# best score so far: 5.64391
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.57
# Actor Loss: -0.0075, Critic Loss: 0.7411, Entropy: 0.4876
# best score so far: 5.64391
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.54
# Actor Loss: -0.0084, Critic Loss: 0.6177, Entropy: 0.5003
# best score so far: 5.64391
# -----------------------------------
# serial calc_performance called
# Episode 47800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.66
# Actor Loss: -0.0088, Critic Loss: 0.7138, Entropy: 0.5026
# best score so far: 5.65578
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.52
# Actor Loss: -0.0067, Critic Loss: 0.8097, Entropy: 0.4867
# best score so far: 5.65578
# -----------------------------------
# serial calc_performance called
# Episode 48200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.57
# Actor Loss: -0.0077, Critic Loss: 0.6352, Entropy: 0.5136
# best score so far: 5.65578
# -----------------------------------
# serial calc_performance called
# Episode 48400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.57
# Actor Loss: -0.0073, Critic Loss: 0.7250, Entropy: 0.4789
# best score so far: 5.65578
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.65
# Actor Loss: -0.0062, Critic Loss: 0.7530, Entropy: 0.5185
# best score so far: 5.65578
# -----------------------------------
# serial calc_performance called
# Episode 48800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.68
# Actor Loss: -0.0064, Critic Loss: 0.5306, Entropy: 0.4732
# best score so far: 5.67610
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.44
# Actor Loss: -0.0076, Critic Loss: 0.6717, Entropy: 0.4773
# best score so far: 5.67610
# -----------------------------------
# serial calc_performance called
# Episode 49200,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.66
# Actor Loss: -0.0063, Critic Loss: 0.7791, Entropy: 0.4710
# best score so far: 5.67610
# -----------------------------------
# serial calc_performance called
# Episode 49400,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.48
# Actor Loss: -0.0072, Critic Loss: 0.7657, Entropy: 0.4699
# best score so far: 5.67610
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49600,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.53
# Actor Loss: -0.0064, Critic Loss: 0.7647, Entropy: 0.4849
# best score so far: 5.67610
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.55
# Actor Loss: -0.0067, Critic Loss: 0.6467, Entropy: 0.4557
# best score so far: 5.67610
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50000,LR: A4.4e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.48
# Actor Loss: -0.0083, Critic Loss: 0.6320, Entropy: 0.4873
# best score so far: 5.67610
# -----------------------------------
# serial calc_performance called
# Episode 50200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0045, Critic Loss: 0.7372, Entropy: 0.5027
# best score so far: 5.67610
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0062, Critic Loss: 0.6547, Entropy: 0.5101
# best score so far: 5.67610
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0048, Critic Loss: 0.6588, Entropy: 0.4832
# best score so far: 5.67610
# -----------------------------------
# serial calc_performance called
# Episode 50800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0052, Critic Loss: 0.7398, Entropy: 0.4733
# best score so far: 5.67610
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.70
# Actor Loss: -0.0051, Critic Loss: 0.7055, Entropy: 0.4843
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 51200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0056, Critic Loss: 0.7309, Entropy: 0.5039
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 51400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0054, Critic Loss: 0.6021, Entropy: 0.5207
# best score so far: 5.70364
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0058, Critic Loss: 0.6394, Entropy: 0.4780
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 51800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0064, Critic Loss: 0.6289, Entropy: 0.4787
# best score so far: 5.70364
# -----------------------------------
# Episode 52000
# serial calc_performance called
# Episode 52000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0049, Critic Loss: 0.7080, Entropy: 0.4698
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 52200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0076, Critic Loss: 0.7326, Entropy: 0.4963
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 52400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0073, Critic Loss: 0.8263, Entropy: 0.4750
# best score so far: 5.70364
# -----------------------------------
# Episode 52500
# serial calc_performance called
# Episode 52600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0057, Critic Loss: 0.6434, Entropy: 0.4378
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 52800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0040, Critic Loss: 0.7126, Entropy: 0.4460
# best score so far: 5.70364
# -----------------------------------
# Episode 53000
# serial calc_performance called
# Episode 53000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0060, Critic Loss: 0.6675, Entropy: 0.4821
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 53200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0049, Critic Loss: 0.6269, Entropy: 0.4885
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 53400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0077, Critic Loss: 0.6745, Entropy: 0.4557
# best score so far: 5.70364
# -----------------------------------
# Episode 53500
# serial calc_performance called
# Episode 53600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0058, Critic Loss: 0.7558, Entropy: 0.4993
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 53800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0061, Critic Loss: 0.7234, Entropy: 0.4970
# best score so far: 5.70364
# -----------------------------------
# Episode 54000
# serial calc_performance called
# Episode 54000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.61
# Actor Loss: -0.0057, Critic Loss: 0.6127, Entropy: 0.4538
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 54200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0066, Critic Loss: 0.6936, Entropy: 0.4635
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 54400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0044, Critic Loss: 0.6288, Entropy: 0.4717
# best score so far: 5.70364
# -----------------------------------
# Episode 54500
# serial calc_performance called
# Episode 54600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0047, Critic Loss: 0.6004, Entropy: 0.4564
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 54800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0043, Critic Loss: 0.7453, Entropy: 0.4650
# best score so far: 5.70364
# -----------------------------------
# Episode 55000
# serial calc_performance called
# Episode 55000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.62
# Actor Loss: -0.0049, Critic Loss: 0.6558, Entropy: 0.4629
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 55200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.58
# Actor Loss: -0.0068, Critic Loss: 0.5873, Entropy: 0.4850
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 55400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0059, Critic Loss: 0.6310, Entropy: 0.4967
# best score so far: 5.70364
# -----------------------------------
# Episode 55500
# serial calc_performance called
# Episode 55600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.57
# Actor Loss: -0.0070, Critic Loss: 0.7418, Entropy: 0.4823
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 55800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0063, Critic Loss: 0.6497, Entropy: 0.4789
# best score so far: 5.70364
# -----------------------------------
# Episode 56000
# serial calc_performance called
# Episode 56000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0053, Critic Loss: 0.6282, Entropy: 0.4757
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 56200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0053, Critic Loss: 0.7013, Entropy: 0.4764
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 56400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.58
# Actor Loss: -0.0053, Critic Loss: 0.8276, Entropy: 0.4419
# best score so far: 5.70364
# -----------------------------------
# Episode 56500
# serial calc_performance called
# Episode 56600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0059, Critic Loss: 0.6458, Entropy: 0.4797
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 56800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0050, Critic Loss: 0.7549, Entropy: 0.4503
# best score so far: 5.70364
# -----------------------------------
# Episode 57000
# serial calc_performance called
# Episode 57000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0060, Critic Loss: 0.7254, Entropy: 0.4792
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 57200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0065, Critic Loss: 0.6161, Entropy: 0.4795
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 57400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0059, Critic Loss: 0.6817, Entropy: 0.4533
# best score so far: 5.70364
# -----------------------------------
# Episode 57500
# serial calc_performance called
# Episode 57600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0064, Critic Loss: 0.7673, Entropy: 0.4828
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 57800,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0065, Critic Loss: 0.8199, Entropy: 0.4771
# best score so far: 5.70364
# -----------------------------------
# Episode 58000
# serial calc_performance called
# Episode 58000,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.55
# Actor Loss: -0.0046, Critic Loss: 0.7962, Entropy: 0.4963
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 58200,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.60
# Actor Loss: -0.0054, Critic Loss: 0.6781, Entropy: 0.4581
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
# Episode 58400,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.65
# Actor Loss: -0.0047, Critic Loss: 0.7440, Entropy: 0.4293
# best score so far: 5.70364
# -----------------------------------
# Episode 58500
# serial calc_performance called
# Episode 58600,LR: A1.5e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0069, Critic Loss: 0.6921, Entropy: 0.4611
# best score so far: 5.70364
# -----------------------------------
# serial calc_performance called
