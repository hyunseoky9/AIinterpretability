# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 34 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1 
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 34, iteration: 0, seed: 152634
# env: metapop1
# device: cpu
# state size: (np.int64(20), np.int64(4)), action size: 40
# actor: hidden num: 2, hidden size: [128, 128]
# critic: hidden num: 2, hidden size: [512, 512]
# encoder: hidden num: 2, hidden size: [256, 256], encoder output size: 256
# actor lr: 0.0001, critic lr: 0.0001, encoder lr: 0.0001
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 4096, minibatch size: 128, n_epochs: 10
# evaluation interval: 300, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 100000
# -------------------------------------------------------
# --------------------------------------------------------
# Episode 500
# Episode 1000
# Episode 1500
# Episode 2000
# Episode 2500
# Episode 3000
# Episode 3500
# Episode 4000
# Episode 4500
# Episode 5000
# Episode 5500
# Episode 6000
# Episode 6500
# Episode 7000
# Episode 7500
# Episode 8000
# Episode 8500
# Episode 9000
# Episode 9500
# Episode 10000
# serial calc_performance called
# Episode 10200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.68
# Actor Loss: -0.0054, Critic Loss: 0.3438, Entropy: 7.7978
# best score so far: 4.67778
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.66
# Actor Loss: -0.0055, Critic Loss: 0.3911, Entropy: 7.4697
# best score so far: 4.67778
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.74
# Actor Loss: -0.0041, Critic Loss: 0.4139, Entropy: 7.4763
# best score so far: 4.73807
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.84
# Actor Loss: -0.0066, Critic Loss: 0.3952, Entropy: 7.3140
# best score so far: 4.83622
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.74
# Actor Loss: -0.0062, Critic Loss: 0.3826, Entropy: 7.0585
# best score so far: 4.83622
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.90
# Actor Loss: -0.0054, Critic Loss: 0.3849, Entropy: 6.9731
# best score so far: 4.89675
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.92
# Actor Loss: -0.0030, Critic Loss: 0.3911, Entropy: 6.9732
# best score so far: 4.92210
# -----------------------------------
# serial calc_performance called
# Episode 12300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.93
# Actor Loss: -0.0064, Critic Loss: 0.3496, Entropy: 6.9561
# best score so far: 4.93174
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.94
# Actor Loss: -0.0039, Critic Loss: 0.3701, Entropy: 6.6966
# best score so far: 4.94196
# -----------------------------------
# serial calc_performance called
# Episode 12900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.99
# Actor Loss: -0.0052, Critic Loss: 0.3565, Entropy: 6.7138
# best score so far: 4.99092
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.93
# Actor Loss: -0.0050, Critic Loss: 0.4582, Entropy: 6.8104
# best score so far: 4.99092
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.10
# Actor Loss: -0.0033, Critic Loss: 0.4145, Entropy: 6.7706
# best score so far: 5.10041
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.96
# Actor Loss: -0.0039, Critic Loss: 0.3455, Entropy: 6.6712
# best score so far: 5.10041
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.07
# Actor Loss: -0.0054, Critic Loss: 0.3457, Entropy: 6.3418
# best score so far: 5.10041
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.12
# Actor Loss: -0.0039, Critic Loss: 0.4121, Entropy: 6.1607
# best score so far: 5.12240
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.10
# Actor Loss: -0.0041, Critic Loss: 0.3932, Entropy: 6.0028
# best score so far: 5.12240
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.06
# Actor Loss: -0.0059, Critic Loss: 0.3763, Entropy: 5.9013
# best score so far: 5.12240
# -----------------------------------
# serial calc_performance called
# Episode 15300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.15
# Actor Loss: -0.0059, Critic Loss: 0.3796, Entropy: 5.8280
# best score so far: 5.15476
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.22
# Actor Loss: -0.0055, Critic Loss: 0.4246, Entropy: 5.4109
# best score so far: 5.21864
# -----------------------------------
# serial calc_performance called
# Episode 15900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.16
# Actor Loss: -0.0048, Critic Loss: 0.4198, Entropy: 5.3955
# best score so far: 5.21864
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.18
# Actor Loss: -0.0047, Critic Loss: 0.3811, Entropy: 5.4445
# best score so far: 5.21864
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.22
# Actor Loss: -0.0045, Critic Loss: 0.4514, Entropy: 5.4891
# best score so far: 5.22317
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.20
# Actor Loss: -0.0048, Critic Loss: 0.3866, Entropy: 5.4488
# best score so far: 5.22317
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.23
# Actor Loss: -0.0026, Critic Loss: 0.3924, Entropy: 5.3756
# best score so far: 5.22728
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.20
# Actor Loss: -0.0033, Critic Loss: 0.3521, Entropy: 5.2972
# best score so far: 5.22728
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.25
# Actor Loss: -0.0028, Critic Loss: 0.3950, Entropy: 5.1823
# best score so far: 5.25269
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.21
# Actor Loss: -0.0039, Critic Loss: 0.4143, Entropy: 5.2002
# best score so far: 5.25269
# -----------------------------------
# serial calc_performance called
# Episode 18300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.27
# Actor Loss: -0.0052, Critic Loss: 0.3954, Entropy: 5.3259
# best score so far: 5.26838
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.28
# Actor Loss: -0.0039, Critic Loss: 0.4153, Entropy: 5.0433
# best score so far: 5.28318
# -----------------------------------
# serial calc_performance called
# Episode 18900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.34
# Actor Loss: -0.0044, Critic Loss: 0.3748, Entropy: 4.9402
# best score so far: 5.34295
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.26
# Actor Loss: -0.0039, Critic Loss: 0.3695, Entropy: 4.9279
# best score so far: 5.34295
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.23
# Actor Loss: -0.0034, Critic Loss: 0.3567, Entropy: 4.9592
# best score so far: 5.34295
# -----------------------------------
# serial calc_performance called
# Episode 19800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.28
# Actor Loss: -0.0029, Critic Loss: 0.4127, Entropy: 4.8789
# best score so far: 5.34295
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.31
# Actor Loss: -0.0032, Critic Loss: 0.3930, Entropy: 4.6542
# best score so far: 5.34295
# -----------------------------------
# serial calc_performance called
# Episode 20400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0031, Critic Loss: 0.4022, Entropy: 4.5338
# best score so far: 5.34295
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0046, Critic Loss: 0.4334, Entropy: 4.5822
# best score so far: 5.34295
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0047, Critic Loss: 0.3895, Entropy: 4.5963
# best score so far: 5.34295
# -----------------------------------
# serial calc_performance called
# Episode 21300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0034, Critic Loss: 0.4080, Entropy: 4.4267
# best score so far: 5.34295
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.25
# Actor Loss: -0.0042, Critic Loss: 0.3802, Entropy: 4.3143
# best score so far: 5.34295
# -----------------------------------
# serial calc_performance called
# Episode 21900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0026, Critic Loss: 0.4115, Entropy: 4.2621
# best score so far: 5.34295
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0047, Critic Loss: 0.4128, Entropy: 4.1613
# best score so far: 5.36521
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0045, Critic Loss: 0.4492, Entropy: 4.3473
# best score so far: 5.36521
# -----------------------------------
# serial calc_performance called
# Episode 22800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0051, Critic Loss: 0.3730, Entropy: 4.1809
# best score so far: 5.36858
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0047, Critic Loss: 0.3816, Entropy: 4.2545
# best score so far: 5.40804
# -----------------------------------
# serial calc_performance called
# Episode 23400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0024, Critic Loss: 0.3448, Entropy: 4.1942
# best score so far: 5.40804
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0033, Critic Loss: 0.3984, Entropy: 4.0550
# best score so far: 5.40804
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0050, Critic Loss: 0.4083, Entropy: 3.8994
# best score so far: 5.40804
# -----------------------------------
# serial calc_performance called
# Episode 24300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0026, Critic Loss: 0.3554, Entropy: 3.9665
# best score so far: 5.40804
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0041, Critic Loss: 0.3915, Entropy: 3.7794
# best score so far: 5.40804
# -----------------------------------
# serial calc_performance called
# Episode 24900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0028, Critic Loss: 0.3583, Entropy: 3.8031
# best score so far: 5.40804
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0028, Critic Loss: 0.3233, Entropy: 3.7823
# best score so far: 5.41764
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0025, Critic Loss: 0.3872, Entropy: 3.7861
# best score so far: 5.41764
# -----------------------------------
# serial calc_performance called
# Episode 25800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0035, Critic Loss: 0.4021, Entropy: 3.6074
# best score so far: 5.41764
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0022, Critic Loss: 0.4159, Entropy: 3.6350
# best score so far: 5.41764
# -----------------------------------
# serial calc_performance called
# Episode 26400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0024, Critic Loss: 0.3735, Entropy: 3.6184
# best score so far: 5.41764
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0032, Critic Loss: 0.4413, Entropy: 3.6171
# best score so far: 5.41764
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0030, Critic Loss: 0.4359, Entropy: 3.6443
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 27300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0047, Critic Loss: 0.4775, Entropy: 3.6207
# best score so far: 5.46645
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0033, Critic Loss: 0.3951, Entropy: 3.6333
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 27900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0020, Critic Loss: 0.3769, Entropy: 3.6420
# best score so far: 5.46645
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0021, Critic Loss: 0.3810, Entropy: 3.4991
# best score so far: 5.46645
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0053, Critic Loss: 0.3761, Entropy: 3.5248
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 28800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0026, Critic Loss: 0.4679, Entropy: 3.6370
# best score so far: 5.46645
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0025, Critic Loss: 0.4108, Entropy: 3.5351
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 29400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0020, Critic Loss: 0.4213, Entropy: 3.5295
# best score so far: 5.46645
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0043, Critic Loss: 0.3550, Entropy: 3.5344
# best score so far: 5.46645
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0033, Critic Loss: 0.3620, Entropy: 3.5436
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 30300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0025, Critic Loss: 0.3947, Entropy: 3.6198
# best score so far: 5.46645
# -----------------------------------
# Episode 30500
# serial calc_performance called
# Episode 30600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0023, Critic Loss: 0.4139, Entropy: 3.6604
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 30900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0040, Critic Loss: 0.4055, Entropy: 3.5999
# best score so far: 5.46645
# -----------------------------------
# Episode 31000
# serial calc_performance called
# Episode 31200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0026, Critic Loss: 0.4252, Entropy: 3.6227
# best score so far: 5.46645
# -----------------------------------
# Episode 31500
# serial calc_performance called
# Episode 31500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0041, Critic Loss: 0.3789, Entropy: 3.4943
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 31800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.32
# Actor Loss: -0.0023, Critic Loss: 0.3657, Entropy: 3.5241
# best score so far: 5.46645
# -----------------------------------
# Episode 32000
# serial calc_performance called
# Episode 32100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0052, Critic Loss: 0.3974, Entropy: 3.4716
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 32400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0029, Critic Loss: 0.4481, Entropy: 3.2919
# best score so far: 5.46645
# -----------------------------------
# Episode 32500
# serial calc_performance called
# Episode 32700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0024, Critic Loss: 0.4087, Entropy: 3.3072
# best score so far: 5.46645
# -----------------------------------
# Episode 33000
# serial calc_performance called
# Episode 33000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0021, Critic Loss: 0.3899, Entropy: 3.2242
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 33300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0032, Critic Loss: 0.3784, Entropy: 3.3603
# best score so far: 5.46645
# -----------------------------------
# Episode 33500
# serial calc_performance called
# Episode 33600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0022, Critic Loss: 0.3614, Entropy: 3.3865
# best score so far: 5.46645
# -----------------------------------
# serial calc_performance called
# Episode 33900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0031, Critic Loss: 0.3643, Entropy: 3.2292
# best score so far: 5.46645
# -----------------------------------
# Episode 34000
# serial calc_performance called
# Episode 34200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0022, Critic Loss: 0.3466, Entropy: 3.2217
# best score so far: 5.51831
# -----------------------------------
# Episode 34500
# serial calc_performance called
# Episode 34500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0035, Critic Loss: 0.4644, Entropy: 3.1249
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 34800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0034, Critic Loss: 0.3817, Entropy: 3.0750
# best score so far: 5.51831
# -----------------------------------
# Episode 35000
# serial calc_performance called
# Episode 35100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0040, Critic Loss: 0.4592, Entropy: 3.0716
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 35400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0034, Critic Loss: 0.4239, Entropy: 3.0713
# best score so far: 5.51831
# -----------------------------------
# Episode 35500
# serial calc_performance called
# Episode 35700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0034, Critic Loss: 0.4396, Entropy: 2.9526
# best score so far: 5.51831
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0039, Critic Loss: 0.3407, Entropy: 2.8536
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 36300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0035, Critic Loss: 0.4185, Entropy: 2.8976
# best score so far: 5.51831
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0034, Critic Loss: 0.3728, Entropy: 2.8740
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 36900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0022, Critic Loss: 0.4639, Entropy: 2.7884
# best score so far: 5.51831
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0032, Critic Loss: 0.3945, Entropy: 2.7326
# best score so far: 5.51831
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0028, Critic Loss: 0.4006, Entropy: 2.5778
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0022, Critic Loss: 0.3774, Entropy: 2.5620
# best score so far: 5.51831
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0024, Critic Loss: 0.4094, Entropy: 2.5593
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0019, Critic Loss: 0.3657, Entropy: 2.5016
# best score so far: 5.51831
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0036, Critic Loss: 0.3726, Entropy: 2.4546
# best score so far: 5.51831
# -----------------------------------
# Episode 39000
# serial calc_performance called
# Episode 39000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0048, Critic Loss: 0.4121, Entropy: 2.3891
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 39300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0034, Critic Loss: 0.3783, Entropy: 2.3323
# best score so far: 5.51831
# -----------------------------------
# Episode 39500
# serial calc_performance called
# Episode 39600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0021, Critic Loss: 0.3395, Entropy: 2.2805
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 39900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0031, Critic Loss: 0.3753, Entropy: 2.2229
# best score so far: 5.51831
# -----------------------------------
# Episode 40000
# serial calc_performance called
# Episode 40200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0037, Critic Loss: 0.4035, Entropy: 2.2307
# best score so far: 5.51831
# -----------------------------------
# Episode 40500
# serial calc_performance called
# Episode 40500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0018, Critic Loss: 0.3917, Entropy: 2.2414
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 40800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0026, Critic Loss: 0.4069, Entropy: 2.2689
# best score so far: 5.51831
# -----------------------------------
# Episode 41000
# serial calc_performance called
# Episode 41100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0027, Critic Loss: 0.3840, Entropy: 2.2240
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 41400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0023, Critic Loss: 0.3730, Entropy: 2.2697
# best score so far: 5.51831
# -----------------------------------
# Episode 41500
# serial calc_performance called
# Episode 41700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0023, Critic Loss: 0.3408, Entropy: 2.2854
# best score so far: 5.51831
# -----------------------------------
# Episode 42000
# serial calc_performance called
# Episode 42000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0020, Critic Loss: 0.3547, Entropy: 2.2991
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 42300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0030, Critic Loss: 0.4077, Entropy: 2.1679
# best score so far: 5.51831
# -----------------------------------
# Episode 42500
# serial calc_performance called
# Episode 42600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0021, Critic Loss: 0.4004, Entropy: 2.1318
# best score so far: 5.51831
# -----------------------------------
# serial calc_performance called
# Episode 42900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0028, Critic Loss: 0.3603, Entropy: 2.1921
# best score so far: 5.52145
# -----------------------------------
# Episode 43000
# serial calc_performance called
# Episode 43200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0030, Critic Loss: 0.3720, Entropy: 2.1683
# best score so far: 5.52145
# -----------------------------------
# Episode 43500
# serial calc_performance called
# Episode 43500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0025, Critic Loss: 0.3736, Entropy: 2.1109
# best score so far: 5.52145
# -----------------------------------
# serial calc_performance called
# Episode 43800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0022, Critic Loss: 0.4018, Entropy: 2.1313
# best score so far: 5.52145
# -----------------------------------
# Episode 44000
# serial calc_performance called
# Episode 44100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0022, Critic Loss: 0.3696, Entropy: 2.1137
# best score so far: 5.52145
# -----------------------------------
# serial calc_performance called
# Episode 44400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0024, Critic Loss: 0.4072, Entropy: 2.0998
# best score so far: 5.52145
# -----------------------------------
# Episode 44500
# serial calc_performance called
# Episode 44700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0020, Critic Loss: 0.4446, Entropy: 2.1383
# best score so far: 5.52358
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0026, Critic Loss: 0.4137, Entropy: 2.1891
# best score so far: 5.52358
# -----------------------------------
# serial calc_performance called
# Episode 45300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0018, Critic Loss: 0.3844, Entropy: 2.1942
# best score so far: 5.52358
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0031, Critic Loss: 0.3549, Entropy: 2.1531
# best score so far: 5.52828
# -----------------------------------
# serial calc_performance called
# Episode 45900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0034, Critic Loss: 0.3429, Entropy: 2.1564
# best score so far: 5.53774
# -----------------------------------
# Episode 46000
# serial calc_performance called
# Episode 46200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0025, Critic Loss: 0.3534, Entropy: 2.1570
# best score so far: 5.53774
# -----------------------------------
# Episode 46500
# serial calc_performance called
# Episode 46500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0022, Critic Loss: 0.3693, Entropy: 2.1170
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 46800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0026, Critic Loss: 0.4018, Entropy: 2.0854
# best score so far: 5.53774
# -----------------------------------
# Episode 47000
# serial calc_performance called
# Episode 47100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0024, Critic Loss: 0.4152, Entropy: 2.1959
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 47400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0033, Critic Loss: 0.3812, Entropy: 2.1080
# best score so far: 5.53774
# -----------------------------------
# Episode 47500
# serial calc_performance called
# Episode 47700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0026, Critic Loss: 0.4098, Entropy: 2.1119
# best score so far: 5.53774
# -----------------------------------
# Episode 48000
# serial calc_performance called
# Episode 48000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0021, Critic Loss: 0.3461, Entropy: 2.1386
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 48300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0028, Critic Loss: 0.3774, Entropy: 2.1519
# best score so far: 5.53774
# -----------------------------------
# Episode 48500
# serial calc_performance called
# Episode 48600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0032, Critic Loss: 0.3678, Entropy: 2.1550
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 48900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0046, Critic Loss: 0.4860, Entropy: 2.1638
# best score so far: 5.53774
# -----------------------------------
# Episode 49000
# serial calc_performance called
# Episode 49200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0031, Critic Loss: 0.4232, Entropy: 2.1511
# best score so far: 5.53774
# -----------------------------------
# Episode 49500
# serial calc_performance called
# Episode 49500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0018, Critic Loss: 0.4015, Entropy: 2.0944
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 49800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0028, Critic Loss: 0.3693, Entropy: 2.0374
# best score so far: 5.53774
# -----------------------------------
# Episode 50000
# serial calc_performance called
# Episode 50100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0022, Critic Loss: 0.3768, Entropy: 2.0323
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 50400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0044, Critic Loss: 0.4107, Entropy: 2.0595
# best score so far: 5.53774
# -----------------------------------
# Episode 50500
# serial calc_performance called
# Episode 50700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0034, Critic Loss: 0.4043, Entropy: 1.9985
# best score so far: 5.53774
# -----------------------------------
# Episode 51000
# serial calc_performance called
# Episode 51000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0019, Critic Loss: 0.3987, Entropy: 1.9863
# best score so far: 5.53774
# -----------------------------------
# serial calc_performance called
# Episode 51300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0034, Critic Loss: 0.3882, Entropy: 2.0161
# best score so far: 5.54270
# -----------------------------------
# Episode 51500
# serial calc_performance called
# Episode 51600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0022, Critic Loss: 0.3799, Entropy: 1.9585
# best score so far: 5.54270
# -----------------------------------
# serial calc_performance called
# Episode 51900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0026, Critic Loss: 0.3878, Entropy: 2.0068
# best score so far: 5.54270
# -----------------------------------
# Episode 52000
# serial calc_performance called
# Episode 52200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0020, Critic Loss: 0.3429, Entropy: 1.9675
# best score so far: 5.54270
# -----------------------------------
# Episode 52500
# serial calc_performance called
# Episode 52500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0030, Critic Loss: 0.3804, Entropy: 1.9536
# best score so far: 5.54270
# -----------------------------------
# serial calc_performance called
# Episode 52800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0036, Critic Loss: 0.3415, Entropy: 1.9747
# best score so far: 5.54270
# -----------------------------------
# Episode 53000
# serial calc_performance called
# Episode 53100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0023, Critic Loss: 0.3769, Entropy: 1.9822
# best score so far: 5.54270
# -----------------------------------
# serial calc_performance called
# Episode 53400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0019, Critic Loss: 0.4685, Entropy: 1.9842
# best score so far: 5.54270
# -----------------------------------
# Episode 53500
# serial calc_performance called
# Episode 53700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0034, Critic Loss: 0.4244, Entropy: 1.8978
# best score so far: 5.54270
# -----------------------------------
# Episode 54000
# serial calc_performance called
# Episode 54000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0025, Critic Loss: 0.4038, Entropy: 1.9147
# best score so far: 5.54270
# -----------------------------------
# serial calc_performance called
# Episode 54300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0018, Critic Loss: 0.3485, Entropy: 1.8802
# best score so far: 5.54270
# -----------------------------------
# Episode 54500
# serial calc_performance called
# Episode 54600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0020, Critic Loss: 0.3842, Entropy: 1.8969
# best score so far: 5.54270
# -----------------------------------
# serial calc_performance called
# Episode 54900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0029, Critic Loss: 0.3993, Entropy: 1.8779
# best score so far: 5.54270
# -----------------------------------
# Episode 55000
# serial calc_performance called
# Episode 55200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.56
# Actor Loss: -0.0042, Critic Loss: 0.3943, Entropy: 1.8801
# best score so far: 5.56138
# -----------------------------------
# Episode 55500
# serial calc_performance called
# Episode 55500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0029, Critic Loss: 0.3980, Entropy: 1.8884
# best score so far: 5.56138
# -----------------------------------
# serial calc_performance called
# Episode 55800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0043, Critic Loss: 0.4101, Entropy: 1.8321
# best score so far: 5.56138
# -----------------------------------
# Episode 56000
# serial calc_performance called
# Episode 56100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0032, Critic Loss: 0.3867, Entropy: 1.8800
# best score so far: 5.56138
# -----------------------------------
# serial calc_performance called
# Episode 56400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0038, Critic Loss: 0.4932, Entropy: 1.8343
# best score so far: 5.56138
# -----------------------------------
# Episode 56500
# serial calc_performance called
# Episode 56700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.59
# Actor Loss: -0.0026, Critic Loss: 0.4085, Entropy: 1.8572
# best score so far: 5.58713
# -----------------------------------
# Episode 57000
# serial calc_performance called
# Episode 57000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0023, Critic Loss: 0.4137, Entropy: 1.8393
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 57300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0023, Critic Loss: 0.3855, Entropy: 1.8495
# best score so far: 5.58713
# -----------------------------------
# Episode 57500
# serial calc_performance called
# Episode 57600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0017, Critic Loss: 0.4236, Entropy: 1.8396
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 57900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.54
# Actor Loss: -0.0022, Critic Loss: 0.3720, Entropy: 1.8614
# best score so far: 5.58713
# -----------------------------------
# Episode 58000
# serial calc_performance called
# Episode 58200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0020, Critic Loss: 0.3758, Entropy: 1.8735
# best score so far: 5.58713
# -----------------------------------
# Episode 58500
# serial calc_performance called
# Episode 58500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0023, Critic Loss: 0.3885, Entropy: 1.8582
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 58800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0032, Critic Loss: 0.4637, Entropy: 1.8570
# best score so far: 5.58713
# -----------------------------------
# Episode 59000
# serial calc_performance called
# Episode 59100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0026, Critic Loss: 0.4032, Entropy: 1.8707
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 59400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0023, Critic Loss: 0.4364, Entropy: 1.7980
# best score so far: 5.58713
# -----------------------------------
# Episode 59500
# serial calc_performance called
# Episode 59700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0019, Critic Loss: 0.3468, Entropy: 1.7980
# best score so far: 5.58713
# -----------------------------------
# Episode 60000
# serial calc_performance called
# Episode 60000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.49
# Actor Loss: -0.0027, Critic Loss: 0.3658, Entropy: 1.8049
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 60300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0021, Critic Loss: 0.3580, Entropy: 1.7851
# best score so far: 5.58713
# -----------------------------------
# Episode 60500
# serial calc_performance called
# Episode 60600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0015, Critic Loss: 0.3914, Entropy: 1.8027
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 60900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0022, Critic Loss: 0.4121, Entropy: 1.8618
# best score so far: 5.58713
# -----------------------------------
# Episode 61000
# serial calc_performance called
# Episode 61200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0032, Critic Loss: 0.3822, Entropy: 1.8879
# best score so far: 5.58713
# -----------------------------------
# Episode 61500
# serial calc_performance called
# Episode 61500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0033, Critic Loss: 0.4209, Entropy: 1.8178
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 61800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0023, Critic Loss: 0.3694, Entropy: 1.8083
# best score so far: 5.58713
# -----------------------------------
# Episode 62000
# serial calc_performance called
# Episode 62100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0021, Critic Loss: 0.4131, Entropy: 1.8122
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 62400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.58
# Actor Loss: -0.0026, Critic Loss: 0.4352, Entropy: 1.8811
# best score so far: 5.58713
# -----------------------------------
# Episode 62500
# serial calc_performance called
# Episode 62700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.53
# Actor Loss: -0.0018, Critic Loss: 0.3885, Entropy: 1.7810
# best score so far: 5.58713
# -----------------------------------
# Episode 63000
# serial calc_performance called
# Episode 63000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.52
# Actor Loss: -0.0012, Critic Loss: 0.4162, Entropy: 1.8247
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 63300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0012, Critic Loss: 0.3977, Entropy: 1.8236
# best score so far: 5.58713
# -----------------------------------
# Episode 63500
# serial calc_performance called
# Episode 63600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0015, Critic Loss: 0.3052, Entropy: 1.8483
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 63900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.54
# Actor Loss: -0.0015, Critic Loss: 0.3513, Entropy: 1.8477
# best score so far: 5.58713
# -----------------------------------
# Episode 64000
# serial calc_performance called
# Episode 64200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.48
# Actor Loss: -0.0013, Critic Loss: 0.3486, Entropy: 1.7259
# best score so far: 5.58713
# -----------------------------------
# Episode 64500
# serial calc_performance called
# Episode 64500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0016, Critic Loss: 0.3584, Entropy: 1.8364
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 64800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.56
# Actor Loss: -0.0016, Critic Loss: 0.3503, Entropy: 1.7932
# best score so far: 5.58713
# -----------------------------------
# Episode 65000
# serial calc_performance called
# Episode 65100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0009, Critic Loss: 0.4423, Entropy: 1.7911
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 65400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.41
# Actor Loss: -0.0032, Critic Loss: 0.3983, Entropy: 1.8188
# best score so far: 5.58713
# -----------------------------------
# Episode 65500
# serial calc_performance called
# Episode 65700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.42
# Actor Loss: -0.0016, Critic Loss: 0.4039, Entropy: 1.8442
# best score so far: 5.58713
# -----------------------------------
# Episode 66000
# serial calc_performance called
# Episode 66000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0019, Critic Loss: 0.4242, Entropy: 1.8060
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 66300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0022, Critic Loss: 0.4447, Entropy: 1.7375
# best score so far: 5.58713
# -----------------------------------
# Episode 66500
# serial calc_performance called
# Episode 66600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0039, Critic Loss: 0.3742, Entropy: 1.8062
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 66900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0022, Critic Loss: 0.4499, Entropy: 1.7851
# best score so far: 5.58713
# -----------------------------------
# Episode 67000
# serial calc_performance called
# Episode 67200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.46
# Actor Loss: -0.0012, Critic Loss: 0.3444, Entropy: 1.7775
# best score so far: 5.58713
# -----------------------------------
# Episode 67500
# serial calc_performance called
# Episode 67500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0026, Critic Loss: 0.3901, Entropy: 1.7929
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 67800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.45
# Actor Loss: -0.0022, Critic Loss: 0.4350, Entropy: 1.7643
# best score so far: 5.58713
# -----------------------------------
# Episode 68000
# serial calc_performance called
# Episode 68100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.40
# Actor Loss: -0.0013, Critic Loss: 0.3973, Entropy: 1.7403
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 68400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.54
# Actor Loss: -0.0014, Critic Loss: 0.3492, Entropy: 1.7659
# best score so far: 5.58713
# -----------------------------------
# Episode 68500
# serial calc_performance called
# Episode 68700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.51
# Actor Loss: -0.0016, Critic Loss: 0.3576, Entropy: 1.7892
# best score so far: 5.58713
# -----------------------------------
# Episode 69000
# serial calc_performance called
# Episode 69000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0018, Critic Loss: 0.4186, Entropy: 1.7976
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 69300,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0018, Critic Loss: 0.4386, Entropy: 1.8368
# best score so far: 5.58713
# -----------------------------------
# Episode 69500
# serial calc_performance called
# Episode 69600,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.55
# Actor Loss: -0.0011, Critic Loss: 0.3765, Entropy: 1.8192
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 69900,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.44
# Actor Loss: -0.0022, Critic Loss: 0.4325, Entropy: 1.8074
# best score so far: 5.58713
# -----------------------------------
# Episode 70000
# serial calc_performance called
# Episode 70200,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.50
# Actor Loss: -0.0026, Critic Loss: 0.4170, Entropy: 1.8091
# best score so far: 5.58713
# -----------------------------------
# Episode 70500
# serial calc_performance called
# Episode 70500,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0008, Critic Loss: 0.3623, Entropy: 1.8144
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 70800,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.47
# Actor Loss: -0.0020, Critic Loss: 0.4406, Entropy: 1.7992
# best score so far: 5.58713
# -----------------------------------
# Episode 71000
# serial calc_performance called
# Episode 71100,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0035, Critic Loss: 0.4313, Entropy: 1.8011
# best score so far: 5.58713
# -----------------------------------
# serial calc_performance called
# Episode 71400,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0029, Critic Loss: 0.3971, Entropy: 1.8065
# best score so far: 5.58713
# -----------------------------------
# Episode 71500
# serial calc_performance called
# Episode 71700,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0013, Critic Loss: 0.4061, Entropy: 1.7756
# best score so far: 5.58713
# -----------------------------------
# Episode 72000
# serial calc_performance called
# Episode 72000,LR: A4e-06/C4e-06/E4e-06 Avg Performance: 5.49
# Actor Loss: -0.0027, Critic Loss: 0.3798, Entropy: 1.7090
# best score so far: 5.58713
# -----------------------------------
# ...
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.29
# Actor Loss: -0.0025, Critic Loss: 0.3971, Entropy: 4.6843
# best score so far: 5.32158
# -----------------------------------
# serial calc_performance called
# Episode 18300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.24
# Actor Loss: -0.0032, Critic Loss: 0.3746, Entropy: 4.5940
# best score so far: 5.32158
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.26
# Actor Loss: -0.0048, Critic Loss: 0.3747, Entropy: 4.4851
# best score so far: 5.32158
# -----------------------------------
# serial calc_performance called
# Episode 18900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.37
# Actor Loss: -0.0049, Critic Loss: 0.4202, Entropy: 4.5849
# best score so far: 5.37030
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.40
# Actor Loss: -0.0051, Critic Loss: 0.3902, Entropy: 4.6401
# best score so far: 5.39559
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.23
# Actor Loss: -0.0042, Critic Loss: 0.3928, Entropy: 4.4908
# best score so far: 5.39559
# -----------------------------------
# serial calc_performance called
# Episode 19800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.40
# Actor Loss: -0.0043, Critic Loss: 0.4437, Entropy: 4.3488
# best score so far: 5.40150
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.34
# Actor Loss: -0.0035, Critic Loss: 0.3862, Entropy: 4.3990
# best score so far: 5.40150
# -----------------------------------
# serial calc_performance called
# Episode 20400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0045, Critic Loss: 0.4161, Entropy: 4.4037
# best score so far: 5.40150
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0045, Critic Loss: 0.3561, Entropy: 4.4287
# best score so far: 5.40150
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.25
# Actor Loss: -0.0044, Critic Loss: 0.3605, Entropy: 4.4505
# best score so far: 5.40150
# -----------------------------------
# serial calc_performance called
# Episode 21300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.18
# Actor Loss: -0.0031, Critic Loss: 0.3518, Entropy: 4.3886
# best score so far: 5.40150
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0013, Critic Loss: 0.3618, Entropy: 4.2574
# best score so far: 5.40150
# -----------------------------------
# serial calc_performance called
# Episode 21900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0058, Critic Loss: 0.3959, Entropy: 4.3748
# best score so far: 5.40150
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0024, Critic Loss: 0.3898, Entropy: 4.4543
# best score so far: 5.40150
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0020, Critic Loss: 0.3614, Entropy: 4.2934
# best score so far: 5.40150
# -----------------------------------
# serial calc_performance called
# Episode 22800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0050, Critic Loss: 0.4190, Entropy: 4.3365
# best score so far: 5.40150
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0031, Critic Loss: 0.4659, Entropy: 4.2384
# best score so far: 5.40150
# -----------------------------------
# serial calc_performance called
# Episode 23400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0027, Critic Loss: 0.3223, Entropy: 4.1536
# best score so far: 5.40150
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0021, Critic Loss: 0.3774, Entropy: 4.1386
# best score so far: 5.40150
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0055, Critic Loss: 0.3874, Entropy: 4.1057
# best score so far: 5.40150
# -----------------------------------
# serial calc_performance called
# Episode 24300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0040, Critic Loss: 0.3895, Entropy: 3.9736
# best score so far: 5.44574
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0030, Critic Loss: 0.3796, Entropy: 3.9092
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 24900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0047, Critic Loss: 0.4041, Entropy: 3.8277
# best score so far: 5.44574
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0044, Critic Loss: 0.4213, Entropy: 3.8409
# best score so far: 5.44574
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0065, Critic Loss: 0.4215, Entropy: 3.8517
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 25800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0037, Critic Loss: 0.4128, Entropy: 3.8283
# best score so far: 5.44574
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0025, Critic Loss: 0.3597, Entropy: 3.6699
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 26400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0031, Critic Loss: 0.3653, Entropy: 3.7509
# best score so far: 5.44574
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0035, Critic Loss: 0.3661, Entropy: 3.7414
# best score so far: 5.44574
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0053, Critic Loss: 0.3942, Entropy: 3.7426
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 27300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.27
# Actor Loss: -0.0032, Critic Loss: 0.3712, Entropy: 3.7745
# best score so far: 5.44574
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0065, Critic Loss: 0.3949, Entropy: 3.6232
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 27900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0025, Critic Loss: 0.4038, Entropy: 3.5309
# best score so far: 5.44574
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0020, Critic Loss: 0.4048, Entropy: 3.5681
# best score so far: 5.44574
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0042, Critic Loss: 0.4216, Entropy: 3.5588
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 28800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0037, Critic Loss: 0.3910, Entropy: 3.6042
# best score so far: 5.44574
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0054, Critic Loss: 0.3636, Entropy: 3.5364
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 29400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0042, Critic Loss: 0.3422, Entropy: 3.3995
# best score so far: 5.44574
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0035, Critic Loss: 0.4069, Entropy: 3.4166
# best score so far: 5.44574
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0024, Critic Loss: 0.3794, Entropy: 3.4678
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 30300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0038, Critic Loss: 0.3418, Entropy: 3.5176
# best score so far: 5.44574
# -----------------------------------
# Episode 30500
# serial calc_performance called
# Episode 30600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0043, Critic Loss: 0.3945, Entropy: 3.5863
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 30900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0034, Critic Loss: 0.4191, Entropy: 3.4681
# best score so far: 5.44574
# -----------------------------------
# Episode 31000
# serial calc_performance called
# Episode 31200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0043, Critic Loss: 0.3638, Entropy: 3.5411
# best score so far: 5.44574
# -----------------------------------
# Episode 31500
# serial calc_performance called
# Episode 31500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0032, Critic Loss: 0.4077, Entropy: 3.4156
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 31800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0033, Critic Loss: 0.4227, Entropy: 3.2745
# best score so far: 5.44574
# -----------------------------------
# Episode 32000
# serial calc_performance called
# Episode 32100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0026, Critic Loss: 0.3550, Entropy: 3.2462
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 32400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0028, Critic Loss: 0.4217, Entropy: 3.1603
# best score so far: 5.44574
# -----------------------------------
# Episode 32500
# serial calc_performance called
# Episode 32700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0034, Critic Loss: 0.3641, Entropy: 3.2212
# best score so far: 5.44574
# -----------------------------------
# Episode 33000
# serial calc_performance called
# Episode 33000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0025, Critic Loss: 0.3959, Entropy: 3.1449
# best score so far: 5.44574
# -----------------------------------
# serial calc_performance called
# Episode 33300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0037, Critic Loss: 0.3794, Entropy: 3.0499
# best score so far: 5.44846
# -----------------------------------
# Episode 33500
# serial calc_performance called
# Episode 33600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0020, Critic Loss: 0.4002, Entropy: 3.1323
# best score so far: 5.44846
# -----------------------------------
# serial calc_performance called
# Episode 33900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0025, Critic Loss: 0.3808, Entropy: 3.0047
# best score so far: 5.46988
# -----------------------------------
# Episode 34000
# serial calc_performance called
# Episode 34200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0016, Critic Loss: 0.4159, Entropy: 2.9913
# best score so far: 5.46988
# -----------------------------------
# Episode 34500
# serial calc_performance called
# Episode 34500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0057, Critic Loss: 0.3747, Entropy: 2.8883
# best score so far: 5.47465
# -----------------------------------
# serial calc_performance called
# Episode 34800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0035, Critic Loss: 0.4099, Entropy: 2.9371
# best score so far: 5.47465
# -----------------------------------
# Episode 35000
# serial calc_performance called
# Episode 35100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0034, Critic Loss: 0.3915, Entropy: 2.9212
# best score so far: 5.47465
# -----------------------------------
# serial calc_performance called
# Episode 35400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0044, Critic Loss: 0.3606, Entropy: 2.8853
# best score so far: 5.48395
# -----------------------------------
# Episode 35500
# serial calc_performance called
# Episode 35700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0032, Critic Loss: 0.3946, Entropy: 2.8296
# best score so far: 5.48395
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0026, Critic Loss: 0.3669, Entropy: 2.8924
# best score so far: 5.48395
# -----------------------------------
# serial calc_performance called
# Episode 36300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0031, Critic Loss: 0.3896, Entropy: 2.7661
# best score so far: 5.48395
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0017, Critic Loss: 0.3829, Entropy: 2.8031
# best score so far: 5.48395
# -----------------------------------
# serial calc_performance called
# Episode 36900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0029, Critic Loss: 0.3861, Entropy: 2.8249
# best score so far: 5.48395
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0036, Critic Loss: 0.3574, Entropy: 2.7836
# best score so far: 5.48395
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0030, Critic Loss: 0.3924, Entropy: 2.8329
# best score so far: 5.48395
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0028, Critic Loss: 0.4131, Entropy: 2.8763
# best score so far: 5.48395
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0050, Critic Loss: 0.3861, Entropy: 2.8032
# best score so far: 5.48395
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0023, Critic Loss: 0.4159, Entropy: 2.9100
# best score so far: 5.52838
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0026, Critic Loss: 0.3963, Entropy: 2.8882
# best score so far: 5.52838
# -----------------------------------
# Episode 39000
# serial calc_performance called
