# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 34 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1 
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 34, iteration: 0, seed: 945315
# env: metapop1
# device: cpu
# state size: (np.int64(20), np.int64(4)), action size: 40
# actor: hidden num: 2, hidden size: [128, 128]
# critic: hidden num: 2, hidden size: [512, 512]
# encoder: hidden num: 2, hidden size: [256, 256], encoder output size: 256
# actor lr: 0.0001, critic lr: 0.0001, encoder lr: 0.0001
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 4096, minibatch size: 128, n_epochs: 10
# evaluation interval: 300, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 100000
# -------------------------------------------------------
# --------------------------------------------------------
# Episode 500
# Episode 1000
# Episode 1500
# Episode 2000
# Episode 2500
# Episode 3000
# Episode 3500
# Episode 4000
# Episode 4500
# Episode 5000
# Episode 5500
# Episode 6000
# Episode 6500
# Episode 7000
# Episode 7500
# Episode 8000
# Episode 8500
# Episode 9000
# Episode 9500
# Episode 10000
# serial calc_performance called
# Episode 10200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.58
# Actor Loss: -0.0035, Critic Loss: 0.3726, Entropy: 7.2161
# best score so far: 4.58477
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.64
# Actor Loss: -0.0046, Critic Loss: 0.3315, Entropy: 7.0395
# best score so far: 4.63734
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.63
# Actor Loss: -0.0037, Critic Loss: 0.2999, Entropy: 7.0765
# best score so far: 4.63734
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.66
# Actor Loss: -0.0029, Critic Loss: 0.3428, Entropy: 6.7397
# best score so far: 4.65623
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.81
# Actor Loss: -0.0052, Critic Loss: 0.3433, Entropy: 6.6989
# best score so far: 4.81105
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.86
# Actor Loss: -0.0037, Critic Loss: 0.3339, Entropy: 6.5471
# best score so far: 4.85699
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.83
# Actor Loss: -0.0044, Critic Loss: 0.3551, Entropy: 6.4675
# best score so far: 4.85699
# -----------------------------------
# serial calc_performance called
# Episode 12300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.81
# Actor Loss: -0.0044, Critic Loss: 0.3090, Entropy: 6.3798
# best score so far: 4.85699
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.79
# Actor Loss: -0.0052, Critic Loss: 0.3169, Entropy: 6.2820
# best score so far: 4.85699
# -----------------------------------
# serial calc_performance called
# Episode 12900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.90
# Actor Loss: -0.0055, Critic Loss: 0.3269, Entropy: 6.0600
# best score so far: 4.90451
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.85
# Actor Loss: -0.0028, Critic Loss: 0.3528, Entropy: 6.0425
# best score so far: 4.90451
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.94
# Actor Loss: -0.0060, Critic Loss: 0.3786, Entropy: 5.9779
# best score so far: 4.93646
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.00
# Actor Loss: -0.0053, Critic Loss: 0.3341, Entropy: 5.9377
# best score so far: 5.00498
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.93
# Actor Loss: -0.0055, Critic Loss: 0.3194, Entropy: 5.7326
# best score so far: 5.00498
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.95
# Actor Loss: -0.0030, Critic Loss: 0.4080, Entropy: 5.6061
# best score so far: 5.00498
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.06
# Actor Loss: -0.0037, Critic Loss: 0.3393, Entropy: 5.6222
# best score so far: 5.05905
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.06
# Actor Loss: -0.0033, Critic Loss: 0.3883, Entropy: 5.5966
# best score so far: 5.05970
# -----------------------------------
# serial calc_performance called
# Episode 15300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.09
# Actor Loss: -0.0030, Critic Loss: 0.3663, Entropy: 5.3771
# best score so far: 5.08501
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.03
# Actor Loss: -0.0048, Critic Loss: 0.3930, Entropy: 5.4420
# best score so far: 5.08501
# -----------------------------------
# serial calc_performance called
# Episode 15900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.14
# Actor Loss: -0.0017, Critic Loss: 0.3154, Entropy: 5.3092
# best score so far: 5.14401
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 4.97
# Actor Loss: -0.0044, Critic Loss: 0.3054, Entropy: 5.5053
# best score so far: 5.14401
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.01
# Actor Loss: -0.0047, Critic Loss: 0.3413, Entropy: 5.5508
# best score so far: 5.14401
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.05
# Actor Loss: -0.0043, Critic Loss: 0.3457, Entropy: 5.4686
# best score so far: 5.14401
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.01
# Actor Loss: -0.0052, Critic Loss: 0.3744, Entropy: 5.3147
# best score so far: 5.14401
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.14
# Actor Loss: -0.0022, Critic Loss: 0.4032, Entropy: 5.2739
# best score so far: 5.14401
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17700,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.14
# Actor Loss: -0.0049, Critic Loss: 0.3699, Entropy: 5.1491
# best score so far: 5.14401
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.19
# Actor Loss: -0.0047, Critic Loss: 0.3551, Entropy: 4.9963
# best score so far: 5.18623
# -----------------------------------
# serial calc_performance called
# Episode 18300,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.19
# Actor Loss: -0.0049, Critic Loss: 0.4069, Entropy: 4.8405
# best score so far: 5.19281
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18600,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.23
# Actor Loss: -0.0043, Critic Loss: 0.3467, Entropy: 4.9602
# best score so far: 5.22997
# -----------------------------------
# serial calc_performance called
# Episode 18900,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.19
# Actor Loss: -0.0050, Critic Loss: 0.3745, Entropy: 4.7144
# best score so far: 5.22997
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19200,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.26
# Actor Loss: -0.0064, Critic Loss: 0.3694, Entropy: 4.8269
# best score so far: 5.25969
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.16
# Actor Loss: -0.0033, Critic Loss: 0.3541, Entropy: 4.8629
# best score so far: 5.25969
# -----------------------------------
# serial calc_performance called
# Episode 19800,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.13
# Actor Loss: -0.0030, Critic Loss: 0.3509, Entropy: 4.7106
# best score so far: 5.25969
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20100,LR: A3.3e-05/C3.3e-05/E3.3e-05 Avg Performance: 5.23
# Actor Loss: -0.0048, Critic Loss: 0.3623, Entropy: 4.6850
# best score so far: 5.25969
# -----------------------------------
# serial calc_performance called
# Episode 20400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.16
# Actor Loss: -0.0027, Critic Loss: 0.3389, Entropy: 4.8191
# best score so far: 5.25969
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.17
# Actor Loss: -0.0027, Critic Loss: 0.3351, Entropy: 4.7365
# best score so far: 5.25969
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0051, Critic Loss: 0.3431, Entropy: 4.6092
# best score so far: 5.28863
# -----------------------------------
# serial calc_performance called
# Episode 21300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0027, Critic Loss: 0.3663, Entropy: 4.6576
# best score so far: 5.30577
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.22
# Actor Loss: -0.0045, Critic Loss: 0.3598, Entropy: 4.4078
# best score so far: 5.30577
# -----------------------------------
# serial calc_performance called
# Episode 21900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.27
# Actor Loss: -0.0036, Critic Loss: 0.3758, Entropy: 4.4224
# best score so far: 5.30577
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.32
# Actor Loss: -0.0028, Critic Loss: 0.3731, Entropy: 4.3262
# best score so far: 5.31608
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0035, Critic Loss: 0.3624, Entropy: 4.3417
# best score so far: 5.31608
# -----------------------------------
# serial calc_performance called
# Episode 22800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.27
# Actor Loss: -0.0015, Critic Loss: 0.3469, Entropy: 4.3611
# best score so far: 5.31608
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0039, Critic Loss: 0.4284, Entropy: 4.3830
# best score so far: 5.35356
# -----------------------------------
# serial calc_performance called
# Episode 23400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0035, Critic Loss: 0.3498, Entropy: 4.0900
# best score so far: 5.35356
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.25
# Actor Loss: -0.0036, Critic Loss: 0.3770, Entropy: 4.0388
# best score so far: 5.35356
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0044, Critic Loss: 0.3943, Entropy: 3.9501
# best score so far: 5.35356
# -----------------------------------
# serial calc_performance called
# Episode 24300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.29
# Actor Loss: -0.0046, Critic Loss: 0.3002, Entropy: 4.0980
# best score so far: 5.35356
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0031, Critic Loss: 0.3598, Entropy: 3.9188
# best score so far: 5.35356
# -----------------------------------
# serial calc_performance called
# Episode 24900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0030, Critic Loss: 0.4064, Entropy: 3.8434
# best score so far: 5.35356
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0032, Critic Loss: 0.3629, Entropy: 3.6845
# best score so far: 5.38509
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.31
# Actor Loss: -0.0059, Critic Loss: 0.3695, Entropy: 3.7876
# best score so far: 5.38509
# -----------------------------------
# serial calc_performance called
# Episode 25800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0058, Critic Loss: 0.3912, Entropy: 3.8300
# best score so far: 5.38509
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0037, Critic Loss: 0.3875, Entropy: 3.6826
# best score so far: 5.38509
# -----------------------------------
# serial calc_performance called
# Episode 26400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0026, Critic Loss: 0.3172, Entropy: 3.7435
# best score so far: 5.38509
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0037, Critic Loss: 0.3490, Entropy: 3.6773
# best score so far: 5.38509
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0039, Critic Loss: 0.3331, Entropy: 3.6411
# best score so far: 5.38509
# -----------------------------------
# serial calc_performance called
# Episode 27300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0032, Critic Loss: 0.3598, Entropy: 3.6113
# best score so far: 5.38509
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0032, Critic Loss: 0.3602, Entropy: 3.5728
# best score so far: 5.38509
# -----------------------------------
# serial calc_performance called
# Episode 27900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0023, Critic Loss: 0.4462, Entropy: 3.6568
# best score so far: 5.38509
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.34
# Actor Loss: -0.0038, Critic Loss: 0.3968, Entropy: 3.5546
# best score so far: 5.38509
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.30
# Actor Loss: -0.0047, Critic Loss: 0.4074, Entropy: 3.3130
# best score so far: 5.38509
# -----------------------------------
# serial calc_performance called
# Episode 28800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0031, Critic Loss: 0.3652, Entropy: 3.2116
# best score so far: 5.42098
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0037, Critic Loss: 0.4441, Entropy: 3.1592
# best score so far: 5.46621
# -----------------------------------
# serial calc_performance called
# Episode 29400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0030, Critic Loss: 0.3526, Entropy: 3.1711
# best score so far: 5.46621
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0020, Critic Loss: 0.3897, Entropy: 3.3489
# best score so far: 5.46621
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0034, Critic Loss: 0.3926, Entropy: 3.3923
# best score so far: 5.46621
# -----------------------------------
# serial calc_performance called
# Episode 30300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0037, Critic Loss: 0.3911, Entropy: 3.4107
# best score so far: 5.46621
# -----------------------------------
# Episode 30500
# serial calc_performance called
# Episode 30600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0016, Critic Loss: 0.3942, Entropy: 3.3177
# best score so far: 5.46621
# -----------------------------------
# serial calc_performance called
# Episode 30900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0054, Critic Loss: 0.3745, Entropy: 3.2821
# best score so far: 5.46621
# -----------------------------------
# Episode 31000
# serial calc_performance called
# Episode 31200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.36
# Actor Loss: -0.0046, Critic Loss: 0.3860, Entropy: 3.2055
# best score so far: 5.46621
# -----------------------------------
# Episode 31500
# serial calc_performance called
# Episode 31500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.39
# Actor Loss: -0.0047, Critic Loss: 0.3925, Entropy: 3.2361
# best score so far: 5.46621
# -----------------------------------
# serial calc_performance called
# Episode 31800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0031, Critic Loss: 0.3581, Entropy: 3.1627
# best score so far: 5.46621
# -----------------------------------
# Episode 32000
# serial calc_performance called
# Episode 32100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0032, Critic Loss: 0.4002, Entropy: 3.1198
# best score so far: 5.46875
# -----------------------------------
# serial calc_performance called
# Episode 32400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0043, Critic Loss: 0.3890, Entropy: 3.0205
# best score so far: 5.46875
# -----------------------------------
# Episode 32500
# serial calc_performance called
# Episode 32700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0039, Critic Loss: 0.3647, Entropy: 3.1184
# best score so far: 5.46875
# -----------------------------------
# Episode 33000
# serial calc_performance called
# Episode 33000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0045, Critic Loss: 0.3727, Entropy: 3.1547
# best score so far: 5.46875
# -----------------------------------
# serial calc_performance called
# Episode 33300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0021, Critic Loss: 0.4081, Entropy: 3.1459
# best score so far: 5.46875
# -----------------------------------
# Episode 33500
# serial calc_performance called
# Episode 33600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0034, Critic Loss: 0.4005, Entropy: 3.1260
# best score so far: 5.46875
# -----------------------------------
# serial calc_performance called
# Episode 33900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0026, Critic Loss: 0.3921, Entropy: 3.1356
# best score so far: 5.47456
# -----------------------------------
# Episode 34000
# serial calc_performance called
# Episode 34200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0047, Critic Loss: 0.4499, Entropy: 3.0697
# best score so far: 5.47456
# -----------------------------------
# Episode 34500
# serial calc_performance called
# Episode 34500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0025, Critic Loss: 0.4388, Entropy: 2.9574
# best score so far: 5.47456
# -----------------------------------
# serial calc_performance called
# Episode 34800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0022, Critic Loss: 0.4769, Entropy: 2.9530
# best score so far: 5.47456
# -----------------------------------
# Episode 35000
# serial calc_performance called
# Episode 35100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0036, Critic Loss: 0.3693, Entropy: 2.8677
# best score so far: 5.47456
# -----------------------------------
# serial calc_performance called
# Episode 35400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.42
# Actor Loss: -0.0032, Critic Loss: 0.3658, Entropy: 2.8647
# best score so far: 5.47456
# -----------------------------------
# Episode 35500
# serial calc_performance called
# Episode 35700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.47
# Actor Loss: -0.0039, Critic Loss: 0.4296, Entropy: 2.8596
# best score so far: 5.47500
# -----------------------------------
# Episode 36000
# serial calc_performance called
# Episode 36000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0025, Critic Loss: 0.4351, Entropy: 2.7939
# best score so far: 5.47500
# -----------------------------------
# serial calc_performance called
# Episode 36300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.46
# Actor Loss: -0.0044, Critic Loss: 0.3456, Entropy: 2.8505
# best score so far: 5.47500
# -----------------------------------
# Episode 36500
# serial calc_performance called
# Episode 36600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0043, Critic Loss: 0.4059, Entropy: 2.7479
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 36900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.53
# Actor Loss: -0.0013, Critic Loss: 0.3895, Entropy: 2.7316
# best score so far: 5.52726
# -----------------------------------
# Episode 37000
# serial calc_performance called
# Episode 37200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0030, Critic Loss: 0.3818, Entropy: 2.7731
# best score so far: 5.52726
# -----------------------------------
# Episode 37500
# serial calc_performance called
# Episode 37500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.48
# Actor Loss: -0.0021, Critic Loss: 0.4736, Entropy: 2.6966
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 37800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0033, Critic Loss: 0.3925, Entropy: 2.6373
# best score so far: 5.52726
# -----------------------------------
# Episode 38000
# serial calc_performance called
# Episode 38100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.43
# Actor Loss: -0.0041, Critic Loss: 0.4070, Entropy: 2.5932
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 38400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0044, Critic Loss: 0.3958, Entropy: 2.5396
# best score so far: 5.52726
# -----------------------------------
# Episode 38500
# serial calc_performance called
# Episode 38700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0040, Critic Loss: 0.3126, Entropy: 2.5769
# best score so far: 5.52726
# -----------------------------------
# Episode 39000
# serial calc_performance called
# Episode 39000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0022, Critic Loss: 0.3837, Entropy: 2.4994
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 39300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0026, Critic Loss: 0.3999, Entropy: 2.5337
# best score so far: 5.52726
# -----------------------------------
# Episode 39500
# serial calc_performance called
# Episode 39600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0038, Critic Loss: 0.3849, Entropy: 2.5405
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 39900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0013, Critic Loss: 0.3503, Entropy: 2.6099
# best score so far: 5.52726
# -----------------------------------
# Episode 40000
# serial calc_performance called
# Episode 40200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.37
# Actor Loss: -0.0034, Critic Loss: 0.4166, Entropy: 2.6348
# best score so far: 5.52726
# -----------------------------------
# Episode 40500
# serial calc_performance called
# Episode 40500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.52
# Actor Loss: -0.0023, Critic Loss: 0.3979, Entropy: 2.6901
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 40800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.38
# Actor Loss: -0.0022, Critic Loss: 0.3919, Entropy: 2.7316
# best score so far: 5.52726
# -----------------------------------
# Episode 41000
# serial calc_performance called
# Episode 41100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.35
# Actor Loss: -0.0021, Critic Loss: 0.3669, Entropy: 2.6464
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 41400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0027, Critic Loss: 0.3367, Entropy: 2.6631
# best score so far: 5.52726
# -----------------------------------
# Episode 41500
# serial calc_performance called
# Episode 41700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.45
# Actor Loss: -0.0048, Critic Loss: 0.3987, Entropy: 2.6067
# best score so far: 5.52726
# -----------------------------------
# Episode 42000
# serial calc_performance called
# Episode 42000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.33
# Actor Loss: -0.0028, Critic Loss: 0.3615, Entropy: 2.7014
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 42300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0032, Critic Loss: 0.3930, Entropy: 2.7089
# best score so far: 5.52726
# -----------------------------------
# Episode 42500
# serial calc_performance called
# Episode 42600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0032, Critic Loss: 0.4124, Entropy: 2.6297
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 42900,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0040, Critic Loss: 0.3603, Entropy: 2.5853
# best score so far: 5.52726
# -----------------------------------
# Episode 43000
# serial calc_performance called
# Episode 43200,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.50
# Actor Loss: -0.0028, Critic Loss: 0.4105, Entropy: 2.6059
# best score so far: 5.52726
# -----------------------------------
# Episode 43500
# serial calc_performance called
# Episode 43500,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0025, Critic Loss: 0.3854, Entropy: 2.5688
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 43800,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0020, Critic Loss: 0.3829, Entropy: 2.5354
# best score so far: 5.52726
# -----------------------------------
# Episode 44000
# serial calc_performance called
# Episode 44100,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.51
# Actor Loss: -0.0020, Critic Loss: 0.3839, Entropy: 2.5242
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 44400,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0034, Critic Loss: 0.3559, Entropy: 2.5276
# best score so far: 5.52726
# -----------------------------------
# Episode 44500
# serial calc_performance called
# Episode 44700,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0023, Critic Loss: 0.3961, Entropy: 2.4979
# best score so far: 5.52726
# -----------------------------------
# Episode 45000
# serial calc_performance called
# Episode 45000,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.40
# Actor Loss: -0.0038, Critic Loss: 0.3555, Entropy: 2.4643
# best score so far: 5.52726
# -----------------------------------
# serial calc_performance called
# Episode 45300,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.41
# Actor Loss: -0.0008, Critic Loss: 0.3985, Entropy: 2.4087
# best score so far: 5.52726
# -----------------------------------
# Episode 45500
# serial calc_performance called
# Episode 45600,LR: A1.1e-05/C1.1e-05/E1.1e-05 Avg Performance: 5.44
# Actor Loss: -0.0026, Critic Loss: 0.3982, Entropy: 2.3031
# best score so far: 5.52726
# -----------------------------------
