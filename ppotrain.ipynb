# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...
# Computing V for t=28...
# Computing V for t=27...
# Computing V for t=26...
# Computing V for t=25...
# Computing V for t=24...
# Computing V for t=23...
# Computing V for t=22...
# Computing V for t=21...
# Computing V for t=20...
# Computing V for t=19...
# Computing V for t=18...
# Computing V for t=17...
# Computing V for t=16...
# Computing V for t=15...
# Computing V for t=14...
# Computing V for t=13...
# Computing V for t=12...
# Computing V for t=11...
# Computing V for t=10...
# Computing V for t=9...
# Computing V for t=8...
# Computing V for t=7...
# Computing V for t=6...
# Computing V for t=5...
# Computing V for t=4...
# Computing V for t=3...
# Computing V for t=2...
# Computing V for t=1...
# Computing V for t=0...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8 iteration_num = 10
#       9 hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
# ---> 10 paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
#      11 tuneset = 1
#      12 best_scores = []
#
# File g:\My Drive\research\interpretability\codes\call_paramset.py:9, in call_paramset(filename, id)
#       7 data.columns = data.iloc[0]
#       8 data = data.drop(0)
# ----> 9 paramdf = data.iloc[id].to_dict()
#      10 paramdflist = []
#      11 # if there are semicolons, separate them and make all combinations of paramdf
#
# File c:\Users\Hyun\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Hyun\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Hyun\anaconda3\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 25 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 25, iteration: 0, seed: 598071
# env: metapop1
# device: cpu
# state size: (5, 4), action size: 10
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 3, hidden size: [256, 256, 256]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 15
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 8000
# -------------------------------------------------------
# --------------------------------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -2.99
# Actor Loss: -0.0233, Critic Loss: 0.9151, Entropy: 4.9053
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 0.15
# Actor Loss: -0.0238, Critic Loss: 0.9609, Entropy: 4.1063
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.56
# Actor Loss: -0.0196, Critic Loss: 0.8241, Entropy: 3.2600
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.47
# Actor Loss: -0.0216, Critic Loss: 0.8290, Entropy: 2.8889
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.93
# Actor Loss: -0.0153, Critic Loss: 1.1289, Entropy: 2.6183
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.37
# Actor Loss: -0.0090, Critic Loss: 1.1571, Entropy: 2.2953
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.71
# Actor Loss: -0.0098, Critic Loss: 1.1788, Entropy: 2.0631
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.80
# Actor Loss: -0.0097, Critic Loss: 1.2862, Entropy: 1.9760
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.90
# Actor Loss: -0.0090, Critic Loss: 1.1277, Entropy: 1.9059
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.01
# Actor Loss: -0.0121, Critic Loss: 0.9914, Entropy: 1.7382
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.15
# Actor Loss: -0.0070, Critic Loss: 1.3036, Entropy: 1.6061
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 3.99
# Actor Loss: -0.0098, Critic Loss: 1.3111, Entropy: 1.5694
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.47
# Actor Loss: -0.0124, Critic Loss: 1.1920, Entropy: 1.5459
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.60
# Actor Loss: -0.0114, Critic Loss: 1.0371, Entropy: 1.5018
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.60
# Actor Loss: -0.0080, Critic Loss: 1.2515, Entropy: 1.4558
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.67
# Actor Loss: -0.0078, Critic Loss: 1.2567, Entropy: 1.2875
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.81
# Actor Loss: -0.0094, Critic Loss: 0.7870, Entropy: 1.3014
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.80
# Actor Loss: -0.0100, Critic Loss: 1.3462, Entropy: 1.2985
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.82
# Actor Loss: -0.0102, Critic Loss: 0.9885, Entropy: 1.2295
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.79
# Actor Loss: -0.0062, Critic Loss: 1.2907, Entropy: 1.2101
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.84
# Actor Loss: -0.0099, Critic Loss: 1.3465, Entropy: 1.1438
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.87
# Actor Loss: -0.0083, Critic Loss: 1.2911, Entropy: 1.0542
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.09
# Actor Loss: -0.0075, Critic Loss: 1.4497, Entropy: 1.0423
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.97
# Actor Loss: -0.0055, Critic Loss: 1.4507, Entropy: 0.9748
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.14
# Actor Loss: -0.0044, Critic Loss: 1.3395, Entropy: 0.9718
# -----------------------------------
# serial calc_performance called
# Episode 5200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.31
# Actor Loss: -0.0065, Critic Loss: 1.3270, Entropy: 0.9031
# -----------------------------------
# serial calc_performance called
# Episode 5400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.00
# Actor Loss: -0.0065, Critic Loss: 1.2398, Entropy: 0.7812
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.03
# Actor Loss: -0.0042, Critic Loss: 1.4809, Entropy: 0.8118
# -----------------------------------
# serial calc_performance called
# Episode 5800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.90
# Actor Loss: -0.0060, Critic Loss: 1.1859, Entropy: 0.7836
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.20
# Actor Loss: -0.0051, Critic Loss: 1.0402, Entropy: 0.7435
# -----------------------------------
# serial calc_performance called
# Episode 6200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.28
# Actor Loss: -0.0080, Critic Loss: 1.0883, Entropy: 0.7313
# -----------------------------------
# serial calc_performance called
# Episode 6400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.23
# Actor Loss: -0.0084, Critic Loss: 1.2419, Entropy: 0.7060
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.37
# Actor Loss: -0.0059, Critic Loss: 1.4407, Entropy: 0.7215
# -----------------------------------
# serial calc_performance called
# Episode 6800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.40
# Actor Loss: -0.0051, Critic Loss: 1.2059, Entropy: 0.6345
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.47
# Actor Loss: -0.0077, Critic Loss: 1.3381, Entropy: 0.6794
# -----------------------------------
# serial calc_performance called
# Episode 7200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0055, Critic Loss: 1.1383, Entropy: 0.5401
# -----------------------------------
# serial calc_performance called
# Episode 7400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.37
# Actor Loss: -0.0072, Critic Loss: 1.1591, Entropy: 0.5453
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0057, Critic Loss: 1.2939, Entropy: 0.5920
# -----------------------------------
# serial calc_performance called
# Episode 7800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.50
# Actor Loss: -0.0084, Critic Loss: 1.1861, Entropy: 0.5896
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0035, Critic Loss: 1.1839, Entropy: 0.5755
# -----------------------------------
# best Policy network found at episode 7200
# Training completed.
# Tuneset 1, Iteration 0: [ 5.590175  5.58162   5.50134   5.46792   5.45104   5.402     5.37039
#   5.3676    5.31      5.279195  5.228445  5.204005  5.136445  5.085755
#   5.031355  5.00396   4.96768   4.895815  4.86785   4.84243   4.82101
#   4.81408   4.80456   4.792605  4.6689    4.601865  4.595405  4.469025
#   4.1475    4.009745  3.987955  3.899555  3.79906   3.714185  3.36896
#   2.93429   2.465375  1.55971   0.151545 -2.98914 ]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 25, iteration: 1, seed: 887703
# env: metapop1
# device: cpu
# state size: (5, 4), action size: 10
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 3, hidden size: [256, 256, 256]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 15
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 8000
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -3.63
# Actor Loss: -0.0293, Critic Loss: 1.1357, Entropy: 4.9062
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -0.32
# Actor Loss: -0.0224, Critic Loss: 0.8422, Entropy: 4.2932
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.20
# Actor Loss: -0.0220, Critic Loss: 0.8169, Entropy: 3.5262
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.89
# Actor Loss: -0.0162, Critic Loss: 0.6135, Entropy: 2.9960
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.07
# Actor Loss: -0.0218, Critic Loss: 0.8249, Entropy: 2.6824
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.37
# Actor Loss: -0.0137, Critic Loss: 0.9132, Entropy: 2.6780
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.56
# Actor Loss: -0.0127, Critic Loss: 1.0873, Entropy: 2.6061
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.02
# Actor Loss: -0.0164, Critic Loss: 0.8812, Entropy: 2.6280
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.56
# Actor Loss: -0.0136, Critic Loss: 1.0446, Entropy: 2.3208
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.73
# Actor Loss: -0.0143, Critic Loss: 1.1724, Entropy: 2.1947
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.18
# Actor Loss: -0.0147, Critic Loss: 1.0101, Entropy: 1.9128
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.44
# Actor Loss: -0.0096, Critic Loss: 1.2306, Entropy: 1.7296
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.34
# Actor Loss: -0.0119, Critic Loss: 1.1142, Entropy: 1.7159
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.75
# Actor Loss: -0.0094, Critic Loss: 1.3499, Entropy: 1.6403
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.77
# Actor Loss: -0.0109, Critic Loss: 1.3383, Entropy: 1.5656
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.06
# Actor Loss: -0.0098, Critic Loss: 1.0260, Entropy: 1.3079
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0099, Critic Loss: 1.8842, Entropy: 1.0811
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.41
# Actor Loss: -0.0139, Critic Loss: 1.7725, Entropy: 0.9989
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0088, Critic Loss: 1.3465, Entropy: 0.9688
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0077, Critic Loss: 1.3119, Entropy: 0.8485
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.47
# Actor Loss: -0.0117, Critic Loss: 1.2054, Entropy: 0.8617
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.41
# Actor Loss: -0.0080, Critic Loss: 1.6615, Entropy: 0.8281
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0082, Critic Loss: 1.4155, Entropy: 0.8280
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0081, Critic Loss: 1.4176, Entropy: 0.7004
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0073, Critic Loss: 1.6919, Entropy: 0.6885
# -----------------------------------
# serial calc_performance called
# Episode 5200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.81
# Actor Loss: -0.0077, Critic Loss: 1.2984, Entropy: 0.6850
# -----------------------------------
# serial calc_performance called
# Episode 5400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0087, Critic Loss: 1.4354, Entropy: 0.6308
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0080, Critic Loss: 1.3496, Entropy: 0.6565
# -----------------------------------
# serial calc_performance called
# Episode 5800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.52
# Actor Loss: -0.0086, Critic Loss: 1.0992, Entropy: 0.6463
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.79
# Actor Loss: -0.0092, Critic Loss: 1.7913, Entropy: 0.6010
# -----------------------------------
# serial calc_performance called
# Episode 6200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0059, Critic Loss: 1.7304, Entropy: 0.5441
# -----------------------------------
# serial calc_performance called
# Episode 6400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.75
# Actor Loss: -0.0064, Critic Loss: 1.9271, Entropy: 0.5064
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0069, Critic Loss: 1.7620, Entropy: 0.4477
# -----------------------------------
# serial calc_performance called
# Episode 6800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.61
# Actor Loss: -0.0091, Critic Loss: 1.7084, Entropy: 0.4661
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0091, Critic Loss: 1.0947, Entropy: 0.4164
# -----------------------------------
# serial calc_performance called
# Episode 7200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0067, Critic Loss: 1.2847, Entropy: 0.4220
# -----------------------------------
# serial calc_performance called
# Episode 7400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0114, Critic Loss: 1.4797, Entropy: 0.4339
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.66
# Actor Loss: -0.0066, Critic Loss: 1.3571, Entropy: 0.3903
# -----------------------------------
# serial calc_performance called
# Episode 7800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0094, Critic Loss: 1.4020, Entropy: 0.4048
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0079, Critic Loss: 1.3172, Entropy: 0.3740
# -----------------------------------
# best Policy network found at episode 5200
# Training completed.
# Tuneset 1, Iteration 1: [ 5.811935  5.79302   5.782765  5.765815  5.75191   5.71706   5.69988
#   5.682555  5.660705  5.637575  5.63361   5.631045  5.60786   5.60074
#   5.587495  5.57689   5.53777   5.516025  5.473285  5.454045  5.453605
#   5.45331   5.406975  5.406415  5.06425   4.766225  4.749195  4.439355
#   4.34274   4.177805  3.729125  3.564015  3.01563   2.55786   2.368955
#   2.06946   1.889785  1.19964  -0.316465 -3.629725]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 25, iteration: 2, seed: 274252
# env: metapop1
# device: cpu
# state size: (5, 4), action size: 10
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 3, hidden size: [256, 256, 256]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 15
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 8000
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -3.83
# Actor Loss: -0.0306, Critic Loss: 1.1322, Entropy: 4.9299
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -0.12
# Actor Loss: -0.0321, Critic Loss: 0.7888, Entropy: 4.1957
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.63
# Actor Loss: -0.0202, Critic Loss: 0.7037, Entropy: 3.4299
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.14
# Actor Loss: -0.0167, Critic Loss: 0.9841, Entropy: 2.8652
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.40
# Actor Loss: -0.0140, Critic Loss: 0.7421, Entropy: 2.8889
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.11
# Actor Loss: -0.0189, Critic Loss: 1.0235, Entropy: 2.7152
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.32
# Actor Loss: -0.0160, Critic Loss: 1.2622, Entropy: 2.4515
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.50
# Actor Loss: -0.0132, Critic Loss: 1.5949, Entropy: 2.3508
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.76
# Actor Loss: -0.0173, Critic Loss: 1.3842, Entropy: 2.2117
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.09
# Actor Loss: -0.0169, Critic Loss: 1.5095, Entropy: 2.1310
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.40
# Actor Loss: -0.0124, Critic Loss: 1.1151, Entropy: 1.9529
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.41
# Actor Loss: -0.0171, Critic Loss: 1.0744, Entropy: 1.8610
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.89
# Actor Loss: -0.0104, Critic Loss: 0.9461, Entropy: 1.6451
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 4.97
# Actor Loss: -0.0130, Critic Loss: 1.2597, Entropy: 1.3875
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.37
# Actor Loss: -0.0126, Critic Loss: 1.1192, Entropy: 1.1695
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.40
# Actor Loss: -0.0084, Critic Loss: 1.0815, Entropy: 1.1450
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.43
# Actor Loss: -0.0139, Critic Loss: 1.5286, Entropy: 1.1001
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0105, Critic Loss: 1.5224, Entropy: 1.0196
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.44
# Actor Loss: -0.0096, Critic Loss: 1.4846, Entropy: 0.9663
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0096, Critic Loss: 1.5118, Entropy: 0.7721
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0070, Critic Loss: 1.6710, Entropy: 0.7165
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0069, Critic Loss: 1.4199, Entropy: 0.6848
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0081, Critic Loss: 1.4242, Entropy: 0.6233
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0080, Critic Loss: 1.6407, Entropy: 0.5264
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.75
# Actor Loss: -0.0056, Critic Loss: 1.5238, Entropy: 0.5331
# -----------------------------------
# serial calc_performance called
# Episode 5200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.69
# Actor Loss: -0.0051, Critic Loss: 0.9776, Entropy: 0.4703
# -----------------------------------
