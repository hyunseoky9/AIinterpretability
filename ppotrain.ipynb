# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 19
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 19: {'ID': 19, 'partial_observability': 0, 'patchnum': 5, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 74, 'paramsetID': 9, 'kR': 1, 'kS': 5, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=5 MDP 2D really high cost high extinction, median centrality'}
# Computing V for t=29...
# Computing V for t=28...
# Computing V for t=27...
# Computing V for t=26...
# Computing V for t=25...
# Computing V for t=24...
# Computing V for t=23...
# Computing V for t=22...
# Computing V for t=21...
# Computing V for t=20...
# Computing V for t=19...
# Computing V for t=18...
# Computing V for t=17...
# Computing V for t=16...
# Computing V for t=15...
# Computing V for t=14...
# Computing V for t=13...
# Computing V for t=12...
# Computing V for t=11...
# Computing V for t=10...
# Computing V for t=9...
# Computing V for t=8...
# Computing V for t=7...
# Computing V for t=6...
# Computing V for t=5...
# Computing V for t=4...
# Computing V for t=3...
# Computing V for t=2...
# Computing V for t=1...
# Computing V for t=0...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 16 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 32 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 32, iteration: 0, seed: 325586
# env: metapop1
# device: cpu
# state size: (10, 4), action size: 20
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [256, 256]
# encoder: hidden num: 2, hidden size: [128, 128], encoder output size: 128
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 2048, minibatch size: 64, n_epochs: 10
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 150000
# -------------------------------------------------------
# --------------------------------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -8.68
# Actor Loss: -0.0184, Critic Loss: 0.4665, Entropy: 11.3137
# best score so far: 0.00000
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -6.48
# Actor Loss: -0.0243, Critic Loss: 0.5351, Entropy: 10.9185
# best score so far: 0.00000
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -4.60
# Actor Loss: -0.0209, Critic Loss: 0.4911, Entropy: 10.4501
# best score so far: 0.00000
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -2.34
# Actor Loss: -0.0256, Critic Loss: 0.6021, Entropy: 9.6062
# best score so far: 0.00000
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -0.99
# Actor Loss: -0.0152, Critic Loss: 0.5975, Entropy: 8.9859
# best score so far: 0.00000
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 0.13
# Actor Loss: -0.0149, Critic Loss: 0.5390, Entropy: 8.2963
# best score so far: 0.13096
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 0.99
# Actor Loss: -0.0121, Critic Loss: 0.5899, Entropy: 7.6936
# best score so far: 0.98515
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.70
# Actor Loss: -0.0136, Critic Loss: 0.5001, Entropy: 7.3293
# best score so far: 1.69787
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.23
# Actor Loss: -0.0123, Critic Loss: 0.5576, Entropy: 6.8528
# best score so far: 2.23054
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.43
# Actor Loss: -0.0152, Critic Loss: 0.6236, Entropy: 6.6280
# best score so far: 2.42866
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.91
# Actor Loss: -0.0099, Critic Loss: 0.5629, Entropy: 6.1986
# best score so far: 2.90586
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.21
# Actor Loss: -0.0117, Critic Loss: 0.6887, Entropy: 5.8343
# best score so far: 3.21399
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.45
# Actor Loss: -0.0084, Critic Loss: 0.7266, Entropy: 5.5411
# best score so far: 3.44915
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.50
# Actor Loss: -0.0118, Critic Loss: 0.6137, Entropy: 5.3529
# best score so far: 3.50166
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.91
# Actor Loss: -0.0095, Critic Loss: 0.5869, Entropy: 5.1584
# best score so far: 3.91196
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.06
# Actor Loss: -0.0075, Critic Loss: 0.6094, Entropy: 4.8660
# best score so far: 4.06037
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.92
# Actor Loss: -0.0098, Critic Loss: 0.5181, Entropy: 4.9502
# best score so far: 4.06037
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.34
# Actor Loss: -0.0098, Critic Loss: 0.5855, Entropy: 4.8106
# best score so far: 4.33595
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.23
# Actor Loss: -0.0093, Critic Loss: 0.6110, Entropy: 4.5597
# best score so far: 4.33595
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.40
# Actor Loss: -0.0052, Critic Loss: 0.6318, Entropy: 4.3960
# best score so far: 4.39673
# -----------------------------------
# serial calc_performance called
