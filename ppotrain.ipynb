# %%
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 11 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 10, iteration: 0, seed: 726988
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# -------------------------------------------------------
# --------------------------------------------------------
# serial calc_performance called
# Episode 100, Learning Rate: A0.0005/C0.0003 Avg Performance: 10.84
# -----------------------------------
# serial calc_performance called
# Episode 200, Learning Rate: A0.0005/C0.0003 Avg Performance: 14.61
# -----------------------------------
# serial calc_performance called
# Episode 300, Learning Rate: A0.0005/C0.0003 Avg Performance: 18.43
# -----------------------------------
# serial calc_performance called
# Episode 400, Learning Rate: A0.0005/C0.0003 Avg Performance: 19.87
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.38
# -----------------------------------
# serial calc_performance called
# Episode 600, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.85
# -----------------------------------
# serial calc_performance called
# Episode 700, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.51
# -----------------------------------
# serial calc_performance called
# Episode 800, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.72
# -----------------------------------
# serial calc_performance called
# Episode 900, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.04
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.88
# -----------------------------------
# serial calc_performance called
# Episode 1100, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.23
# -----------------------------------
# serial calc_performance called
# Episode 1200, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.37
# -----------------------------------
# serial calc_performance called
# Episode 1300, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.21
# -----------------------------------
# serial calc_performance called
# Episode 1400, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.13
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.38
# -----------------------------------
# serial calc_performance called
# Episode 1600, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.45
# -----------------------------------
# serial calc_performance called
# Episode 1700, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.40
# -----------------------------------
# serial calc_performance called
# Episode 1800, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.44
# -----------------------------------
# serial calc_performance called
# Episode 1900, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.58
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.67
# -----------------------------------
# serial calc_performance called
# Episode 2100, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.56
# -----------------------------------
# serial calc_performance called
# Episode 2200, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.57
# -----------------------------------
# serial calc_performance called
# Episode 2300, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.44
# -----------------------------------
# serial calc_performance called
# Episode 2400, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.72
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.26
# -----------------------------------
# serial calc_performance called
# Episode 2600, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.43
# -----------------------------------
# serial calc_performance called
# Episode 2700, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.43
# -----------------------------------
# serial calc_performance called
# Episode 2800, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.62
# -----------------------------------
# serial calc_performance called
# Episode 2900, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.57
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.73
# -----------------------------------
# serial calc_performance called
# Episode 3100, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.64
# -----------------------------------
# serial calc_performance called
# Episode 3200, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.90
# -----------------------------------
# serial calc_performance called
# Episode 3300, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.98
# -----------------------------------
# serial calc_performance called
# Episode 3400, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.76
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.74
# -----------------------------------
# serial calc_performance called
# Episode 3600, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.75
# -----------------------------------
# serial calc_performance called
# Episode 3700, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.91
# -----------------------------------
# serial calc_performance called
# Episode 3800, Learning Rate: A0.000167/C0.0001 Avg Performance: 22.03
# -----------------------------------
# serial calc_performance called
# Episode 3900, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.68
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.81
# -----------------------------------
# best Policy network found at episode 3800
# Training completed.
# Tuneset 1, Iteration 0: [22.03    21.9785  21.90575 21.89525 21.80575 21.7595  21.74525 21.739
#  21.73075 21.7175  21.67775 21.674   21.641   21.6175  21.58325 21.57425
#  21.57175 21.5625  21.445   21.439   21.43775 21.434   21.43125 21.3985
#  21.3815  21.37175 21.25625 21.232   21.214   21.128   21.03675 20.88225
#  20.85275 20.72225 20.5135  20.37725 19.87175 18.425   14.60725 10.84075]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 10, iteration: 1, seed: 160268
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100, Learning Rate: A0.0005/C0.0003 Avg Performance: 11.32
# -----------------------------------
# serial calc_performance called
# Episode 200, Learning Rate: A0.0005/C0.0003 Avg Performance: 15.86
# -----------------------------------
# serial calc_performance called
# Episode 300, Learning Rate: A0.0005/C0.0003 Avg Performance: 18.98
# -----------------------------------
# serial calc_performance called
# Episode 400, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.04
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.31
# -----------------------------------
# serial calc_performance called
# Episode 600, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.70
# -----------------------------------
# serial calc_performance called
# Episode 700, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.75
# -----------------------------------
# serial calc_performance called
# Episode 800, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.79
# -----------------------------------
# serial calc_performance called
# Episode 900, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.09
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.05
# -----------------------------------
# serial calc_performance called
# Episode 1100, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.92
# -----------------------------------
# serial calc_performance called
# Episode 1200, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.08
# -----------------------------------
# serial calc_performance called
# Episode 1300, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.20
# -----------------------------------
# serial calc_performance called
# Episode 1400, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.14
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.49
# -----------------------------------
# serial calc_performance called
# Episode 1600, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.25
# -----------------------------------
# serial calc_performance called
# Episode 1700, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.56
# -----------------------------------
# serial calc_performance called
# Episode 1800, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.53
# -----------------------------------
# serial calc_performance called
# Episode 1900, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.38
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.72
# -----------------------------------
# serial calc_performance called
# Episode 2100, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.42
# -----------------------------------
# serial calc_performance called
# Episode 2200, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.39
# -----------------------------------
# serial calc_performance called
# Episode 2300, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.59
# -----------------------------------
# serial calc_performance called
# Episode 2400, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.65
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.66
# -----------------------------------
# serial calc_performance called
# Episode 2600, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.47
# -----------------------------------
# serial calc_performance called
# Episode 2700, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.69
# -----------------------------------
# serial calc_performance called
# Episode 2800, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.93
# -----------------------------------
# serial calc_performance called
# Episode 2900, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.62
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.65
# -----------------------------------
# serial calc_performance called
# Episode 3100, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.75
# -----------------------------------
# serial calc_performance called
# Episode 3200, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.69
# -----------------------------------
# serial calc_performance called
# Episode 3300, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.64
# -----------------------------------
# serial calc_performance called
# Episode 3400, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.66
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.58
# -----------------------------------
# serial calc_performance called
# Episode 3600, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.87
# -----------------------------------
# serial calc_performance called
# Episode 3700, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.80
# -----------------------------------
# serial calc_performance called
# Episode 3800, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.87
# -----------------------------------
# serial calc_performance called
# Episode 3900, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.47
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.90
# -----------------------------------
# best Policy network found at episode 2800
# Training completed.
# Tuneset 1, Iteration 1: [21.93375 21.89925 21.8715  21.8695  21.79675 21.747   21.71725 21.68975
#  21.6895  21.65975 21.656   21.65475 21.6485  21.645   21.618   21.5865
#  21.578   21.563   21.5305  21.49225 21.4675  21.46675 21.4235  21.389
#  21.37625 21.25075 21.19975 21.145   21.094   21.08275 21.0505  20.9235
#  20.78875 20.74775 20.70175 20.30625 20.03575 18.9785  15.86125 11.3215 ]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 10, iteration:
performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100, Learning Rate: A0.0005/C0.0003 Avg Performance: 11.36
# -----------------------------------
# serial calc_performance called
# Episode 200, Learning Rate: A0.0005/C0.0003 Avg Performance: 16.33
# -----------------------------------
# serial calc_performance called
# Episode 300, Learning Rate: A0.0005/C0.0003 Avg Performance: 18.78
# -----------------------------------
# serial calc_performance called
# Episode 400, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.29
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.29
# -----------------------------------
# serial calc_performance called
# Episode 600, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.83
# -----------------------------------
# serial calc_performance called
# Episode 700, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.77
# -----------------------------------
# serial calc_performance called
# Episode 800, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.90
# -----------------------------------
# serial calc_performance called
# Episode 900, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.93
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.89
# -----------------------------------
# serial calc_performance called
# Episode 1100, Learning Rate: A0.0005/C0.0003 Avg Performance: 20.84
# -----------------------------------
# serial calc_performance called
# Episode 1200, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.09
# -----------------------------------
# serial calc_performance called
# Episode 1300, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.16
# -----------------------------------
# serial calc_performance called
# Episode 1400, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.29
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.37
# -----------------------------------
# serial calc_performance called
# Episode 1600, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.50
# -----------------------------------
# serial calc_performance called
# Episode 1700, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.48
# -----------------------------------
# serial calc_performance called
# Episode 1800, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.41
# -----------------------------------
# serial calc_performance called
# Episode 1900, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.78
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 21.66
# -----------------------------------
# serial calc_performance called
# Episode 2100, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.53
# -----------------------------------
# serial calc_performance called
# Episode 2200, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.73
# -----------------------------------
# serial calc_performance called
# Episode 2300, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.49
# -----------------------------------
# serial calc_performance called
# Episode 2400, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.69
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.59
# -----------------------------------
# serial calc_performance called
# Episode 2600, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.78
# -----------------------------------
# serial calc_performance called
# Episode 2700, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.59
# -----------------------------------
# serial calc_performance called
# Episode 2800, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.58
# -----------------------------------
# serial calc_performance called
# Episode 2900, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.75
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.79
# -----------------------------------
# serial calc_performance called
# Episode 3100, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.66
# -----------------------------------
# serial calc_performance called
# Episode 3200, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.60
# -----------------------------------
# serial calc_performance called
# Episode 3300, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.40
# -----------------------------------
# serial calc_performance called
# Episode 3400, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.50
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.54
# -----------------------------------
# serial calc_performance called
# Episode 3600, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.82
# -----------------------------------
# serial calc_performance called
# Episode 3700, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.37
# -----------------------------------
# serial calc_performance called
# Episode 3800, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.66
# -----------------------------------
# serial calc_performance called
# Episode 3900, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.29
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 21.55
# -----------------------------------
# best Policy network found at episode 3600
# Training completed.
# Tuneset 1, Iteration 9: [21.82325 21.792   21.7805  21.77575 21.75225 21.73475 21.69475 21.661
#  21.659   21.655   21.60275 21.59125 21.59125 21.57525 21.553   21.5385
#  21.52725 21.50275 21.5     21.4885  21.47525 21.4075  21.40075 21.372
#  21.36625 21.29175 21.29125 21.1615  21.09025 20.9345  20.901   20.89375
#  20.838   20.827   20.7705  20.29425 20.28875 18.78175 16.33475 11.357  ]
# seed  best_score
# 6  971985    22.08400
# 7  246323    22.07800
# 0  726988    22.03000
# 3  284437    21.97650
# 2  699110    21.93975
# 1  160268    21.93375
# 4  271227    21.90550
# 9   26409    21.82325
# 5  949696    21.75725
# 8  270351    21.67250
