# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.27
# -----------------------------------
# best Policy network found at episode 3100
# Training completed.
# Tuneset 1, Iteration 6: [20.76   20.5725 20.2925 20.2675 20.26   20.165  20.1625 20.11   20.09
#  19.995  19.9875 19.9    19.8075 19.73   19.6675 19.5775 19.2575 19.175
#  19.1725 19.0625 18.985  18.985  18.9125 18.4175 18.4025 18.1475 17.7475
#  17.6575 17.1125 16.88   16.2175 16.13   14.1325 14.125  12.59   12.0575
#  10.99   10.055   8.495   7.9525]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 1, iteration: 7, seed: 59116
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0003, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.01, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 2000, minibatch size: 64, n_epochs: 10
# evaluation interval: 100, performance sampleN: 100, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100, Learning Rate: A0.0003/C0.0003 Avg Performance: 7.80
# -----------------------------------
# ...
# Episode 2700, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.98
# -----------------------------------
# serial calc_performance called
# Episode 2800, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.37
# -----------------------------------
# serial calc_performance called
# Episode 2900, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.24
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.95
# -----------------------------------
# serial calc_performance called
# Episode 3100, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.06
# -----------------------------------
# serial calc_performance called
# Episode 3200, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.00
# -----------------------------------
# serial calc_performance called
# Episode 3300, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.33
# -----------------------------------
# serial calc_performance called
# Episode 3400, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.25
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.71
# -----------------------------------
# serial calc_performance called
# Episode 3600, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.02
# -----------------------------------
# serial calc_performance called
# Episode 3700, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.77
# -----------------------------------
# serial calc_performance called
# Episode 3800, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.21
# -----------------------------------
# serial calc_performance called
# Episode 3900, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.89
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.41
# -----------------------------------
# best Policy network found at episode 3900
# Training completed.
# Tuneset 1, Iteration 7: [20.8925 20.7075 20.705  20.6875 20.52   20.415  20.3725 20.3275 20.255
#  20.24   20.2125 20.06   20.0225 20.0025 19.945  19.765  19.765  19.74
#  19.5675 19.395  19.06   19.0325 18.985  18.6725 18.665  18.655  18.0975
#  17.9275 16.555  16.24   15.9775 15.15   13.9525 13.5775 11.9325 11.51
#  10.2975  9.56    9.0625  7.8   ]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 1, iteration: 8, seed: 730646
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0003, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.01, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 2000, minibatch size: 64, n_epochs: 10
# evaluation interval: 100, performance sampleN: 100, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100, Learning Rate: A0.0003/C0.0003 Avg Performance: 7.08
# -----------------------------------
# serial calc_performance called
# Episode 200, Learning Rate: A0.0003/C0.0003 Avg Performance: 7.64
# -----------------------------------
# serial calc_performance called
# Episode 300, Learning Rate: A0.0003/C0.0003 Avg Performance: 9.16
# -----------------------------------
# serial calc_performance called
# Episode 400, Learning Rate: A0.0003/C0.0003 Avg Performance: 9.71
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0003/C0.0003 Avg Performance: 11.25
# -----------------------------------
# serial calc_performance called
# Episode 600, Learning Rate: A0.0003/C0.0003 Avg Performance: 12.04
# -----------------------------------
# serial calc_performance called
# Episode 700, Learning Rate: A0.0003/C0.0003 Avg Performance: 13.13
# -----------------------------------
# serial calc_performance called
# Episode 800, Learning Rate: A0.0003/C0.0003 Avg Performance: 14.15
# -----------------------------------
# serial calc_performance called
# Episode 900, Learning Rate: A0.0003/C0.0003 Avg Performance: 14.77
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0003/C0.0003 Avg Performance: 15.68
# -----------------------------------
# serial calc_performance called
# Episode 1100, Learning Rate: A0.0001/C0.0001 Avg Performance: 16.87
# -----------------------------------
# serial calc_performance called
# Episode 1200, Learning Rate: A0.0001/C0.0001 Avg Performance: 16.80
# -----------------------------------
# serial calc_performance called
# Episode 1300, Learning Rate: A0.0001/C0.0001 Avg Performance: 17.66
# -----------------------------------
# serial calc_performance called
# Episode 1400, Learning Rate: A0.0001/C0.0001 Avg Performance: 17.94
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.61
# -----------------------------------
# serial calc_performance called
# Episode 1600, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.24
# -----------------------------------
# serial calc_performance called
# Episode 1700, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.25
# -----------------------------------
# serial calc_performance called
# Episode 1800, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.08
# -----------------------------------
# serial calc_performance called
# Episode 1900, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.81
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.08
# -----------------------------------
# serial calc_performance called
# Episode 2100, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.93
# -----------------------------------
# serial calc_performance called
# Episode 2200, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.20
# -----------------------------------
# serial calc_performance called
# Episode 2300, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.96
# -----------------------------------
# serial calc_performance called
# Episode 2400, Learning Rate: A0.0001/C0.0001 Avg Performance: 21.03
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.09
# -----------------------------------
# serial calc_performance called
# Episode 2600, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.75
# -----------------------------------
# serial calc_performance called
# Episode 2700, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.39
# -----------------------------------
# serial calc_performance called
# Episode 2800, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.28
# -----------------------------------
# serial calc_performance called
# Episode 2900, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.78
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.67
# -----------------------------------
# serial calc_performance called
# Episode 3100, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.60
# -----------------------------------
# serial calc_performance called
# Episode 3200, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.33
# -----------------------------------
# serial calc_performance called
# Episode 3300, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.27
# -----------------------------------
# serial calc_performance called
# Episode 3400, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.24
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.28
# -----------------------------------
# serial calc_performance called
# Episode 3600, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.84
# -----------------------------------
# serial calc_performance called
# Episode 3700, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.49
# -----------------------------------
# serial calc_performance called
# Episode 3800, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.86
# -----------------------------------
# serial calc_performance called
# Episode 3900, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.48
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.70
# -----------------------------------
# best Policy network found at episode 2400
# Training completed.
# Tuneset 1, Iteration 8: [21.03   20.7025 20.4775 20.395  20.3325 20.28   20.28   20.2725 20.2375
#  20.195  20.0875 20.08   19.9575 19.925  19.8625 19.845  19.8125 19.7825
#  19.755  19.6725 19.6025 19.4925 19.25   19.0825 18.615  18.2375 17.94
#  17.66   16.87   16.7975 15.675  14.7725 14.1525 13.1325 12.0375 11.25
#   9.71    9.16    7.645   7.085 ]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 1, iteration: 9, seed: 815351
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0003, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.01, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 2000, minibatch size: 64, n_epochs: 10
# evaluation interval: 100, performance sampleN: 100, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100, Learning Rate: A0.0003/C0.0003 Avg Performance: 7.94
# -----------------------------------
# serial calc_performance called
# Episode 200, Learning Rate: A0.0003/C0.0003 Avg Performance: 9.32
# -----------------------------------
# serial calc_performance called
# Episode 300, Learning Rate: A0.0003/C0.0003 Avg Performance: 9.31
# -----------------------------------
# serial calc_performance called
# Episode 400, Learning Rate: A0.0003/C0.0003 Avg Performance: 10.11
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0003/C0.0003 Avg Performance: 11.21
# -----------------------------------
# serial calc_performance called
# Episode 600, Learning Rate: A0.0003/C0.0003 Avg Performance: 11.61
# -----------------------------------
# serial calc_performance called
# Episode 700, Learning Rate: A0.0003/C0.0003 Avg Performance: 13.30
# -----------------------------------
# serial calc_performance called
# Episode 800, Learning Rate: A0.0003/C0.0003 Avg Performance: 13.57
# -----------------------------------
# serial calc_performance called
# Episode 900, Learning Rate: A0.0003/C0.0003 Avg Performance: 14.87
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0003/C0.0003 Avg Performance: 15.43
# -----------------------------------
# serial calc_performance called
# Episode 1100, Learning Rate: A0.0001/C0.0001 Avg Performance: 15.57
# -----------------------------------
# serial calc_performance called
# Episode 1200, Learning Rate: A0.0001/C0.0001 Avg Performance: 16.22
# -----------------------------------
# serial calc_performance called
# Episode 1300, Learning Rate: A0.0001/C0.0001 Avg Performance: 16.73
# -----------------------------------
# serial calc_performance called
# Episode 1400, Learning Rate: A0.0001/C0.0001 Avg Performance: 17.44
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.25
# -----------------------------------
# serial calc_performance called
# Episode 1600, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.33
# -----------------------------------
# serial calc_performance called
# Episode 1700, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.59
# -----------------------------------
# serial calc_performance called
# Episode 1800, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.36
# -----------------------------------
# serial calc_performance called
# Episode 1900, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.91
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.18
# -----------------------------------
# serial calc_performance called
# Episode 2100, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.85
# -----------------------------------
# serial calc_performance called
# Episode 2200, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.64
# -----------------------------------
# serial calc_performance called
# Episode 2300, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.16
# -----------------------------------
# serial calc_performance called
# Episode 2400, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.11
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.22
# -----------------------------------
# serial calc_performance called
# Episode 2600, Learning Rate: A0.0001/C0.0001 Avg Performance: 18.70
# -----------------------------------
# serial calc_performance called
# Episode 2700, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.00
# -----------------------------------
# serial calc_performance called
# Episode 2800, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.70
# -----------------------------------
# serial calc_performance called
# Episode 2900, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.16
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.34
# -----------------------------------
# serial calc_performance called
# Episode 3100, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.86
# -----------------------------------
# serial calc_performance called
# Episode 3200, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.52
# -----------------------------------
# serial calc_performance called
# Episode 3300, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.96
# -----------------------------------
# serial calc_performance called
# Episode 3400, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.72
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.0001/C0.0001 Avg Performance: 20.15
# -----------------------------------
# serial calc_performance called
# Episode 3600, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.83
# -----------------------------------
# serial calc_performance called
# Episode 3700, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.98
# -----------------------------------
# serial calc_performance called
# Episode 3800, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.64
# -----------------------------------
# serial calc_performance called
# Episode 3900, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.86
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.0001/C0.0001 Avg Performance: 19.97
# -----------------------------------
# best Policy network found at episode 3000
# Training completed.
# Tuneset 1, Iteration 9: [20.34   20.16   20.1475 19.9975 19.985  19.9675 19.9575 19.86   19.86
#  19.8275 19.7175 19.7025 19.6375 19.5175 19.36   19.2225 19.175  19.115
#  18.9125 18.8525 18.7    18.6375 18.595  18.3275 18.25   18.165  17.4425
#  16.7325 16.22   15.5725 15.425  14.87   13.575  13.3    11.6075 11.21
#  10.105   9.3225  9.3075  7.9425]
# seed  best_score
# 4  254927     21.1450
# 8  730646     21.0300
# 7   59116     20.8925
# 2  932214     20.8200
# 3  337513     20.7900
# 1  592278     20.7750
# 6  577025     20.7600
# 0  808952     20.7525
# 5   44454     20.6625
# 9  815351     20.3400
