# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 5
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 5: {'ID': 5, 'partial_observability': 0, 'patchnum': 4, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 0, 'paramsetID': 1, 'kR': 1, 'kS': 8, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=4 MDP scaling up from here'}
# Computing V for t=29...
# Computing V for t=28...
# Computing V for t=27...
# Computing V for t=26...
# Computing V for t=25...
# Computing V for t=24...
# Computing V for t=23...
# Computing V for t=22...
# Computing V for t=21...
# Computing V for t=20...
# Computing V for t=19...
# Computing V for t=18...
# Computing V for t=17...
# Computing V for t=16...
# Computing V for t=15...
# Computing V for t=14...
# Computing V for t=13...
# Computing V for t=12...
# Computing V for t=11...
# Computing V for t=10...
# Computing V for t=9...
# Computing V for t=8...
# Computing V for t=7...
# Computing V for t=6...
# Computing V for t=5...
# Computing V for t=4...
# Computing V for t=3...
# Computing V for t=2...
# Computing V for t=1...
# Computing V for t=0...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 11 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 11, iteration: 0, seed: 438788
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# -------------------------------------------------------
# --------------------------------------------------------
# serial calc_performance called

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 32 # test id = 4
    iteration_num = 2
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     from PPO2 import *
#
#   File g:\My Drive\research\interpretability\codes\PPO2.py:258
#     if i_episode % self.evaluation_interval and == 0:
#                                                 ^
# SyntaxError: invalid syntax

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 30 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 30, iteration: 0, seed: 452501
# env: metapop1
# device: cpu
# state size: (5, 4), action size: 10
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 10
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 60000
# -------------------------------------------------------
# --------------------------------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -3.92
# Actor Loss: -0.0216, Critic Loss: 0.8819, Entropy: 4.9201
# best score so far: 0.00000
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -0.05
# Actor Loss: -0.0234, Critic Loss: 0.9864, Entropy: 4.1586
# best score so far: 0.00000
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.05
# Actor Loss: -0.0215, Critic Loss: 0.9525, Entropy: 3.6090
# best score so far: 1.04661
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.60
# Actor Loss: -0.0125, Critic Loss: 1.2073, Entropy: 3.1776
# best score so far: 1.59950
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.21
# Actor Loss: -0.0077, Critic Loss: 1.0917, Entropy: 2.8756
# best score so far: 2.21208
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.67
# Actor Loss: -0.0119, Critic Loss: 0.7025, Entropy: 2.6892
# best score so far: 2.67260
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.79
# Actor Loss: -0.0097, Critic Loss: 1.3646, Entropy: 2.4603
# best score so far: 2.79434
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.42
# Actor Loss: -0.0103, Critic Loss: 1.0135, Entropy: 2.4104
# best score so far: 3.42474
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.82
# Actor Loss: -0.0081, Critic Loss: 1.1284, Entropy: 2.1468
# best score so far: 3.81767
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.11
# Actor Loss: -0.0082, Critic Loss: 1.3511, Entropy: 2.1036
# best score so far: 4.10906
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.29
# Actor Loss: -0.0032, Critic Loss: 1.3554, Entropy: 2.0612
# best score so far: 4.28925
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.27
# Actor Loss: -0.0055, Critic Loss: 1.1958, Entropy: 1.9150
# best score so far: 4.28925
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.39
# Actor Loss: -0.0073, Critic Loss: 0.9902, Entropy: 1.8602
# best score so far: 4.38926
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.55
# Actor Loss: -0.0094, Critic Loss: 1.3382, Entropy: 1.5876
# best score so far: 4.55483
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.82
# Actor Loss: -0.0098, Critic Loss: 1.1115, Entropy: 1.5687
# best score so far: 4.82105
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.06
# Actor Loss: -0.0064, Critic Loss: 1.2469, Entropy: 1.4097
# best score so far: 5.05745
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.09
# Actor Loss: -0.0059, Critic Loss: 1.1451, Entropy: 1.3941
# best score so far: 5.09107
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.10
# Actor Loss: -0.0020, Critic Loss: 1.2123, Entropy: 1.3514
# best score so far: 5.10304
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.10
# Actor Loss: -0.0093, Critic Loss: 1.1828, Entropy: 1.2770
# best score so far: 5.10304
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.20
# Actor Loss: -0.0062, Critic Loss: 1.1675, Entropy: 1.2157
# best score so far: 5.19540
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.03
# Actor Loss: -0.0072, Critic Loss: 1.1413, Entropy: 1.1137
# best score so far: 5.19540
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.01
# Actor Loss: -0.0073, Critic Loss: 1.2777, Entropy: 1.1088
# best score so far: 5.19540
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.03
# Actor Loss: -0.0140, Critic Loss: 1.2231, Entropy: 1.0332
# best score so far: 5.19540
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.97
# Actor Loss: -0.0069, Critic Loss: 1.1764, Entropy: 1.0565
# best score so far: 5.19540
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.08
# Actor Loss: -0.0063, Critic Loss: 1.1547, Entropy: 0.9210
# best score so far: 5.19540
# -----------------------------------
# serial calc_performance called
# Episode 5200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.19
# Actor Loss: -0.0050, Critic Loss: 1.6852, Entropy: 0.8901
# best score so far: 5.19540
# -----------------------------------
# serial calc_performance called
# Episode 5400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.01
# Actor Loss: -0.0041, Critic Loss: 1.2987, Entropy: 0.9018
# best score so far: 5.19540
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.28
# Actor Loss: -0.0081, Critic Loss: 0.9955, Entropy: 0.8138
# best score so far: 5.27613
# -----------------------------------
# serial calc_performance called
# Episode 5800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.34
# Actor Loss: -0.0061, Critic Loss: 1.1808, Entropy: 0.7337
# best score so far: 5.33710
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.42
# Actor Loss: -0.0100, Critic Loss: 1.0482, Entropy: 0.6434
# best score so far: 5.41769
# -----------------------------------
# serial calc_performance called
# Episode 6200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.25
# Actor Loss: -0.0056, Critic Loss: 1.5018, Entropy: 0.6700
# best score so far: 5.41769
# -----------------------------------
# serial calc_performance called
# Episode 6400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.22
# Actor Loss: -0.0049, Critic Loss: 1.0461, Entropy: 0.6721
# best score so far: 5.41769
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.13
# Actor Loss: -0.0080, Critic Loss: 1.2209, Entropy: 0.7009
# best score so far: 5.41769
# -----------------------------------
# serial calc_performance called
# Episode 6800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.24
# Actor Loss: -0.0074, Critic Loss: 1.2080, Entropy: 0.7313
# best score so far: 5.41769
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.29
# Actor Loss: -0.0037, Critic Loss: 1.2584, Entropy: 0.6284
# best score so far: 5.41769
# -----------------------------------
# serial calc_performance called
# Episode 7200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.33
# Actor Loss: -0.0088, Critic Loss: 1.3110, Entropy: 0.6376
# best score so far: 5.41769
# -----------------------------------
# serial calc_performance called
# Episode 7400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.44
# Actor Loss: -0.0043, Critic Loss: 1.2079, Entropy: 0.6407
# best score so far: 5.44189
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.19
# Actor Loss: -0.0066, Critic Loss: 1.2654, Entropy: 0.6243
# best score so far: 5.44189
# -----------------------------------
# serial calc_performance called
# Episode 7800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.30
# Actor Loss: -0.0050, Critic Loss: 1.1661, Entropy: 0.5569
# best score so far: 5.44189
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.39
# Actor Loss: -0.0052, Critic Loss: 1.0137, Entropy: 0.5231
# best score so far: 5.44189
# -----------------------------------
# serial calc_performance called
# Episode 8200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0050, Critic Loss: 1.5124, Entropy: 0.5506
# best score so far: 5.54321
# -----------------------------------
# serial calc_performance called
# Episode 8400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.41
# Actor Loss: -0.0052, Critic Loss: 1.0143, Entropy: 0.5168
# best score so far: 5.54321
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.52
# Actor Loss: -0.0082, Critic Loss: 1.3763, Entropy: 0.5657
# best score so far: 5.54321
# -----------------------------------
# serial calc_performance called
# Episode 8800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.47
# Actor Loss: -0.0041, Critic Loss: 1.2297, Entropy: 0.5177
# best score so far: 5.54321
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0063, Critic Loss: 1.1376, Entropy: 0.5316
# best score so far: 5.54321
# -----------------------------------
# serial calc_performance called
# Episode 9200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.46
# Actor Loss: -0.0064, Critic Loss: 1.5192, Entropy: 0.4824
# best score so far: 5.54321
# -----------------------------------
# serial calc_performance called
# Episode 9400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.42
# Actor Loss: -0.0069, Critic Loss: 1.1808, Entropy: 0.4939
# best score so far: 5.54321
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0057, Critic Loss: 1.3084, Entropy: 0.4817
# best score so far: 5.59577
# -----------------------------------
# serial calc_performance called
# Episode 9800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0048, Critic Loss: 1.2451, Entropy: 0.4869
# best score so far: 5.64945
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0047, Critic Loss: 1.6521, Entropy: 0.4911
# best score so far: 5.64945
# -----------------------------------
# serial calc_performance called
# Episode 10200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.44
# Actor Loss: -0.0039, Critic Loss: 1.2295, Entropy: 0.4512
# best score so far: 5.64945
# -----------------------------------
# serial calc_performance called
# Episode 10400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.35
# Actor Loss: -0.0088, Critic Loss: 1.0327, Entropy: 0.4512
# best score so far: 5.64945
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.34
# Actor Loss: -0.0067, Critic Loss: 1.3156, Entropy: 0.4796
# best score so far: 5.64945
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0071, Critic Loss: 1.0964, Entropy: 0.4591
# best score so far: 5.64945
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0060, Critic Loss: 1.5005, Entropy: 0.5164
# best score so far: 5.64945
# -----------------------------------
# serial calc_performance called
# Episode 11200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0048, Critic Loss: 1.3280, Entropy: 0.3725
# best score so far: 5.64945
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0062, Critic Loss: 1.0748, Entropy: 0.3969
# best score so far: 5.64945
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0065, Critic Loss: 1.1379, Entropy: 0.4279
# best score so far: 5.65461
# -----------------------------------
# serial calc_performance called
# Episode 11800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0061, Critic Loss: 1.0640, Entropy: 0.4666
# best score so far: 5.65461
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.66
# Actor Loss: -0.0062, Critic Loss: 1.3335, Entropy: 0.4023
# best score so far: 5.66123
# -----------------------------------
# serial calc_performance called
# Episode 12200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.67
# Actor Loss: -0.0045, Critic Loss: 0.9916, Entropy: 0.4225
# best score so far: 5.67127
# -----------------------------------
# serial calc_performance called
# Episode 12400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.61
# Actor Loss: -0.0047, Critic Loss: 1.1934, Entropy: 0.4404
# best score so far: 5.67127
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.53
# Actor Loss: -0.0040, Critic Loss: 1.2750, Entropy: 0.4125
# best score so far: 5.67127
# -----------------------------------
# serial calc_performance called
# Episode 12800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.67
# Actor Loss: -0.0047, Critic Loss: 1.3415, Entropy: 0.3598
# best score so far: 5.67323
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.50
# Actor Loss: -0.0020, Critic Loss: 0.9912, Entropy: 0.3574
# best score so far: 5.67323
# -----------------------------------
# serial calc_performance called
# Episode 13200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0045, Critic Loss: 1.1028, Entropy: 0.3662
# best score so far: 5.68348
# -----------------------------------
# serial calc_performance called
# Episode 13400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0068, Critic Loss: 1.5581, Entropy: 0.3742
# best score so far: 5.68348
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0049, Critic Loss: 1.1434, Entropy: 0.3316
# best score so far: 5.68348
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0047, Critic Loss: 1.0710, Entropy: 0.3301
# best score so far: 5.68348
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0060, Critic Loss: 1.1544, Entropy: 0.3258
# best score so far: 5.68348
# -----------------------------------
# serial calc_performance called
# Episode 14200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.39
# Actor Loss: -0.0044, Critic Loss: 1.4700, Entropy: 0.3283
# best score so far: 5.68348
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.50
# Actor Loss: -0.0032, Critic Loss: 1.3099, Entropy: 0.3138
# best score so far: 5.68348
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0056, Critic Loss: 1.4050, Entropy: 0.3001
# best score so far: 5.68348
# -----------------------------------
# serial calc_performance called
# Episode 14800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0078, Critic Loss: 1.4348, Entropy: 0.3317
# best score so far: 5.68348
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0039, Critic Loss: 1.2797, Entropy: 0.3141
# best score so far: 5.68348
# -----------------------------------
# serial calc_performance called
# Episode 15200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0070, Critic Loss: 1.5913, Entropy: 0.3025
# best score so far: 5.69694
# -----------------------------------
# serial calc_performance called
# Episode 15400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0053, Critic Loss: 1.6625, Entropy: 0.3646
# best score so far: 5.72115
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0066, Critic Loss: 1.8076, Entropy: 0.3226
# best score so far: 5.72115
# -----------------------------------
# serial calc_performance called
# Episode 15800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.53
# Actor Loss: -0.0054, Critic Loss: 1.2265, Entropy: 0.3478
# best score so far: 5.72115
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0086, Critic Loss: 1.3129, Entropy: 0.3703
# best score so far: 5.72115
# -----------------------------------
# serial calc_performance called
# Episode 16200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0067, Critic Loss: 1.4238, Entropy: 0.3800
# best score so far: 5.72115
# -----------------------------------
# serial calc_performance called
# Episode 16400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.44
# Actor Loss: -0.0086, Critic Loss: 1.1558, Entropy: 0.3267
# best score so far: 5.72115
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0082, Critic Loss: 1.2628, Entropy: 0.3571
# best score so far: 5.72115
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0051, Critic Loss: 1.6167, Entropy: 0.3600
# best score so far: 5.72115
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0061, Critic Loss: 1.1461, Entropy: 0.3196
# best score so far: 5.72115
# -----------------------------------
# serial calc_performance called
# Episode 17200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.58
# Actor Loss: -0.0076, Critic Loss: 1.5281, Entropy: 0.3645
# best score so far: 5.72115
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0040, Critic Loss: 1.1482, Entropy: 0.3524
# best score so far: 5.75882
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0063, Critic Loss: 1.2826, Entropy: 0.3666
# best score so far: 5.75882
# -----------------------------------
# serial calc_performance called
# Episode 17800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.56
# Actor Loss: -0.0056, Critic Loss: 1.4081, Entropy: 0.3266
# best score so far: 5.75882
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0057, Critic Loss: 1.3969, Entropy: 0.3425
# best score so far: 5.75882
# -----------------------------------
# serial calc_performance called
# Episode 18200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0054, Critic Loss: 1.4492, Entropy: 0.3098
# best score so far: 5.75882
# -----------------------------------
# Kill rule triggered
# Kill rule triggered at episode 18200, stopping training.
# best Policy network found at episode 17400
# Training completed.
# Tuneset 1, Iteration 0: [ 5.758815  5.758645  5.72115   5.69694   5.683485  5.67867   5.678335
#   5.67521   5.673235  5.67127   5.661235  5.65464   5.65461   5.652585
#   5.64945   5.64356   5.642645  5.612255  5.599325  5.59787   5.597695
#   5.595775  5.59434   5.590855  5.588595  5.58605   5.58403   5.58233
#   5.580825  5.578045  5.5747    5.55767   5.55366   5.549765  5.54321
#   5.53735   5.531015  5.530125  5.520315  5.504895  5.497485  5.471275
#   5.46476   5.44615   5.441895  5.438935  5.43739   5.42109   5.41769
#   5.411905  5.38897   5.38733   5.353765  5.34388   5.3371    5.3299
#   5.296035  5.294945  5.27613   5.252265  5.24159   5.222815  5.195405
#   5.193275  5.18703   5.125425  5.10304   5.099705  5.09107   5.08142
#   5.057445  5.03403   5.026595  5.012355  5.01001   4.972095  4.82105
#   4.554835  4.38926   4.289245  4.267225  4.109065  3.81767   3.42474
#   2.794345  2.6726    2.212075  1.599505  1.046605 -0.051755 -3.918485]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 30, iteration: 1, seed: 543227
# env: metapop1
# device: cpu
# state size: (5, 4), action size: 10
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 10
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 60000
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -4.00
# Actor Loss: -0.0259, Critic Loss: 1.0553, Entropy: 4.9249
# best score so far: 0.00000
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 0.10
# Actor Loss: -0.0255, Critic Loss: 0.8424, Entropy: 4.1839
# best score so far: 0.09734
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.20
# Actor Loss: -0.0128, Critic Loss: 0.8240, Entropy: 3.5691
# best score so far: 1.19867
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.83
# Actor Loss: -0.0149, Critic Loss: 0.8258, Entropy: 3.0156
# best score so far: 1.83480
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.21
# Actor Loss: -0.0142, Critic Loss: 0.8020, Entropy: 2.9096
# best score so far: 2.20855
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.62
# Actor Loss: -0.0132, Critic Loss: 0.6980, Entropy: 2.5828
# best score so far: 2.62377
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.84
# Actor Loss: -0.0081, Critic Loss: 0.8992, Entropy: 2.3604
# best score so far: 2.84321
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.03
# Actor Loss: -0.0115, Critic Loss: 0.9604, Entropy: 2.2830
# best score so far: 3.03319
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.25
# Actor Loss: -0.0096, Critic Loss: 0.6685, Entropy: 2.2175
# best score so far: 3.24914
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.65
# Actor Loss: -0.0123, Critic Loss: 0.9523, Entropy: 2.1402
# best score so far: 3.65248
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.35
# Actor Loss: -0.0093, Critic Loss: 1.3113, Entropy: 1.9343
# best score so far: 4.35206
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.82
# Actor Loss: -0.0049, Critic Loss: 1.4878, Entropy: 1.6495
# best score so far: 4.82287
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.57
# Actor Loss: -0.0065, Critic Loss: 1.5121, Entropy: 1.6703
# best score so far: 4.82287
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.83
# Actor Loss: -0.0084, Critic Loss: 1.3088, Entropy: 1.4357
# best score so far: 4.82946
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.41
# Actor Loss: -0.0047, Critic Loss: 1.2529, Entropy: 1.2675
# best score so far: 4.82946
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.91
# Actor Loss: -0.0065, Critic Loss: 1.4088, Entropy: 1.3596
# best score so far: 4.91385
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.80
# Actor Loss: -0.0121, Critic Loss: 1.0726, Entropy: 1.3152
# best score so far: 4.91385
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.87
# Actor Loss: -0.0061, Critic Loss: 0.8834, Entropy: 1.1492
# best score so far: 4.91385
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.74
# Actor Loss: -0.0042, Critic Loss: 1.5066, Entropy: 1.1916
# best score so far: 4.91385
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.95
# Actor Loss: -0.0094, Critic Loss: 1.4082, Entropy: 1.1202
# best score so far: 4.95027
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.42
# Actor Loss: -0.0053, Critic Loss: 1.1303, Entropy: 0.9310
# best score so far: 5.42032
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.37
# Actor Loss: -0.0068, Critic Loss: 1.1372, Entropy: 0.9489
# best score so far: 5.42032
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.29
# Actor Loss: -0.0076, Critic Loss: 1.2736, Entropy: 0.9320
# best score so far: 5.42032
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.23
# Actor Loss: -0.0120, Critic Loss: 1.9808, Entropy: 0.8583
# best score so far: 5.42032
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.52
# Actor Loss: -0.0151, Critic Loss: 1.5307, Entropy: 0.9096
# best score so far: 5.51883
# -----------------------------------
# serial calc_performance called
# Episode 5200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.36
# Actor Loss: -0.0111, Critic Loss: 1.6922, Entropy: 0.8706
# best score so far: 5.51883
# -----------------------------------
# serial calc_performance called
# Episode 5400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.52
# Actor Loss: -0.0057, Critic Loss: 1.0582, Entropy: 0.7386
# best score so far: 5.51883
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.52
# Actor Loss: -0.0115, Critic Loss: 1.8564, Entropy: 0.6954
# best score so far: 5.52059
# -----------------------------------
# serial calc_performance called
# Episode 5800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.57
# Actor Loss: -0.0050, Critic Loss: 1.5683, Entropy: 0.6563
# best score so far: 5.56591
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 5.48
# Actor Loss: -0.0112, Critic Loss: 1.3969, Entropy: 0.6585
# best score so far: 5.56591
# -----------------------------------
# serial calc_performance called
# Episode 6200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.49
# Actor Loss: -0.0091, Critic Loss: 1.3532, Entropy: 0.6437
# best score so far: 5.56591
# -----------------------------------
# serial calc_performance called
# Episode 6400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.44
# Actor Loss: -0.0029, Critic Loss: 1.3775, Entropy: 0.6068
# best score so far: 5.56591
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.50
# Actor Loss: -0.0093, Critic Loss: 1.3712, Entropy: 0.5981
# best score so far: 5.56591
# -----------------------------------
# serial calc_performance called
# Episode 6800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0102, Critic Loss: 1.1423, Entropy: 0.5929
# best score so far: 5.56591
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.46
# Actor Loss: -0.0068, Critic Loss: 0.9860, Entropy: 0.5870
# best score so far: 5.56591
# -----------------------------------
# serial calc_performance called
# Episode 7200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.49
# Actor Loss: -0.0088, Critic Loss: 1.3346, Entropy: 0.5881
# best score so far: 5.56591
# -----------------------------------
# serial calc_performance called
# Episode 7400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0097, Critic Loss: 1.5911, Entropy: 0.5338
# best score so far: 5.57497
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.56
# Actor Loss: -0.0065, Critic Loss: 1.4421, Entropy: 0.5159
# best score so far: 5.57497
# -----------------------------------
# serial calc_performance called
# Episode 7800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.55
# Actor Loss: -0.0096, Critic Loss: 1.2216, Entropy: 0.4520
# best score so far: 5.57497
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.33
# Actor Loss: -0.0080, Critic Loss: 1.4658, Entropy: 0.5176
# best score so far: 5.57497
# -----------------------------------
# serial calc_performance called
# Episode 8200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.34
# Actor Loss: -0.0110, Critic Loss: 1.6839, Entropy: 0.4465
# best score so far: 5.57497
# -----------------------------------
# serial calc_performance called
# Episode 8400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.56
# Actor Loss: -0.0101, Critic Loss: 1.5513, Entropy: 0.4589
# best score so far: 5.57497
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.65
# Actor Loss: -0.0068, Critic Loss: 1.2874, Entropy: 0.4823
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 8800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0070, Critic Loss: 1.5746, Entropy: 0.4851
# best score so far: 5.64564
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.54
# Actor Loss: -0.0081, Critic Loss: 1.2980, Entropy: 0.4742
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 9200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.32
# Actor Loss: -0.0064, Critic Loss: 1.3556, Entropy: 0.4593
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 9400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.39
# Actor Loss: -0.0087, Critic Loss: 1.0333, Entropy: 0.4472
# best score so far: 5.64564
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.45
# Actor Loss: -0.0034, Critic Loss: 1.3450, Entropy: 0.3878
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 9800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.44
# Actor Loss: -0.0071, Critic Loss: 1.2707, Entropy: 0.4471
# best score so far: 5.64564
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.49
# Actor Loss: -0.0058, Critic Loss: 1.5108, Entropy: 0.4850
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 10200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.56
# Actor Loss: -0.0045, Critic Loss: 1.1596, Entropy: 0.4557
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 10400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.57
# Actor Loss: -0.0070, Critic Loss: 1.2059, Entropy: 0.4391
# best score so far: 5.64564
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.61
# Actor Loss: -0.0061, Critic Loss: 1.3574, Entropy: 0.4693
# best score so far: 5.64564
# -----------------------------------
# serial calc_performance called
# Episode 10800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.81
# Actor Loss: -0.0074, Critic Loss: 1.5096, Entropy: 0.4183
# best score so far: 5.81362
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.59
# Actor Loss: -0.0052, Critic Loss: 1.4109, Entropy: 0.4460
# best score so far: 5.81362
# -----------------------------------
# serial calc_performance called
# Episode 11200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.74
# Actor Loss: -0.0107, Critic Loss: 1.5609, Entropy: 0.4603
# best score so far: 5.81362
# -----------------------------------
# serial calc_performance called
# Episode 11400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0063, Critic Loss: 1.6313, Entropy: 0.4418
# best score so far: 5.81362
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0097, Critic Loss: 1.6468, Entropy: 0.3783
# best score so far: 5.81362
# -----------------------------------
# serial calc_performance called
# Episode 11800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.79
# Actor Loss: -0.0090, Critic Loss: 1.4791, Entropy: 0.4173
# best score so far: 5.81362
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.91
# Actor Loss: -0.0067, Critic Loss: 1.4717, Entropy: 0.4086
# best score so far: 5.90918
# -----------------------------------
# serial calc_performance called
# Episode 12200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.71
# Actor Loss: -0.0072, Critic Loss: 1.4330, Entropy: 0.3806
# best score so far: 5.90918
# -----------------------------------
# serial calc_performance called
# Episode 12400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.91
# Actor Loss: -0.0049, Critic Loss: 1.6099, Entropy: 0.3857
# best score so far: 5.91381
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.80
# Actor Loss: -0.0079, Critic Loss: 1.3501, Entropy: 0.3673
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 12800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.71
# Actor Loss: -0.0093, Critic Loss: 1.6214, Entropy: 0.3392
# best score so far: 5.91381
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0109, Critic Loss: 1.3718, Entropy: 0.3427
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 13200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0073, Critic Loss: 1.2358, Entropy: 0.3587
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 13400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.72
# Actor Loss: -0.0061, Critic Loss: 1.5541, Entropy: 0.3421
# best score so far: 5.91381
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0083, Critic Loss: 1.3572, Entropy: 0.3534
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 13800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0060, Critic Loss: 1.0958, Entropy: 0.3243
# best score so far: 5.91381
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.83
# Actor Loss: -0.0083, Critic Loss: 1.8253, Entropy: 0.3279
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 14200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0063, Critic Loss: 1.4515, Entropy: 0.3425
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 14400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.83
# Actor Loss: -0.0051, Critic Loss: 1.6389, Entropy: 0.3493
# best score so far: 5.91381
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.73
# Actor Loss: -0.0090, Critic Loss: 1.1354, Entropy: 0.4035
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 14800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.74
# Actor Loss: -0.0063, Critic Loss: 1.4005, Entropy: 0.3888
# best score so far: 5.91381
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.62
# Actor Loss: -0.0062, Critic Loss: 1.0836, Entropy: 0.3246
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 15200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.87
# Actor Loss: -0.0040, Critic Loss: 1.4624, Entropy: 0.3415
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 15400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.76
# Actor Loss: -0.0061, Critic Loss: 1.5459, Entropy: 0.3979
# best score so far: 5.91381
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.88
# Actor Loss: -0.0061, Critic Loss: 1.6108, Entropy: 0.3872
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 15800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.64
# Actor Loss: -0.0077, Critic Loss: 1.5693, Entropy: 0.4084
# best score so far: 5.91381
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.71
# Actor Loss: -0.0134, Critic Loss: 1.6752, Entropy: 0.4583
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 16200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.42
# Actor Loss: -0.0093, Critic Loss: 1.3663, Entropy: 0.5042
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 16400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0060, Critic Loss: 1.5676, Entropy: 0.4594
# best score so far: 5.91381
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.70
# Actor Loss: -0.0091, Critic Loss: 1.5615, Entropy: 0.4482
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 16800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.60
# Actor Loss: -0.0078, Critic Loss: 1.8508, Entropy: 0.4609
# best score so far: 5.91381
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.63
# Actor Loss: -0.0063, Critic Loss: 1.5468, Entropy: 0.4335
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 17200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.73
# Actor Loss: -0.0089, Critic Loss: 1.5328, Entropy: 0.4029
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 17400,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.89
# Actor Loss: -0.0074, Critic Loss: 1.8574, Entropy: 0.3950
# best score so far: 5.91381
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17600,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.77
# Actor Loss: -0.0075, Critic Loss: 1.4364, Entropy: 0.3816
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 17800,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.78
# Actor Loss: -0.0060, Critic Loss: 1.4226, Entropy: 0.3943
# best score so far: 5.91381
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.68
# Actor Loss: -0.0062, Critic Loss: 1.6427, Entropy: 0.4022
# best score so far: 5.91381
# -----------------------------------
# serial calc_performance called
# Episode 18200,LR: A0.000133/C0.0001/E0.0001 Avg Performance: 5.85
# Actor Loss: -0.0055, Critic Loss: 1.4398, Entropy: 0.3481
# best score so far: 5.91381
# -----------------------------------
# Kill rule triggered
# Kill rule triggered at episode 18200, stopping training.
# best Policy network found at episode 12400
# Training completed.
# Tuneset 1, Iteration 1: [ 5.913815  5.909175  5.889095  5.88061   5.86806   5.85484   5.83217
#   5.827815  5.81362   5.80288   5.78984   5.783375  5.774895  5.763675
#   5.740065  5.73799   5.730555  5.7294    5.723445  5.72314   5.71221
#   5.709995  5.708565  5.703245  5.702375  5.701495  5.69607   5.678045
#   5.677965  5.64564   5.64273   5.6341    5.63254   5.628145  5.624425
#   5.605005  5.60335   5.601005  5.59293   5.57497   5.574395  5.56591
#   5.563315  5.5603    5.556485  5.55432   5.54073   5.5399    5.536895
#   5.52059   5.51883   5.51737   5.501085  5.493935  5.49235   5.48928
#   5.475385  5.45737   5.448455  5.437625  5.437105  5.42032   5.41781
#   5.38525   5.37431   5.364435  5.34369   5.3252    5.31866   5.290905
#   5.23387   4.950275  4.91385   4.87115   4.829455  4.822875  4.796065
#   4.74049   4.565845  4.40988   4.352065  3.65248   3.249145  3.033185
#   2.843215  2.62377   2.20855   1.8348    1.198665  0.09734  -3.99892 ]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 30, iteration: 2, seed: 814906
# env: metapop1
# device: cpu
# state size: (5, 4), action size: 10
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0004, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.003, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 10
# evaluation interval: 200, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 60000
# serial calc_performance called
# Episode 200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: -3.55
# Actor Loss: -0.0213, Critic Loss: 0.9013, Entropy: 4.8486
# best score so far: 0.00000
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 0.11
# Actor Loss: -0.0220, Critic Loss: 0.7437, Entropy: 4.0819
# best score so far: 0.11019
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.16
# Actor Loss: -0.0123, Critic Loss: 0.8552, Entropy: 3.5092
# best score so far: 1.16226
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 1.66
# Actor Loss: -0.0142, Critic Loss: 1.0165, Entropy: 3.1916
# best score so far: 1.65509
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.13
# Actor Loss: -0.0183, Critic Loss: 1.2253, Entropy: 2.8747
# best score so far: 2.12781
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.37
# Actor Loss: -0.0100, Critic Loss: 0.8591, Entropy: 2.9924
# best score so far: 2.36711
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.95
# Actor Loss: -0.0150, Critic Loss: 1.0769, Entropy: 2.8469
# best score so far: 2.95241
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 2.97
# Actor Loss: -0.0065, Critic Loss: 1.0987, Entropy: 2.6359
# best score so far: 2.96882
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.58
# Actor Loss: -0.0087, Critic Loss: 1.2629, Entropy: 2.4387
# best score so far: 3.57833
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.83
# Actor Loss: -0.0052, Critic Loss: 1.1224, Entropy: 2.2628
# best score so far: 3.82845
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 3.98
# Actor Loss: -0.0091, Critic Loss: 1.1572, Entropy: 2.1774
# best score so far: 3.98335
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.50
# Actor Loss: -0.0111, Critic Loss: 1.3267, Entropy: 1.9529
# best score so far: 4.49717
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2600,LR: A0.0004/C0.0003/E0.0003 Avg Performance: 4.18
# ...
# OSError: [Errno 22] Invalid argument
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hyun\AppData\Local\Temp\ipykernel_35448\1377199381.py", line 30, in <module>
#     _, scores, training_info = agent.train()
#   File "g:\My Drive\research\interpretability\codes\PPO2.py", line 279, in train
#   File "g:\My Drive\research\interpretability\codes\setup_logger.py", line 31, in write
# Message: 'Actor Loss: -0.0065, Critic Loss: 1.2426, Entropy: 1.5294'
# Arguments: ()
# Actor Loss: -0.0065, Critic Loss: 1.2426, Entropy: 1.5294
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\Hyun\anaconda3\Lib\logging\__init__.py", line 1164, in emit
#     self.flush()
#   File "c:\Users\Hyun\anaconda3\Lib\logging\__init__.py", line 1144, in flush
#     self.stream.flush()
# OSError: [Errno 22] Invalid argument
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hyun\AppData\Local\Temp\ipykernel_35448\1377199381.py", line 30, in <module>
#     _, scores, training_info = agent.train()
#   File "g:\My Drive\research\interpretability\codes\PPO2.py", line 280, in train
#   File "g:\My Drive\research\interpretability\codes\setup_logger.py", line 31, in write
# Message: 'best score so far: 4.75460'
# Arguments: ()
# best score so far: 4.75460
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\Hyun\anaconda3\Lib\logging\__init__.py", line 1164, in emit
#     self.flush()
#   File "c:\Users\Hyun\anaconda3\Lib\logging\__init__.py", line 1144, in flush
#     self.stream.flush()
# OSError: [Errno 22] Invalid argument
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hyun\AppData\Local\Temp\ipykernel_35448\1377199381.py", line 30, in <module>
#     _, scores, training_info = agent.train()
#   File "g:\My Drive\research\interpretability\codes\PPO2.py", line 281, in train
#   File "g:\My Drive\research\interpretability\codes\setup_logger.py", line 31, in write
# Message: '-----------------------------------'
# Arguments: ()
# -----------------------------------
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\Hyun\anaconda3\Lib\logging\__init__.py", line 1164, in emit
#     self.flush()
#   File "c:\Users\Hyun\anaconda3\Lib\logging\__init__.py", line 1144, in flush
#     self.stream.flush()
# OSError: [Errno 22] Invalid argument
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\Hyun\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hyun\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hyun\AppData\Local\Temp\ipykernel_35448\1377199381.py", line 30, in <module>
#     _, scores, training_info = agent.train()
#   File "g:\My Drive\research\interpretability\codes\PPO2.py", line 262, in train
#     inttestscore = calc_performance(self.env,self.device,self.rms,1,self.agent.actorcritic,self.performance_sampleN,self.max_steps,self.deterministic_eval)
#   File "g:\My Drive\research\interpretability\codes\calc_performance3.py", line 11, in calc_performance
#     print('serial calc_performance called')
#   File "g:\My Drive\research\interpretability\codes\setup_logger.py", line 31, in write
#     logger.info(message.strip())
# Message: 'serial calc_performance called'
# Arguments: ()
# serial calc_performance called
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 30
#      28 meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
#      29 agent = PPO2(env, paramdf,meta)
# ---> 30 _, scores, training_info = agent.train()
#      31 best_scores.append(np.max(scores))
#      32 seeds.append(seednum)
#
# File g:\My Drive\research\interpretability\codes\PPO2.py:268, in PPO2.train(self)
#     266 best_score_epi = i_episode
#     267 best_score = inttestscore
# --> 268 self.agent.save_models(savepath)
#     269 # save the running mean and sd/var as well for this episode in pickle
#     270 if self.standardize:
#
# File g:\My Drive\research\interpretability\codes\ppoagent2.py:83, in PPOAgent2.save_models(self, path)
#      82 def save_models(self,path):
# ---> 83     self.save_checkpoint(self.actorcritic, path)
#
# File g:\My Drive\research\interpretability\codes\ppoagent2.py:80, in PPOAgent2.save_checkpoint(self, network, path)
#      79 def save_checkpoint(self, network,path):
# ---> 80     T.save(network, path)
#
# File c:\Users\Hyun\anaconda3\Lib\site-packages\torch\serialization.py:849, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     846 _check_save_filelike(f)
#     848 if _use_new_zipfile_serialization:
# --> 849     with _open_zipfile_writer(f) as opened_zipfile:
#     850         _save(
#     851             obj,
#     852             opened_zipfile,
#    (...)
#     855             _disable_byteorder_record,
#     856         )
#     857         return
#
# File c:\Users\Hyun\anaconda3\Lib\site-packages\torch\serialization.py:716, in _open_zipfile_writer(name_or_buffer)
#     714 else:
#     715     container = _open_zipfile_writer_buffer
# --> 716 return container(name_or_buffer)
#
# File c:\Users\Hyun\anaconda3\Lib\site-packages\torch\serialization.py:687, in _open_zipfile_writer_file.__init__(self, name)
#     685     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     686 else:
# --> 687     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory ./PPO_results/seed814906_paramid30 does not exist.
