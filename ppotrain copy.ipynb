# %%
# value iteration test
import pandas as pd
from metapop_value_iteration import build_optimal_controller_fully_observable
from metapop1 import metapop1

filename = 'envsetting.csv'
settings_df = pd.read_csv(filename)
id = 5
settings = settings_df.iloc[id].to_dict()
env = metapop1(settings)
print(f"Computing the policy with value iteration algorithm with settingID {id}: {settings}")
ctrl = build_optimal_controller_fully_observable(env, kR=settings['kR'], kS=settings['kS'])
# save as pickle
import pickle
with open(f'./value_iteration/VI_controller_setting{id}.pkl', 'wb') as f:
    pickle.dump(ctrl, f)
# Out:
# Computing the policy with value iteration algorithm with settingID 5: {'ID': 5, 'partial_observability': 0, 'patchnum': 4, 'action_portfolio': 0, 'survey_is_action': 0, 'dispersal_regime': 0, 'terminal_penalty': 0, 'dispersal_type': 'uniform', 'dispersal_ID': 0, 'paramsetID': 1, 'kR': 1, 'kS': 8, 'dim2state': 0, 'dim2state_with_C': 0, 'note': 'n=4 MDP scaling up from here'}
# Computing V for t=29...
# Computing V for t=28...
# Computing V for t=27...
# Computing V for t=26...
# Computing V for t=25...
# Computing V for t=24...
# Computing V for t=23...
# Computing V for t=22...
# Computing V for t=21...
# Computing V for t=20...
# Computing V for t=19...
# Computing V for t=18...
# Computing V for t=17...
# Computing V for t=16...
# Computing V for t=15...
# Computing V for t=14...
# Computing V for t=13...
# Computing V for t=12...
# Computing V for t=11...
# Computing V for t=10...
# Computing V for t=9...
# Computing V for t=8...
# Computing V for t=7...
# Computing V for t=6...
# Computing V for t=5...
# Computing V for t=4...
# Computing V for t=3...
# Computing V for t=2...
# Computing V for t=1...
# Computing V for t=0...

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 11 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# Using cpu device
# paramID: 11, iteration: 0, seed: 438788
# env: metapop1
# device: cpu
# state size: 10, action size: 8
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# -------------------------------------------------------
# --------------------------------------------------------
# serial calc_performance called

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 7 # test id = 4
    iteration_num = 2
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 7, iteration: 0, seed: 627881
# env: metapop1
# device: cpu
# state size: (20, 4), action size: 40
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0005, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 8 # test id = 4
    iteration_num = 2
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 8, iteration: 0, seed: 517275
# env: metapop1
# device: cpu
# state size: (20, 4), action size: 40
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0005, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 10
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 5000
# serial calc_performance called
# Episode 100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 6.83
# Actor Loss: -0.0042, Critic Loss: 0.2202, Entropy: 25.2307
# -----------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.27
# Actor Loss: -0.0120, Critic Loss: 0.1511, Entropy: 24.8843
# -----------------------------------
# serial calc_performance called
# Episode 300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.70
# Actor Loss: -0.0114, Critic Loss: 0.1767, Entropy: 24.4794
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.12
# Actor Loss: -0.0141, Critic Loss: 0.2212, Entropy: 24.3078
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.62
# Actor Loss: -0.0121, Critic Loss: 0.1394, Entropy: 23.5309
# -----------------------------------
# serial calc_performance called
# Episode 600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.19
# Actor Loss: -0.0114, Critic Loss: 0.2942, Entropy: 22.9021
# -----------------------------------
# serial calc_performance called
# Episode 700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.72
# Actor Loss: -0.0126, Critic Loss: 0.2413, Entropy: 22.1084
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.96
# Actor Loss: -0.0110, Critic Loss: 0.2437, Entropy: 21.7745
# -----------------------------------
# serial calc_performance called
# Episode 900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.39
# Actor Loss: -0.0145, Critic Loss: 0.3161, Entropy: 20.7627
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.43
# Actor Loss: -0.0168, Critic Loss: 0.1754, Entropy: 20.7556
# -----------------------------------
# serial calc_performance called
# Episode 1100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.64
# Actor Loss: -0.0108, Critic Loss: 0.3894, Entropy: 20.4537
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.94
# Actor Loss: -0.0123, Critic Loss: 0.2617, Entropy: 20.2128
# -----------------------------------
# serial calc_performance called
# Episode 1300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.26
# Actor Loss: -0.0149, Critic Loss: 0.3309, Entropy: 19.1186
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.53
# Actor Loss: -0.0097, Critic Loss: 0.3294, Entropy: 18.5508
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.83
# Actor Loss: -0.0158, Critic Loss: 0.2379, Entropy: 18.1772
# -----------------------------------
# serial calc_performance called
# Episode 1600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.10
# Actor Loss: -0.0129, Critic Loss: 0.4417, Entropy: 17.7104
# -----------------------------------
# serial calc_performance called
# Episode 1700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.20
# Actor Loss: -0.0102, Critic Loss: 0.3710, Entropy: 17.2637
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.23
# Actor Loss: -0.0127, Critic Loss: 0.1782, Entropy: 16.5184
# -----------------------------------
# serial calc_performance called
# Episode 1900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.42
# Actor Loss: -0.0074, Critic Loss: 0.5273, Entropy: 16.1959
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.65
# Actor Loss: -0.0201, Critic Loss: 0.2262, Entropy: 15.6957
# -----------------------------------
# serial calc_performance called
# Episode 2100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 12.95
# Actor Loss: -0.0138, Critic Loss: 0.4965, Entropy: 14.9787
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.14
# Actor Loss: -0.0148, Critic Loss: 0.3740, Entropy: 14.2053
# -----------------------------------
# serial calc_performance called
# Episode 2300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.27
# Actor Loss: -0.0151, Critic Loss: 0.1404, Entropy: 13.9682
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.32
# Actor Loss: -0.0070, Critic Loss: 0.5712, Entropy: 13.7516
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.53
# Actor Loss: -0.0152, Critic Loss: 0.2329, Entropy: 12.7977
# -----------------------------------
# serial calc_performance called
# Episode 2600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.62
# Actor Loss: -0.0055, Critic Loss: 0.5044, Entropy: 12.6214
# -----------------------------------
# serial calc_performance called
# Episode 2700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.74
# Actor Loss: -0.0100, Critic Loss: 0.4371, Entropy: 12.1481
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.86
# Actor Loss: -0.0166, Critic Loss: 0.1697, Entropy: 11.5687
# -----------------------------------
# serial calc_performance called
# Episode 2900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.82
# Actor Loss: -0.0076, Critic Loss: 0.6037, Entropy: 11.3932
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.86
# Actor Loss: -0.0124, Critic Loss: 0.3831, Entropy: 11.7160
# -----------------------------------
# serial calc_performance called
# Episode 3100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.06
# Actor Loss: -0.0153, Critic Loss: 0.1372, Entropy: 10.7867
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.19
# Actor Loss: -0.0120, Critic Loss: 0.5470, Entropy: 10.3163
# -----------------------------------
# serial calc_performance called
# Episode 3300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.31
# Actor Loss: -0.0152, Critic Loss: 0.2562, Entropy: 9.7340
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.42
# Actor Loss: -0.0091, Critic Loss: 0.6282, Entropy: 9.3554
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.49
# Actor Loss: -0.0119, Critic Loss: 0.3689, Entropy: 8.9726
# -----------------------------------
# serial calc_performance called
# Episode 3600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.55
# Actor Loss: -0.0197, Critic Loss: 0.1646, Entropy: 8.6106
# -----------------------------------
# serial calc_performance called
# Episode 3700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.57
# Actor Loss: -0.0088, Critic Loss: 0.5825, Entropy: 9.0121
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.58
# Actor Loss: -0.0113, Critic Loss: 0.2240, Entropy: 8.7172
# -----------------------------------
# serial calc_performance called
# Episode 3900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.63
# Actor Loss: -0.0107, Critic Loss: 0.6476, Entropy: 8.5776
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.72
# Actor Loss: -0.0084, Critic Loss: 0.3523, Entropy: 8.1910
# -----------------------------------
# serial calc_performance called
# Episode 4100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.74
# Actor Loss: -0.0116, Critic Loss: 0.1377, Entropy: 7.8400
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.78
# Actor Loss: -0.0065, Critic Loss: 0.6213, Entropy: 7.5874
# -----------------------------------
# serial calc_performance called
# Episode 4300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.88
# Actor Loss: -0.0156, Critic Loss: 0.3831, Entropy: 7.3038
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.88
# Actor Loss: -0.0081, Critic Loss: 0.4335, Entropy: 7.3495
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.87
# Actor Loss: -0.0089, Critic Loss: 0.5944, Entropy: 7.2054
# -----------------------------------
# serial calc_performance called
# Episode 4600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.94
# Actor Loss: -0.0092, Critic Loss: 0.1677, Entropy: 6.9367
# -----------------------------------
# serial calc_performance called
# Episode 4700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.97
# Actor Loss: -0.0094, Critic Loss: 0.6787, Entropy: 6.5541
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.03
# Actor Loss: -0.0109, Critic Loss: 0.3457, Entropy: 6.4302
# -----------------------------------
# serial calc_performance called
# Episode 4900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.07
# Actor Loss: -0.0078, Critic Loss: 0.4344, Entropy: 6.5085
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.08
# Actor Loss: -0.0103, Critic Loss: 0.4835, Entropy: 6.2912
# -----------------------------------
# best Policy network found at episode 5000
# Training completed.
# Tuneset 1, Iteration 0: [15.083248 15.06775  15.033606 14.970692 14.941756 14.87723  14.875612
#  14.866882 14.78175  14.738944 14.721981 14.634713 14.579729 14.571914
#  14.548782 14.486207 14.417971 14.310167 14.190447 14.056886 13.864712
#  13.859547 13.818046 13.744522 13.623093 13.53406  13.317757 13.268782
#  13.139546 12.954333 12.654026 12.420398 12.225521 12.196164 12.099237
#  11.825556 11.533658 11.261959 10.939747 10.641685 10.430654 10.394024
#   9.955853  9.724681  9.193655  8.616765  8.121964  7.69526   7.267659
#   6.827811]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 8, iteration: 1, seed: 338020
# env: metapop1
# device: cpu
# state size: (20, 4), action size: 40
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0005, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 1024, minibatch size: 64, n_epochs: 10
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 5000
# serial calc_performance called
# Episode 100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.12
# Actor Loss: -0.0114, Critic Loss: 0.2955, Entropy: 24.8750
# -----------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.48
# Actor Loss: -0.0072, Critic Loss: 0.1717, Entropy: 23.6590
# -----------------------------------
# serial calc_performance called
# Episode 300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.03
# Actor Loss: -0.0160, Critic Loss: 0.2051, Entropy: 23.2745
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.56
# Actor Loss: -0.0171, Critic Loss: 0.2438, Entropy: 22.6023
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.92
# Actor Loss: -0.0095, Critic Loss: 0.1280, Entropy: 22.3962
# -----------------------------------
# serial calc_performance called
# Episode 600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.32
# Actor Loss: -0.0056, Critic Loss: 0.2884, Entropy: 22.0810
# -----------------------------------
# serial calc_performance called
# Episode 700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.77
# Actor Loss: -0.0140, Critic Loss: 0.2535, Entropy: 21.3297
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.00
# Actor Loss: -0.0088, Critic Loss: 0.2506, Entropy: 21.0354
# -----------------------------------
# serial calc_performance called
# Episode 900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.45
# Actor Loss: -0.0144, Critic Loss: 0.3700, Entropy: 20.4743
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.90
# Actor Loss: -0.0153, Critic Loss: 0.1541, Entropy: 20.1024
# -----------------------------------
# serial calc_performance called
# Episode 1100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.34
# Actor Loss: -0.0093, Critic Loss: 0.4838, Entropy: 19.1033
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.67
# Actor Loss: -0.0118, Critic Loss: 0.2362, Entropy: 18.1760
# -----------------------------------
# serial calc_performance called
# Episode 1300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.95
# Actor Loss: -0.0138, Critic Loss: 0.3122, Entropy: 17.3855
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.88
# Actor Loss: -0.0130, Critic Loss: 0.3975, Entropy: 17.7309
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.02
# Actor Loss: -0.0082, Critic Loss: 0.2620, Entropy: 17.5186
# -----------------------------------
# serial calc_performance called
# Episode 1600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.16
# Actor Loss: -0.0056, Critic Loss: 0.4285, Entropy: 17.1130
# -----------------------------------
# serial calc_performance called
# Episode 1700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.33
# Actor Loss: -0.0083, Critic Loss: 0.3163, Entropy: 16.5756
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.55
# Actor Loss: -0.0124, Critic Loss: 0.1567, Entropy: 16.1625
# -----------------------------------
# serial calc_performance called
# Episode 1900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.90
# Actor Loss: -0.0041, Critic Loss: 0.4929, Entropy: 14.9921
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.10
# Actor Loss: -0.0039, Critic Loss: 0.2740, Entropy: 14.5687
# -----------------------------------
# serial calc_performance called
# Episode 2100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.39
# Actor Loss: -0.0090, Critic Loss: 0.5160, Entropy: 13.5981
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.62
# Actor Loss: -0.0163, Critic Loss: 0.4388, Entropy: 12.8695
# -----------------------------------
# serial calc_performance called
# Episode 2300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.72
# Actor Loss: -0.0151, Critic Loss: 0.1592, Entropy: 12.5575
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 13.94
# Actor Loss: -0.0138, Critic Loss: 0.6319, Entropy: 11.9606
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.02
# Actor Loss: -0.0154, Critic Loss: 0.3073, Entropy: 11.0296
# -----------------------------------
# serial calc_performance called
# Episode 2600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.18
# Actor Loss: -0.0086, Critic Loss: 0.5484, Entropy: 10.8603
# -----------------------------------
# serial calc_performance called
# Episode 2700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.38
# Actor Loss: -0.0132, Critic Loss: 0.4919, Entropy: 10.2156
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.44
# Actor Loss: -0.0112, Critic Loss: 0.1332, Entropy: 9.6388
# -----------------------------------
# serial calc_performance called
# Episode 2900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.46
# Actor Loss: -0.0139, Critic Loss: 0.6031, Entropy: 9.5906
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.50
# Actor Loss: -0.0113, Critic Loss: 0.4541, Entropy: 9.4473
# -----------------------------------
# serial calc_performance called
# Episode 3100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.54
# Actor Loss: -0.0121, Critic Loss: 0.1757, Entropy: 9.1632
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.59
# Actor Loss: -0.0086, Critic Loss: 0.6495, Entropy: 9.0743
# -----------------------------------
# serial calc_performance called
# Episode 3300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.63
# Actor Loss: -0.0181, Critic Loss: 0.2341, Entropy: 8.5847
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.69
# Actor Loss: -0.0093, Critic Loss: 0.6576, Entropy: 8.2405
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.81
# Actor Loss: -0.0122, Critic Loss: 0.4123, Entropy: 7.6548
# -----------------------------------
# serial calc_performance called
# Episode 3600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.98
# Actor Loss: -0.0090, Critic Loss: 0.1330, Entropy: 7.4659
# -----------------------------------
# serial calc_performance called
# Episode 3700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.04
# Actor Loss: -0.0100, Critic Loss: 0.5767, Entropy: 6.6687
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.13
# Actor Loss: -0.0109, Critic Loss: 0.1830, Entropy: 6.4490
# -----------------------------------
# serial calc_performance called
# Episode 3900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.13
# Actor Loss: -0.0110, Critic Loss: 0.6632, Entropy: 5.9212
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.12
# Actor Loss: -0.0149, Critic Loss: 0.3872, Entropy: 6.2053
# -----------------------------------
# serial calc_performance called
# Episode 4100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.14
# Actor Loss: -0.0111, Critic Loss: 0.1840, Entropy: 6.1508
# -----------------------------------
# serial calc_performance called
# Episode 4200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.13
# Actor Loss: -0.0128, Critic Loss: 0.6232, Entropy: 6.2675
# -----------------------------------
# serial calc_performance called
# Episode 4300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.09
# Actor Loss: -0.0060, Critic Loss: 0.3704, Entropy: 6.1723
# -----------------------------------
# serial calc_performance called
# Episode 4400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.12
# Actor Loss: -0.0054, Critic Loss: 0.4056, Entropy: 6.0173
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.16
# Actor Loss: -0.0101, Critic Loss: 0.5781, Entropy: 5.7368
# -----------------------------------
# serial calc_performance called
# Episode 4600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.19
# Actor Loss: -0.0099, Critic Loss: 0.1768, Entropy: 5.4212
# -----------------------------------
# serial calc_performance called
# Episode 4700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.19
# Actor Loss: -0.0090, Critic Loss: 0.6737, Entropy: 5.6232
# -----------------------------------
# serial calc_performance called
# Episode 4800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.16
# Actor Loss: -0.0104, Critic Loss: 0.2823, Entropy: 5.5534
# -----------------------------------
# serial calc_performance called
# Episode 4900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.22
# Actor Loss: -0.0090, Critic Loss: 0.4089, Entropy: 5.3850
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.23
# Actor Loss: -0.0100, Critic Loss: 0.5529, Entropy: 5.6995
# -----------------------------------
# best Policy network found at episode 5000
# Training completed.
# Tuneset 1, Iteration 1: [15.229666 15.220638 15.194165 15.192429 15.16484  15.16409  15.141959
#  15.134891 15.130947 15.125866 15.12087  15.117447 15.090089 15.036279
#  14.975097 14.813898 14.691432 14.630715 14.588313 14.538538 14.496856
#  14.455862 14.439613 14.377169 14.184118 14.015752 13.939534 13.724499
#  13.624144 13.394834 13.095571 12.901124 12.552544 12.333917 12.158545
#  12.01618  11.953134 11.880961 11.672551 11.340668 10.898589 10.446379
#   9.995831  9.77158   9.324009  8.919556  8.56118   8.030507  7.483684
#   7.122744]
# seed  best_score
# 1  338020   15.229666
# 0  517275   15.083248

# %%
# PPO2 training script
from PPO2 import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
if __name__ == "__main__":
    paramid = 9 # test id = 4
    iteration_num = 2
    hyperparameterization_set_filename = './hyperparamsets/PPO2hyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO2(env, paramdf,meta)
            _, scores, training_info = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
                
            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 9, iteration: 0, seed: 156992
# env: metapop1
# device: cpu
# state size: (20, 4), action size: 40
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0005, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.14
# Actor Loss: -0.0131, Critic Loss: 0.4834, Entropy: 13.8321
# -----------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.99
# Actor Loss: -0.0183, Critic Loss: 0.1723, Entropy: 13.7244
# -----------------------------------
# serial calc_performance called
# Episode 300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.94
# Actor Loss: -0.0231, Critic Loss: 0.3761, Entropy: 13.3288
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.72
# Actor Loss: -0.0163, Critic Loss: 0.3987, Entropy: 12.7206
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.40
# Actor Loss: -0.0214, Critic Loss: 0.1547, Entropy: 12.1003
# -----------------------------------
# serial calc_performance called
# Episode 600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.94
# Actor Loss: -0.0187, Critic Loss: 0.6844, Entropy: 11.2475
# -----------------------------------
# serial calc_performance called
# Episode 700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.52
# Actor Loss: -0.0158, Critic Loss: 0.3229, Entropy: 10.5997
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.78
# Actor Loss: -0.0186, Critic Loss: 0.4677, Entropy: 10.4797
# -----------------------------------
# serial calc_performance called
# Episode 900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.21
# Actor Loss: -0.0207, Critic Loss: 0.6121, Entropy: 9.7099
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.70
# Actor Loss: -0.0358, Critic Loss: 0.2139, Entropy: 8.5515
# -----------------------------------
# serial calc_performance called
# Episode 1100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.12
# Actor Loss: -0.0180, Critic Loss: 0.8339, Entropy: 7.6525
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.45
# Actor Loss: -0.0239, Critic Loss: 0.5727, Entropy: 7.1563
# -----------------------------------
# serial calc_performance called
# Episode 1300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.66
# Actor Loss: -0.0237, Critic Loss: 0.5688, Entropy: 6.8093
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.86
# Actor Loss: -0.0180, Critic Loss: 0.7045, Entropy: 6.1531
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.99
# Actor Loss: -0.0203, Critic Loss: 0.2470, Entropy: 5.6302
# -----------------------------------
# serial calc_performance called
# Episode 1600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.18
# Actor Loss: -0.0172, Critic Loss: 1.0842, Entropy: 5.1737
# -----------------------------------
# serial calc_performance called
# Episode 1700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.38
# Actor Loss: -0.0184, Critic Loss: 0.5672, Entropy: 4.6456
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.51
# Actor Loss: -0.0224, Critic Loss: 0.2188, Entropy: 3.9861
# -----------------------------------
# serial calc_performance called
# Episode 1900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.51
# Actor Loss: -0.0164, Critic Loss: 0.8758, Entropy: 3.9315
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.68
# Actor Loss: -0.0206, Critic Loss: 0.2807, Entropy: 3.3638
# -----------------------------------
# serial calc_performance called
# Episode 2100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.69
# Actor Loss: -0.0156, Critic Loss: 1.0031, Entropy: 3.2497
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.76
# Actor Loss: -0.0192, Critic Loss: 0.8092, Entropy: 3.0354
# -----------------------------------
# serial calc_performance called
# Episode 2300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.73
# Actor Loss: -0.0201, Critic Loss: 0.1255, Entropy: 2.9622
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.80
# Actor Loss: -0.0154, Critic Loss: 1.1896, Entropy: 2.6299
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.84
# Actor Loss: -0.0275, Critic Loss: 0.4411, Entropy: 2.5242
# -----------------------------------
# serial calc_performance called
# Episode 2600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.84
# Actor Loss: -0.0156, Critic Loss: 0.9273, Entropy: 2.1788
# -----------------------------------
# serial calc_performance called
# Episode 2700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.92
# Actor Loss: -0.0212, Critic Loss: 0.8602, Entropy: 2.1942
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.92
# Actor Loss: -0.0180, Critic Loss: 0.2209, Entropy: 2.0737
# -----------------------------------
# serial calc_performance called
# Episode 2900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.97
# Actor Loss: -0.0182, Critic Loss: 1.1239, Entropy: 2.2398
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.96
# Actor Loss: -0.0155, Critic Loss: 0.6278, Entropy: 1.9925
# -----------------------------------
# serial calc_performance called
# Episode 3100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.03
# Actor Loss: -0.0156, Critic Loss: 0.6267, Entropy: 1.7621
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.01
# Actor Loss: -0.0173, Critic Loss: 0.8974, Entropy: 1.8277
# -----------------------------------
# serial calc_performance called
# Episode 3300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.01
# Actor Loss: -0.0219, Critic Loss: 0.2822, Entropy: 2.1197
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.07
# Actor Loss: -0.0081, Critic Loss: 1.2554, Entropy: 1.9273
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.02
# Actor Loss: -0.0283, Critic Loss: 0.5696, Entropy: 1.9224
# -----------------------------------
# serial calc_performance called
# Episode 3600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.01
# Actor Loss: -0.0225, Critic Loss: 0.1000, Entropy: 2.0055
# -----------------------------------
# serial calc_performance called
# Episode 3700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.00
# Actor Loss: -0.0172, Critic Loss: 1.0772, Entropy: 1.9550
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.02
# Actor Loss: -0.0238, Critic Loss: 0.2441, Entropy: 2.0567
# -----------------------------------
# serial calc_performance called
# Episode 3900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.03
# Actor Loss: -0.0156, Critic Loss: 1.1840, Entropy: 1.9875
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.04
# Actor Loss: -0.0290, Critic Loss: 0.5959, Entropy: 2.0140
# -----------------------------------
# best Policy network found at episode 3400
# Training completed.
# Tuneset 1, Iteration 0: [15.071447 15.041289 15.027231 15.025611 15.019293 15.018703 15.013366
#  15.010789 15.010588 15.000932 14.9744   14.963582 14.919455 14.919095
#  14.844957 14.836946 14.797202 14.764355 14.726998 14.686255 14.682691
#  14.510898 14.50796  14.382147 14.181917 13.989194 13.856609 13.659372
#  13.447776 13.119982 12.701195 12.212265 11.778703 11.516856 10.937915
#  10.396496  9.724167  8.942641  7.994062  7.138703]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 9, iteration: 1, seed: 896493
# env: metapop1
# device: cpu
# state size: (20, 4), action size: 40
# actor: hidden num: 2, hidden size: [64, 64]
# critic: hidden num: 2, hidden size: [128, 128]
# encoder: hidden num: 2, hidden size: [64, 64], encoder output size: 64
# actor lr: 0.0005, critic lr: 0.0003, encoder lr: 0.0003
# lr decay type: multistep, lr decay rate: 1.0, min lr: -inf
# standardize: True
# gamma: 0.99, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: False, target KL: 0.02
# c1: 0.5, c2: 0.0, entropy_loss_included: False, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 15
# evaluation interval: 100, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 100, episodenum: 4000
# serial calc_performance called
# Episode 100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.15
# Actor Loss: -0.0123, Critic Loss: 0.4744, Entropy: 13.8516
# -----------------------------------
# serial calc_performance called
# Episode 200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 7.70
# Actor Loss: -0.0206, Critic Loss: 0.1562, Entropy: 13.7057
# -----------------------------------
# serial calc_performance called
# Episode 300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 8.53
# Actor Loss: -0.0189, Critic Loss: 0.3667, Entropy: 13.4043
# -----------------------------------
# serial calc_performance called
# Episode 400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 9.29
# Actor Loss: -0.0180, Critic Loss: 0.3267, Entropy: 13.0787
# -----------------------------------
# Episode 500
# serial calc_performance called
# Episode 500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.17
# Actor Loss: -0.0281, Critic Loss: 0.1206, Entropy: 12.4355
# -----------------------------------
# serial calc_performance called
# Episode 600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 10.83
# Actor Loss: -0.0142, Critic Loss: 0.6121, Entropy: 11.2496
# -----------------------------------
# serial calc_performance called
# Episode 700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.37
# Actor Loss: -0.0073, Critic Loss: 0.2812, Entropy: 10.6929
# -----------------------------------
# serial calc_performance called
# Episode 800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.71
# Actor Loss: -0.0147, Critic Loss: 0.5121, Entropy: 10.4178
# -----------------------------------
# serial calc_performance called
# Episode 900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 11.98
# Actor Loss: -0.0181, Critic Loss: 0.7250, Entropy: 9.9807
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.22
# Actor Loss: -0.0195, Critic Loss: 0.2129, Entropy: 9.7229
# -----------------------------------
# serial calc_performance called
# Episode 1100,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.52
# Actor Loss: -0.0157, Critic Loss: 0.9479, Entropy: 9.2434
# -----------------------------------
# serial calc_performance called
# Episode 1200,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 12.95
# Actor Loss: -0.0153, Critic Loss: 0.4515, Entropy: 8.6791
# -----------------------------------
# serial calc_performance called
# Episode 1300,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.33
# Actor Loss: -0.0143, Critic Loss: 0.5475, Entropy: 8.0100
# -----------------------------------
# serial calc_performance called
# Episode 1400,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.62
# Actor Loss: -0.0162, Critic Loss: 0.7187, Entropy: 6.9847
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 13.80
# Actor Loss: -0.0180, Critic Loss: 0.2637, Entropy: 6.7125
# -----------------------------------
# serial calc_performance called
# Episode 1600,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.13
# Actor Loss: -0.0198, Critic Loss: 1.0261, Entropy: 5.5931
# -----------------------------------
# serial calc_performance called
# Episode 1700,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.30
# Actor Loss: -0.0170, Critic Loss: 0.6977, Entropy: 5.0883
# -----------------------------------
# serial calc_performance called
# Episode 1800,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.44
# Actor Loss: -0.0300, Critic Loss: 0.1754, Entropy: 4.5710
# -----------------------------------
# serial calc_performance called
# Episode 1900,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.69
# Actor Loss: -0.0187, Critic Loss: 1.0985, Entropy: 3.6678
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000,LR: A0.0005/C0.0003/E0.0003 Avg Performance: 14.75
# Actor Loss: -0.0242, Critic Loss: 0.2256, Entropy: 3.5254
# -----------------------------------
# serial calc_performance called
# Episode 2100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.89
# Actor Loss: -0.0074, Critic Loss: 1.0875, Entropy: 3.4602
# -----------------------------------
# serial calc_performance called
# Episode 2200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.82
# Actor Loss: -0.0228, Critic Loss: 0.7718, Entropy: 3.6472
# -----------------------------------
# serial calc_performance called
# Episode 2300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 14.84
# Actor Loss: -0.0377, Critic Loss: 0.2074, Entropy: 3.1763
# -----------------------------------
# serial calc_performance called
# Episode 2400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.03
# Actor Loss: -0.0164, Critic Loss: 1.0442, Entropy: 2.8950
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.10
# Actor Loss: -0.0244, Critic Loss: 0.3798, Entropy: 2.7679
# -----------------------------------
# serial calc_performance called
# Episode 2600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.13
# Actor Loss: -0.0116, Critic Loss: 1.0322, Entropy: 2.6046
# -----------------------------------
# serial calc_performance called
# Episode 2700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.07
# Actor Loss: -0.0186, Critic Loss: 0.8248, Entropy: 2.8928
# -----------------------------------
# serial calc_performance called
# Episode 2800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.18
# Actor Loss: -0.0208, Critic Loss: 0.2173, Entropy: 2.6409
# -----------------------------------
# serial calc_performance called
# Episode 2900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.17
# Actor Loss: -0.0149, Critic Loss: 1.1085, Entropy: 2.7048
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.07
# Actor Loss: -0.0137, Critic Loss: 0.4561, Entropy: 3.0710
# -----------------------------------
# serial calc_performance called
# Episode 3100,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.15
# Actor Loss: -0.0165, Critic Loss: 0.7175, Entropy: 2.6763
# -----------------------------------
# serial calc_performance called
# Episode 3200,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.11
# Actor Loss: -0.0188, Critic Loss: 0.8744, Entropy: 2.5832
# -----------------------------------
# serial calc_performance called
# Episode 3300,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.12
# Actor Loss: -0.0184, Critic Loss: 0.2757, Entropy: 2.4677
# -----------------------------------
# serial calc_performance called
# Episode 3400,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.20
# Actor Loss: -0.0098, Critic Loss: 1.2135, Entropy: 2.1485
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.25
# Actor Loss: -0.0183, Critic Loss: 0.5730, Entropy: 2.1842
# -----------------------------------
# serial calc_performance called
# Episode 3600,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.29
# Actor Loss: -0.0193, Critic Loss: 0.1528, Entropy: 2.0652
# -----------------------------------
# serial calc_performance called
# Episode 3700,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.23
# Actor Loss: -0.0099, Critic Loss: 1.1076, Entropy: 1.6782
# -----------------------------------
# serial calc_performance called
# Episode 3800,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.21
# Actor Loss: -0.0132, Critic Loss: 0.3833, Entropy: 1.7368
# -----------------------------------
# serial calc_performance called
# Episode 3900,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.22
# Actor Loss: -0.0131, Critic Loss: 1.1640, Entropy: 1.8695
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000,LR: A0.000167/C0.0001/E0.0001 Avg Performance: 15.30
# Actor Loss: -0.0114, Critic Loss: 0.5810, Entropy: 1.5896
# -----------------------------------
# best Policy network found at episode 4000
# Training completed.
# Tuneset 1, Iteration 1: [15.295619 15.292321 15.253254 15.234874 15.218736 15.21273  15.196572
#  15.177973 15.167602 15.149709 15.128083 15.115332 15.110706 15.095305
#  15.074509 15.068223 15.028451 14.887754 14.844538 14.81568  14.752038
#  14.690341 14.43991  14.295314 14.134765 13.795963 13.617269 13.329338
#  12.946701 12.517126 12.218753 11.982892 11.705594 11.371326 10.825564
#  10.170663  9.289742  8.530955  7.697168  7.151481]
# seed  best_score
# 1  896493   15.295619
# 0  156992   15.071447
